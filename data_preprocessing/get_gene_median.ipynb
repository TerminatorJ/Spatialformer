# %% [markdown]
#  Getting all the .h5ad according to the names of the datasets

# %%
import os
import pickle
import scanpy as sc
from tqdm import tqdm

# %%
datanames=[
    "Xenium_Prime_Human_Ovary_Cancer_FF_xe_outs",
    "Xenium_Prime_Ovarian_Cancer_FFPE_XRrun_xe_outs",
    "Xenium_Prime_Breast_Cancer_FFPE_xe_outs",
    "Xenium_Prime_Cervical_Cancer_FFPE_xe_outs",
    "Xenium_Prime_Human_Skin_FFPE_xe_outs",
    "Xenium_Prime_Human_Prostate_FFPE_xe_outs",
    "Xenium_Prime_Human_Lymph_Node_Reactive_FFPE_xe_outs",
    "Xenium_Prime_Human_Lung_Cancer_FFPE_xe_outs"
    "Xenium_V1_hKidney_cancer_section_outs",
     "Xenium_V1_hColon_Non_diseased_Add_on_FFPE_outs",
     "Xenium_V1_hBoneMarrow_acute_lymphoid_leukemia_section_outs",
     "Xenium_V1_hLiver_nondiseased_section_FFPE_outs",
     "Xenium_V1_hLung_cancer_section_outs",
     "Xeniumranger_V1_hSkin_Melanoma_Add_on_FFPE_outs",
     "Xenium_Preview_Human_Non_diseased_Lung_With_Add_on_FFPE_outs",
     "Xenium_V1_hSkin_nondiseased_section_2_FFPE_outs",
     "Xenium_V1_hBone_nondiseased_section_outs",
     "Xenium_V1_FFPE_Human_Brain_Healthy_With_Addon_outs",
     "Xenium_V1_hHeart_nondiseased_section_FFPE_outs",
     "Xenium_V1_human_Pancreas_FFPE_outs",
     "Xenium_V1_FFPE_Human_Brain_Alzheimers_With_Addon_outs",
     "Xenium_V1_hSkin_nondiseased_section_1_FFPE_outs",
     "Xenium_V1_hBoneMarrow_nondiseased_section_outs",
     "Xenium_V1_Human_Ovarian_Cancer_Addon_FFPE_outs",
     "Xenium_V1_hSkin_Melanoma_Base_FFPE_outs",
     "Xenium_V1_FFPE_Human_Breast_ILC_outs",
     "Xenium_V1_hPancreas_Cancer_Add_on_FFPE_outs",
     "Xenium_V1_humanLung_Cancer_FFPE_outs",
     "Xenium_V1_Human_Ductal_Adenocarcinoma_FFPE_outs",
     "Xenium_V1_FFPE_Human_Breast_ILC_With_Addon_outs",
     "Xenium_V1_Human_Lung_Cancer_Addon_FFPE_outs",
     "Xenium_V1_hTonsil_follicular_lymphoid_hyperplasia_section_FFPE_outs",
    "Xenium_V1_hColon_Cancer_Base_FFPE_outs",
     "Xenium_V1_FFPE_Human_Breast_IDC_With_Addon_outs",
    "Xenium_V1_FFPE_Human_Breast_IDC_outs",
     "Xenium_V1_hLiver_cancer_section_FFPE_outs",
     "Xenium_V1_hColon_Non_diseased_Base_FFPE_outs",
     "Xenium_V1_hKidney_nondiseased_section_outs",
     "Xenium_V1_FFPE_Human_Breast_IDC_Big_2_outs",
     "Xenium_V1_FFPE_Human_Brain_Glioblastoma_With_Addon_outs",
     "Xenium_V1_Human_Colorectal_Cancer_Addon_FFPE_outs",
     "Xenium_V1_hLymphNode_nondiseased_section_outs",
     "Xenium_V1_hPancreas_nondiseased_section_outs",
     "Xenium_V1_FFPE_Human_Breast_IDC_Big_1_outs",
     "Xenium_V1_hColon_Cancer_Add_on_FFPE_outs",
     "Xenium_V1_hTonsil_reactive_follicular_hyperplasia_section_FFPE_outs",
     "Xenium_V1_Human_Brain_GBM_FFPE_outs",
     "Xenium_Preview_Human_Lung_Cancer_With_Add_on_2_FFPE_outs",
]

base_path = "/scratch/project_465001820/Spatialformer/data"
magic_path = lambda *x: os.path.join(os.path.abspath(base_path), *x)

# %% [markdown]
# loading all the non zero from all "Xenium 5k dataset

# %%
all_exp = {}
for dn in tqdm(datanames, desc="running all datasets"):
    try:
        exp_dict = pickle.load(open(f"/scratch/project_465001820/Spatialformer/data/Xenium_5k_gene_final_exp_{dn}.pkl", "rb"))
        for gene in exp_dict.keys():
            if gene not in all_exp.keys():
                all_exp[gene] = []
            else:
                all_exp[gene].extend(exp_dict[gene])
    except:
        pass
# Out:
# running all datasets: 100%|██████████| 47/47 [00:47<00:00,  1.00s/it]

# %% [markdown]
# #getting the median value

# %%
len(list(all_exp.keys()))
# Out:
# 6000

# %%
import numpy as np

gene_median = {}
for gene in all_exp.keys():
    non_zero_value = all_exp[gene]
    median = np.median(non_zero_value)
    gene_median[gene] = median
# Out:
# /scratch/project_465001820/miniconda3/envs/spatialformer/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /scratch/project_465001820/miniconda3/envs/spatialformer/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
gene_median
# Out:
# {'A2ML1': 1.0,
#  'AAMP': 1.0,
#  'AAR2': 1.0,
#  'AARSD1': 1.0,
#  'ABAT': 1.0,
#  'ABCA1': 1.0,
#  'ABCA3': 1.0,
#  'ABCA4': 1.0,
#  'ABCA7': 1.0,
#  'ABCB1': 1.0,
#  'ABCB4': 1.0,
#  'ABCB6': 1.0,
#  'ABCC1': 1.0,
#  'ABCC12': 1.0,
#  'ABCC2': 1.0,
#  'ABCC3': 1.0,
#  'ABCC4': 1.0,
#  'ABCC6': 1.0,
#  'ABCC8': 1.0,
#  'ABCC9': 1.0,
#  'ABCD1': 1.0,
#  'ABCD3': 1.0,
#  'ABCD4': 1.0,
#  'ABCF3': 1.0,
#  'ABCG1': 1.0,
#  'ABCG2': 1.0,
#  'ABHD11': 1.0,
#  'ABHD6': 1.0,
#  'ABI3': 1.0,
#  'ABI3BP': 1.0,
#  'ABL1': 1.0,
#  'ABL2': 1.0,
#  'ABO': 1.0,
#  'ABTB1': 1.0,
#  'ABTB2': 1.0,
#  'ACAA2': 1.0,
#  'ACACA': 1.0,
#  'ACACB': 1.0,
#  'ACAP1': 1.0,
#  'ACAP2': 1.0,
#  'ACAT1': 1.0,
#  'ACE': 1.0,
#  'ACE2': 1.0,
#  'ACHE': 1.0,
#  'ACKR3': 1.0,
#  'ACLY': 1.0,
#  'ACOD1': 1.0,
#  'ACP5': 1.0,
#  'ACPP': 1.0,
#  'ACRBP': 1.0,
#  'ACRV1': 1.0,
#  'ACSL4': 1.0,
#  'ACTBL2': 1.0,
#  'ACTL6A': 1.0,
#  'ACTL7A': 1.0,
#  'ACTN1': 1.0,
#  'ACTN2': 1.0,
#  'ACTN4': 1.0,
#  'ACVR1': 1.0,
#  'ACVR1B': 1.0,
#  'ACVR2A': 1.0,
#  'ACVRL1': 1.0,
#  'ACYP2': 1.0,
#  'ADA': 1.0,
#  'ADAM10': 1.0,
#  'ADAM12': 1.0,
#  'ADAM17': 1.0,
#  'ADAM28': 1.0,
#  'ADAM33': 1.0,
#  'ADAM8': 1.0,
#  'ADAM9': 1.0,
#  'ADAMDEC1': 1.0,
#  'ADAMTS1': 1.0,
#  'ADAMTS12': 1.0,
#  'ADAMTS19': 1.0,
#  'ADAMTS2': 1.0,
#  'ADAMTS4': 1.0,
#  'ADAMTS5': 1.0,
#  'ADAMTSL3': 1.0,
#  'ADAR': 1.0,
#  'ADCY2': 1.0,
#  'ADCYAP1': 1.0,
#  'ADCYAP1R1': 1.0,
#  'ADD1': 1.0,
#  'ADGRA1': 1.0,
#  'ADGRA2': 1.0,
#  'ADGRA3': 1.0,
#  'ADGRB1': 1.0,
#  'ADGRB2': 1.0,
#  'ADGRD1': 1.0,
#  'ADGRD2': 1.0,
#  'ADGRE1': 1.0,
#  'ADGRE2': 1.0,
#  'ADGRE5': 1.0,
#  'ADGRG5': 1.0,
#  'ADGRG6': 1.0,
#  'ADGRL1': 1.0,
#  'ADGRL4': 1.0,
#  'ADIPOQ': 1.0,
#  'ADIPOR1': 1.0,
#  'ADIPOR2': 1.0,
#  'ADM': 1.0,
#  'ADNP': 1.0,
#  'ADORA1': 1.0,
#  'ADORA2A': 1.0,
#  'ADORA2B': 1.0,
#  'ADORA3': 1.0,
#  'ADRA1A': 1.0,
#  'ADRA1B': 1.0,
#  'ADRA1D': 1.0,
#  'ADRA2A': 1.0,
#  'ADRA2B': 1.0,
#  'ADRA2C': 1.0,
#  'ADRB1': 1.0,
#  'ADRB2': 1.0,
#  'ADRB3': 1.0,
#  'ADTRP': 1.0,
#  'AEBP1': 1.0,
#  'AFAP1L2': 1.0,
#  'AFF1': 1.0,
#  'AFF2': 1.0,
#  'AFG1L': 1.0,
#  'AFM': 1.0,
#  'AGAP1': 1.0,
#  'AGAP3': 1.0,
#  'AGER': 1.0,
#  'AGMAT': 1.0,
#  'AGO1': 1.0,
#  'AGR3': 1.0,
#  'AGRP': 1.0,
#  'AGTR1': 1.0,
#  'AGTR2': 1.0,
#  'AGXT': 1.0,
#  'AHCY': 1.0,
#  'AHR': 1.0,
#  'AHRR': 1.0,
#  'AHSG': 1.0,
#  'AICDA': 1.0,
#  'AIF1L': 1.0,
#  'AIFM1': 1.0,
#  'AIM2': 1.0,
#  'AIMP2': 1.0,
#  'AIP': 1.0,
#  'AIRE': 1.0,
#  'AJAP1': 1.0,
#  'AKAP11': 1.0,
#  'AKAP4': 1.0,
#  'AKAP8': 1.0,
#  'AKR1B1': 1.0,
#  'AKR1C3': 1.0,
#  'AKT1': 1.0,
#  'AKT2': 1.0,
#  'AKT3': 1.0,
#  'AKTIP': 1.0,
#  'ALAD': 1.0,
#  'ALCAM': 1.0,
#  'ALDH1B1': 1.0,
#  'ALDH2': 1.0,
#  'ALDH3A2': 1.0,
#  'ALDH7A1': 1.0,
#  'ALDOA': 1.0,
#  'ALG11': 1.0,
#  'ALG13': 1.0,
#  'ALG2': 1.0,
#  'ALG6': 1.0,
#  'ALG9': 1.0,
#  'ALK': 1.0,
#  'ALKBH5': 1.0,
#  'ALOX12': 1.0,
#  'ALOX15': 1.0,
#  'ALOX5': 1.0,
#  'ALPK1': 1.0,
#  'ALPK3': 1.0,
#  'ALPL': 1.0,
#  'ALX1': 1.0,
#  'ALYREF': 1.0,
#  'AMACR': 1.0,
#  'AMER1': 1.0,
#  'AMFR': 1.0,
#  'AMH': 1.0,
#  'AMIGO1': 1.0,
#  'AMIGO3': 1.0,
#  'AMOT': 1.0,
#  'ANAPC1': 1.0,
#  'ANGPT1': 1.0,
#  'ANGPT2': 1.0,
#  'ANGPTL2': 1.0,
#  'ANGPTL3': 1.0,
#  'ANGPTL4': 1.0,
#  'ANGPTL6': 1.0,
#  'ANGPTL7': 1.0,
#  'ANGPTL8': 1.0,
#  'ANK1': 1.0,
#  'ANKHD1': 1.0,
#  'ANKK1': 1.0,
#  'ANKRD13A': 1.0,
#  'ANKRD13D': 1.0,
#  'ANKRD17': 1.0,
#  'ANKRD30A': 3.0,
#  'ANKRD40': 1.0,
#  'ANKRD44': 1.0,
#  'ANKRD6': 1.0,
#  'ANKS1A': 1.0,
#  'ANKS6': 1.0,
#  'ANKZF1': 1.0,
#  'ANO1': 1.0,
#  'ANO3': 1.0,
#  'ANP32E': 1.0,
#  'ANPEP': 2.0,
#  'ANXA10': 1.0,
#  'ANXA2': 1.0,
#  'ANXA3': 1.0,
#  'ANXA5': 1.0,
#  'ANXA8': 1.0,
#  'AOAH': 1.0,
#  'AOC3': 1.0,
#  'AOX1': 1.0,
#  'AP1B1': 1.0,
#  'AP1M1': 1.0,
#  'AP1S3': 1.0,
#  'AP2A1': 1.0,
#  'AP2A2': 1.0,
#  'AP2M1': 1.0,
#  'AP3B2': 1.0,
#  'AP3D1': 1.0,
#  'AP3M2': 1.0,
#  'AP5B1': 1.0,
#  'APAF1': 1.0,
#  'APC': 1.0,
#  'APCDD1': 1.0,
#  'APELA': 1.0,
#  'APEX1': 1.0,
#  'APEX2': 1.0,
#  'APH1B': 1.0,
#  'API5': 1.0,
#  'APLF': 1.0,
#  'APLN': 1.0,
#  'APLNR': 1.0,
#  'APMAP': 1.0,
#  'APOB': 1.0,
#  'APOBEC3B': 1.0,
#  'APOBEC3C': 1.0,
#  'APOBEC3D': 1.0,
#  'APOBEC3F': 1.0,
#  'APOBEC3G': 1.0,
#  'APOL1': 1.0,
#  'APOL2': 1.0,
#  'APOL3': 1.0,
#  'APOL6': 1.0,
#  'APOM': 1.0,
#  'APP': 1.0,
#  'APPBP2': 1.0,
#  'APTX': 1.0,
#  'AQP4': 2.0,
#  'AQP5': 1.0,
#  'AQP7': 1.0,
#  'AQP8': 3.0,
#  'AQP9': 1.0,
#  'AR': 1.0,
#  'ARC': 1.0,
#  'ARF1': 1.0,
#  'ARF6': 1.0,
#  'ARFIP1': 1.0,
#  'ARG1': 1.0,
#  'ARG2': 1.0,
#  'ARHGAP35': 1.0,
#  'ARHGAP36': 1.0,
#  'ARHGEF2': 1.0,
#  'ARHGEF7': 1.0,
#  'ARID1A': 1.0,
#  'ARID3B': 1.0,
#  'ARL4D': 1.0,
#  'ARL8B': 1.0,
#  'ARMC5': 1.0,
#  'ARMC7': 1.0,
#  'ARMH3': 1.0,
#  'ARNT': 1.0,
#  'ARNTL': 1.0,
#  'ARR3': 1.0,
#  'ARRB1': 1.0,
#  'ARRB2': 1.0,
#  'ARRDC3': 1.0,
#  'ART1': 1.0,
#  'ART3': 1.0,
#  'ART4': 1.0,
#  'ARX': 1.0,
#  'ASCC2': 1.0,
#  'ASCC3': 1.0,
#  'ASCL1': 1.0,
#  'ASCL2': 1.0,
#  'ASF1B': 1.0,
#  'ASH2L': 1.0,
#  'ASIC1': 1.0,
#  'ASPM': 1.0,
#  'ASPN': 1.0,
#  'ASTN2': 1.0,
#  'ASXL1': 1.0,
#  'ATAD3A': 1.0,
#  'ATF1': 1.0,
#  'ATF2': 1.0,
#  'ATF3': 1.0,
#  'ATF4': 1.0,
#  'ATF6': 1.0,
#  'ATG10': 1.0,
#  'ATG16L1': 1.0,
#  'ATG2A': 1.0,
#  'ATG5': 1.0,
#  'ATG7': 1.0,
#  'ATIC': 1.0,
#  'ATL1': 1.0,
#  'ATL2': 1.0,
#  'ATL3': 1.0,
#  'ATM': 1.0,
#  'ATOH1': 1.0,
#  'ATOH7': 1.0,
#  'ATOH8': 1.0,
#  'ATP10D': 1.0,
#  'ATP13A2': 1.0,
#  'ATP1A1': 1.0,
#  'ATP2A2': 1.0,
#  'ATP2B1': 1.0,
#  'ATP5F1A': 1.0,
#  'ATP5F1C': 1.0,
#  'ATP6V1B1': 1.0,
#  'ATP6V1H': 1.0,
#  'ATP7A': 1.0,
#  'ATP7B': 1.0,
#  'ATPAF1': 1.0,
#  'ATPSCKMT': 1.0,
#  'ATR': 1.0,
#  'ATRX': 1.0,
#  'ATXN1': 1.0,
#  'ATXN1L': 1.0,
#  'ATXN2': 1.0,
#  'ATXN2L': 1.0,
#  'ATXN3': 1.0,
#  'ATXN7L2': 1.0,
#  'AUNIP': 1.0,
#  'AURKA': 1.0,
#  'AURKB': 1.0,
#  'AURKC': 1.0,
#  'AVPR1A': 1.0,
#  'AVPR1B': 1.0,
#  'AVPR2': 1.0,
#  'AXIN1': 1.0,
#  'AXIN2': 1.0,
#  'AXL': 1.0,
#  'B3GAT1': 1.0,
#  'B4GAT1': 1.0,
#  'BAALC': 1.0,
#  'BAAT': 1.0,
#  'BACE1': 1.0,
#  'BACE2': 1.0,
#  'BACH2': 1.0,
#  'BAD': 1.0,
#  'BAG2': 1.0,
#  'BAG3': 1.0,
#  'BAG6': 1.0,
#  'BAIAP2': 1.0,
#  'BAK1': 1.0,
#  'BANK1': 1.0,
#  'BAP1': 1.0,
#  'BARD1': 1.0,
#  'BARHL2': 1.0,
#  'BARX2': 1.0,
#  'BATF': 1.0,
#  'BATF3': 1.0,
#  'BAX': 1.0,
#  'BAZ2B': 1.0,
#  'BBC3': 1.0,
#  'BCAM': 1.0,
#  'BCAN': 1.0,
#  'BCAR1': 1.0,
#  'BCAR3': 1.0,
#  'BCAR4': 1.0,
#  'BCAS3': 1.0,
#  'BCCIP': 1.0,
#  'BCHE': 1.0,
#  'BCKDK': 1.0,
#  'BCL10': 1.0,
#  'BCL11A': 1.0,
#  'BCL11B': 1.0,
#  'BCL2': 1.0,
#  'BCL2A1': 1.0,
#  'BCL2L1': 1.0,
#  'BCL2L11': 1.0,
#  'BCL2L12': 1.0,
#  'BCL2L13': 1.0,
#  'BCL2L2': 1.0,
#  'BCL3': 1.0,
#  'BCL6': 1.0,
#  'BCL6B': 1.0,
#  'BCL7B': 1.0,
#  'BCL7C': 1.0,
#  'BCOR': 1.0,
#  'BCORL1': 1.0,
#  'BCR': 1.0,
#  'BDKRB1': 1.0,
#  'BDKRB2': 1.0,
#  'BDNF': 1.0,
#  'BEAN1': 1.0,
#  'BECN1': 1.0,
#  'BEX2': 1.0,
#  'BFSP1': 1.0,
#  'BFSP2': 1.0,
#  'BHMT': 1.0,
#  'BICRAL': 1.0,
#  'BID': 1.0,
#  'BIK': 1.0,
#  'BIRC2': 1.0,
#  'BIRC5': 1.0,
#  'BIRC7': 1.0,
#  'BLK': 1.0,
#  'BLM': 1.0,
#  'BLNK': 1.0,
#  'BLOC1S2': 1.0,
#  'BLVRA': 1.0,
#  'BMI1': 1.0,
#  'BMP2': 1.0,
#  'BMP2K': 1.0,
#  'BMP4': 1.0,
#  'BMP5': 1.0,
#  'BMP6': 1.0,
#  'BMP7': 1.0,
#  'BMP8A': 1.0,
#  'BMP8B': 1.0,
#  'BMPER': 1.0,
#  'BMPR1A': 1.0,
#  'BMPR1B': 1.0,
#  'BMPR2': 1.0,
#  'BNC1': 1.0,
#  'BNC2': 1.0,
#  'BNIP3': 1.0,
#  'BOLL': 1.0,
#  'BRAF': 1.0,
#  'BRCA1': 1.0,
#  'BRCA2': 1.0,
#  'BRD3': 1.0,
#  'BRD4': 1.0,
#  'BRDT': 1.0,
#  'BRI3BP': 1.0,
#  'BRINP1': 1.0,
#  'BRIP1': 1.0,
#  'BRIX1': 1.0,
#  'BRSK2': 1.0,
#  'BSDC1': 1.0,
#  'BST1': 1.0,
#  'BTAF1': 1.0,
#  'BTBD9': 1.0,
#  'BTK': 1.0,
#  'BTLA': 1.0,
#  'BTN3A1': 1.0,
#  'BTNL2': 1.0,
#  'BTRC': 1.0,
#  'BUB1': 1.0,
#  'BUB1B': 1.0,
#  'BVES': 1.0,
#  'C1QBP': 1.0,
#  'C1QL3': 2.0,
#  'C1QTNF1': 1.0,
#  'C1QTNF6': 1.0,
#  'C1QTNF9': 1.0,
#  'C1RL': 1.0,
#  'C3AR1': 1.0,
#  'C4A': 1.0,
#  'C4B': 1.0,
#  'C5': 1.0,
#  'C5AR1': 1.0,
#  'C6': 1.0,
#  'C8B': 1.0,
#  'C8G': 1.0,
#  'C9': 1.0,
#  'CA10': 1.0,
#  'CA12': 1.0,
#  'CA14': 1.0,
#  'CA4': 1.0,
#  'CA9': 1.0,
#  'CABCOCO1': 1.0,
#  'CABP4': 1.0,
#  'CABYR': 1.0,
#  'CACNA1B': 1.0,
#  'CACNA1C': 1.0,
#  'CACNA1D': 1.0,
#  'CACNA1G': 1.0,
#  'CACNA1H': 1.0,
#  'CACNA2D1': 1.0,
#  'CACNG3': 1.0,
#  'CACNG4': 1.0,
#  'CACNG5': 1.0,
#  'CACUL1': 1.0,
#  'CACYBP': 1.0,
#  'CAD': 1.0,
#  'CADM3': 1.0,
#  'CADM4': 1.0,
#  'CALB1': 1.0,
#  'CALB2': 1.0,
#  'CALCA': 1.0,
#  'CALCB': 1.0,
#  'CALCR': 1.0,
#  'CALCRL': 1.0,
#  'CALM3': 1.0,
#  'CALML3': 1.0,
#  'CALR3': 1.0,
#  'CAMK1': 1.0,
#  'CAMK2A': 1.0,
#  'CAMK2B': 1.0,
#  'CAMK2D': 1.0,
#  'CAMK2G': 1.0,
#  'CAMKV': 1.0,
#  'CAMP': 1.0,
#  'CAMSAP2': 1.0,
#  'CAND1': 1.0,
#  'CANX': 1.0,
#  'CAPN1': 1.0,
#  'CAPN3': 1.0,
#  'CARD10': 1.0,
#  'CARD11': 1.0,
#  'CARD14': 1.0,
#  'CARD8': 1.0,
#  'CARD9': 1.0,
#  'CARF': 1.0,
#  'CARM1': 1.0,
#  'CARTPT': 1.0,
#  'CASC8': 1.0,
#  'CASK': 1.0,
#  'CASP1': 1.0,
#  'CASP10': 1.0,
#  'CASP2': 1.0,
#  'CASP3': 1.0,
#  'CASP6': 1.0,
#  'CASP7': 1.0,
#  'CASP8': 1.0,
#  'CASP8AP2': 1.0,
#  'CASP9': 1.0,
#  'CASQ2': 1.0,
#  'CASR': 1.0,
#  'CASS4': 1.0,
#  'CASZ1': 1.0,
#  'CAT': 1.0,
#  'CATSPER2': 1.0,
#  'CAV2': 1.0,
#  'CAVIN2': 1.0,
#  'CAVIN3': 1.0,
#  'CBARP': 1.0,
#  'CBFB': 1.0,
#  'CBL': 1.0,
#  'CBLB': 1.0,
#  'CBLIF': 1.0,
#  'CBLN1': 1.0,
#  'CBLN3': 1.0,
#  'CBLN4': 1.0,
#  'CBR1': 1.0,
#  'CBS': 1.0,
#  'CBSL': 1.0,
#  'CBWD2': 1.0,
#  'CBX1': 1.0,
#  'CBX3': 1.0,
#  'CBX5': 1.0,
#  'CBX7': 1.0,
#  'CC2D1A': 1.0,
#  'CCAR2': 1.0,
#  'CCAT2': 1.0,
#  'CCBE1': 1.0,
#  'CCDC102B': 1.0,
#  'CCDC103': 1.0,
#  'CCDC113': 1.0,
#  'CCDC124': 1.0,
#  'CCDC136': 1.0,
#  'CCDC137': 1.0,
#  'CCDC14': 1.0,
#  'CCDC141': 1.0,
#  'CCDC170': 1.0,
#  'CCDC27': 1.0,
#  'CCDC33': 1.0,
#  'CCDC43': 1.0,
#  'CCDC50': 1.0,
#  'CCDC51': 1.0,
#  'CCDC57': 1.0,
#  'CCDC6': 1.0,
#  'CCDC61': 1.0,
#  'CCDC62': 1.0,
#  'CCDC7': 1.0,
#  'CCDC77': 1.0,
#  'CCDC80': 1.0,
#  'CCDC86': 1.0,
#  'CCDC9': 1.0,
#  'CCDC91': 1.0,
#  'CCK': 3.0,
#  'CCKAR': 1.0,
#  'CCKBR': 1.0,
#  'CCL1': 1.0,
#  'CCL11': 1.0,
#  'CCL13': 1.0,
#  'CCL14': 1.0,
#  'CCL15': 1.0,
#  'CCL16': 1.0,
#  'CCL17': 1.0,
#  'CCL18': 1.0,
#  'CCL19': 1.0,
#  'CCL20': 1.0,
#  'CCL22': 1.0,
#  'CCL23': 1.0,
#  'CCL24': 1.0,
#  'CCL25': 1.0,
#  'CCL26': 1.0,
#  'CCL27': 1.0,
#  'CCL28': 1.0,
#  'CCL7': 1.0,
#  'CCL8': 1.0,
#  'CCN1': 1.0,
#  'CCN2': 1.0,
#  'CCN3': 1.0,
#  'CCN4': 1.0,
#  'CCN5': 1.0,
#  'CCNA1': 1.0,
#  'CCNA2': 1.0,
#  'CCNB1': 1.0,
#  'CCNB2': 1.0,
#  'CCNB3': 1.0,
#  'CCND1': 2.0,
#  'CCND2': 1.0,
#  'CCND3': 1.0,
#  'CCNDBP1': 1.0,
#  'CCNE1': 1.0,
#  'CCNO': 1.0,
#  'CCNT1': 1.0,
#  'CCNY': 1.0,
#  'CCR1': 1.0,
#  'CCR2': 1.0,
#  'CCR3': 1.0,
#  'CCR4': 1.0,
#  'CCR5': 1.0,
#  'CCR6': 1.0,
#  'CCR7': 1.0,
#  'CCR8': 1.0,
#  'CCR9': 1.0,
#  'CCRL2': 1.0,
#  'CCT2': 1.0,
#  'CCT3': 1.0,
#  'CCT5': 1.0,
#  'CCT6A': 1.0,
#  'CCT7': 1.0,
#  'CCT8': 1.0,
#  'CD101': 1.0,
#  'CD109': 1.0,
#  'CD14': 1.0,
#  'CD151': 1.0,
#  'CD160': 1.0,
#  'CD163': 1.0,
#  'CD177': 1.0,
#  'CD180': 1.0,
#  'CD19': 1.0,
#  'CD1A': 1.0,
#  'CD1B': 1.0,
#  'CD1C': 1.0,
#  'CD1D': 1.0,
#  'CD1E': 1.0,
#  'CD2': 1.0,
#  'CD200': 1.0,
#  'CD207': 1.0,
#  'CD209': 1.0,
#  'CD22': 1.0,
#  'CD226': 1.0,
#  'CD244': 1.0,
#  'CD247': 1.0,
#  'CD248': 1.0,
#  'CD27': 1.0,
#  'CD274': 1.0,
#  'CD276': 1.0,
#  'CD28': 1.0,
#  'CD2AP': 1.0,
#  'CD2BP2': 1.0,
#  'CD300A': 1.0,
#  'CD300C': 1.0,
#  'CD300E': 1.0,
#  'CD302': 1.0,
#  'CD320': 1.0,
#  'CD33': 1.0,
#  'CD34': 1.0,
#  'CD36': 1.0,
#  'CD38': 1.0,
#  'CD3E': 1.0,
#  'CD3EAP': 1.0,
#  'CD3G': 1.0,
#  'CD4': 1.0,
#  'CD40': 1.0,
#  'CD40LG': 1.0,
#  'CD44': 1.0,
#  'CD46': 1.0,
#  'CD47': 1.0,
#  'CD5': 1.0,
#  'CD55': 1.0,
#  'CD58': 1.0,
#  'CD59': 1.0,
#  'CD5L': 1.0,
#  'CD6': 1.0,
#  'CD68': 1.0,
#  'CD7': 1.0,
#  'CD70': 1.0,
#  'CD72': 1.0,
#  'CD79A': 2.0,
#  'CD79B': 1.0,
#  'CD80': 1.0,
#  'CD82': 1.0,
#  'CD83': 1.0,
#  'CD84': 1.0,
#  'CD86': 1.0,
#  'CD8A': 1.0,
#  'CD8B': 1.0,
#  'CD93': 1.0,
#  'CD96': 1.0,
#  'CD99': 1.0,
#  'CDA': 1.0,
#  'CDAN1': 1.0,
#  'CDC123': 1.0,
#  'CDC14A': 1.0,
#  'CDC20': 1.0,
#  'CDC25A': 1.0,
#  'CDC25C': 1.0,
#  'CDC27': 1.0,
#  'CDC34': 1.0,
#  'CDC37': 1.0,
#  'CDC42': 1.0,
#  'CDC42BPG': 1.0,
#  'CDC6': 1.0,
#  'CDC73': 1.0,
#  'CDCA2': 1.0,
#  'CDCA3': 1.0,
#  'CDCA7L': 1.0,
#  'CDCP1': 1.0,
#  'CDH1': 1.0,
#  'CDH11': 1.0,
#  'CDH13': 1.0,
#  'CDH16': 2.0,
#  'CDH2': 1.0,
#  'CDH22': 1.0,
#  'CDH23': 1.0,
#  'CDH3': 1.0,
#  'CDH5': 1.0,
#  'CDH6': 1.0,
#  'CDH7': 1.0,
#  'CDHR1': 1.0,
#  'CDHR2': 1.0,
#  'CDK1': 1.0,
#  'CDK10': 1.0,
#  'CDK14': 1.0,
#  'CDK16': 1.0,
#  'CDK17': 1.0,
#  'CDK18': 1.0,
#  'CDK2': 1.0,
#  'CDK3': 1.0,
#  'CDK4': 1.0,
#  'CDK5': 1.0,
#  'CDK5RAP1': 1.0,
#  'CDK6': 1.0,
#  'CDK7': 1.0,
#  'CDK8': 1.0,
#  'CDK9': 1.0,
#  'CDKAL1': 1.0,
#  'CDKL1': 1.0,
#  'CDKL3': 1.0,
#  'CDKN1A': 1.0,
#  'CDKN1B': 1.0,
#  'CDKN1C': 1.0,
#  'CDKN2A': 1.0,
#  'CDKN2AIP': 1.0,
#  'CDKN2B': 1.0,
#  'CDKN3': 1.0,
#  'CDR2L': 1.0,
#  'CDSN': 1.0,
#  'CDV3': 1.0,
#  'CDX1': 1.0,
#  'CDX2': 1.0,
#  'CEACAM1': 1.0,
#  'CEACAM3': 1.0,
#  'CEACAM8': 1.0,
#  'CEBPA': 1.0,
#  'CELSR1': 1.0,
#  'CELSR2': 1.0,
#  'CELSR3': 1.0,
#  'CEMIP2': 1.0,
#  'CENPA': 1.0,
#  'CENPB': 1.0,
#  'CENPF': 1.0,
#  'CENPV': 1.0,
#  'CEP112': 1.0,
#  'CEP128': 1.0,
#  'CEP170': 1.0,
#  'CEP19': 1.0,
#  'CEP44': 1.0,
#  'CEP55': 1.0,
#  'CEP85': 1.0,
#  'CES1': 1.0,
#  'CETP': 1.0,
#  'CFAP20': 1.0,
#  'CFAP43': 1.0,
#  'CFAP46': 1.0,
#  'CFAP47': 1.0,
#  'CFB': 2.0,
#  'CFC1': 1.0,
#  'CFDP1': 1.0,
#  'CFH': 1.0,
#  'CFHR1': 2.0,
#  'CFL2': 1.0,
#  'CFLAR': 1.0,
#  'CFP': 1.0,
#  'CFTR': 2.0,
#  'CGAS': 1.0,
#  'CGB3': 1.0,
#  'CGNL1': 1.0,
#  'CGRRF1': 1.0,
#  'CH25H': 1.0,
#  'CHAD': 1.0,
#  'CHAF1A': 1.0,
#  'CHAMP1': 1.0,
#  'CHD3': 1.0,
#  'CHD5': 1.0,
#  'CHD7': 1.0,
#  'CHEK1': 1.0,
#  'CHEK2': 1.0,
#  'CHFR': 1.0,
#  'CHIT1': 1.0,
#  'CHKA': 1.0,
#  'CHODL': 1.0,
#  'CHRAC1': 1.0,
#  'CHRDL2': 1.0,
#  'CHRM1': 1.0,
#  'CHRM2': 1.0,
#  'CHRM3': 1.0,
#  'CHRM4': 1.0,
#  'CHRM5': 1.0,
#  'CHRNA2': 1.0,
#  'CHRNA3': 1.0,
#  'CHRNA4': 1.0,
#  'CHRNA5': 1.0,
#  'CHRNA6': 1.0,
#  'CHRNA7': 1.0,
#  'CHRNB1': 1.0,
#  'CHRNB2': 1.0,
#  'CHRNB3': 1.0,
#  'CHRNB4': 1.0,
#  'CHST8': 1.0,
#  'CHUK': 1.0,
#  'CIDEC': 1.0,
#  'CIITA': 1.0,
#  'CILP2': 1.0,
#  'CINP': 1.0,
#  'CIP2A': 1.0,
#  'CISD2': 1.0,
#  'CKAP2': 1.0,
#  'CKAP4': 1.0,
#  'CKAP5': 1.0,
#  'CKS2': 1.0,
#  'CLCN3': 1.0,
#  'CLCN4': 1.0,
#  'CLCN5': 1.0,
#  'CLDN1': 1.0,
#  'CLDN18': 1.0,
#  'CLDN5': 1.0,
#  'CLDN7': 1.0,
#  'CLEC10A': 1.0,
#  'CLEC12A': 1.0,
#  'CLEC14A': 1.0,
#  'CLEC16A': 1.0,
#  'CLEC2A': 1.0,
#  'CLEC4A': 1.0,
#  'CLEC4C': 1.0,
#  'CLEC4D': 1.0,
#  'CLEC4M': 1.0,
#  'CLEC5A': 1.0,
#  'CLEC6A': 1.0,
#  'CLEC7A': 1.0,
#  'CLEC9A': 1.0,
#  'CLGN': 1.0,
#  'CLIC3': 1.0,
#  'CLIC4': 1.0,
#  'CLIC6': 3.0,
#  'CLK2': 1.0,
#  'CLK3': 1.0,
#  'CLK4': 1.0,
#  'CLN3': 1.0,
#  'CLN5': 1.0,
#  'CLNK': 1.0,
#  'CLOCK': 1.0,
#  'CLPTM1L': 1.0,
#  'CLPX': 1.0,
#  'CLSTN1': 1.0,
#  'CLSTN3': 1.0,
#  'CLTC': 1.0,
#  'CMA1': 1.0,
#  'CMKLR1': 1.0,
#  'CMSS1': 1.0,
#  'CMTM5': 1.0,
#  'CMTM8': 1.0,
#  'CMYA5': 1.0,
#  'CNDP1': 2.0,
#  'CNGB1': 1.0,
#  'CNGB3': 1.0,
#  'CNIH4': 1.0,
#  'CNKSR3': 1.0,
#  'CNMD': 1.0,
#  'CNNM1': 1.0,
#  'CNNM3': 1.0,
#  'CNOT1': 1.0,
#  'CNP': 1.0,
#  'CNR1': 1.0,
#  'CNR2': 1.0,
#  'CNRIP1': 1.0,
#  'CNST': 1.0,
#  'CNTF': 1.0,
#  'CNTLN': 1.0,
#  'CNTN2': 2.0,
#  'CNTN6': 1.0,
#  'CNTNAP1': 1.0,
#  'CNTNAP3': 1.0,
#  'CNTNAP4': 1.0,
#  'CNTROB': 1.0,
#  'COASY': 1.0,
#  'COBLL1': 1.0,
#  'COCH': 1.0,
#  'COIL': 1.0,
#  'COL10A1': 1.0,
#  'COL11A1': 1.0,
#  'COL17A1': 1.0,
#  'COL18A1': 1.0,
#  'COL23A1': 1.0,
#  'COL25A1': 1.0,
#  'COL2A1': 1.0,
#  'COL4A1': 1.0,
#  'COL4A2': 1.0,
#  'COL4A3': 1.0,
#  'COL4A4': 1.0,
#  'COL4A5': 1.0,
#  'COL5A1': 1.0,
#  'COL5A2': 1.0,
#  'COL7A1': 1.0,
#  'COLEC12': 1.0,
#  'COLQ': 1.0,
#  'COMP': 1.0,
#  'COMT': 1.0,
#  'COPS5': 1.0,
#  'COQ8A': 1.0,
#  'CORIN': 1.0,
#  'CORO1B': 1.0,
#  'CORO1C': 1.0,
#  'CORT': 1.0,
#  'CP': 1.0,
#  'CPA4': 1.0,
#  'CPA5': 1.0,
#  'CPA6': 1.0,
#  'CPB2': 1.0,
#  'CPEB1': 1.0,
#  'CPEB2': 1.0,
#  'CPEB3': 1.0,
#  'CPLX3': 1.0,
#  'CPNE9': 1.0,
#  'CPS1': 1.0,
#  'CPSF6': 1.0,
#  'CPT1A': 1.0,
#  'CPVL': 1.0,
#  'CPXM2': 1.0,
#  'CPZ': 1.0,
#  'CR1': 1.0,
#  'CR2': 1.0,
#  'CRB2': 1.0,
#  'CREB1': 1.0,
#  'CREB3': 1.0,
#  'CREB5': 1.0,
#  'CREBBP': 1.0,
#  'CREG1': 1.0,
#  'CREG2': 1.0,
#  'CRH': 1.0,
#  'CRHR1': 1.0,
#  'CRHR2': 1.0,
#  'CRIPT': 1.0,
#  'CRK': 1.0,
#  'CRKL': 1.0,
#  'CRNDE': 1.0,
#  'CRNN': 1.0,
#  'CRTAC1': 1.0,
#  'CRTAM': 1.0,
#  'CRY2': 1.0,
#  'CRYAA': 1.0,
#  'CRYBB3': 1.0,
#  'CRYBG1': 1.0,
#  'CRYBG3': 1.0,
#  'CRYGC': 1.0,
#  'CRYGS': 1.0,
#  'CRYZ': 1.0,
#  'CRYZL1': 1.0,
#  'CSE1L': 1.0,
#  'CSF1': 1.0,
#  'CSF1R': 1.0,
#  'CSF2': 1.0,
#  'CSF2RA': 1.0,
#  'CSF2RB': 1.0,
#  'CSF3': 1.0,
#  'CSF3R': 1.0,
#  'CSK': 1.0,
#  'CSNK1A1': 1.0,
#  ...}

# %%
import pickle

pickle.dump(gene_median, open("/scratch/project_465001820/Spatialformer/data/gene_median.pkl", "wb"))

# %% [markdown]
# #update the token file

# %%
import json

with open("/scratch/project_465001820/Spatialformer/tokenizer/tokenv4.json", "r") as f:
    tokens = json.load(f)

# %%
list(tokens.values())[-1]
# Out:
# 1949

# %%
gene_median
# Out:
# {'A2ML1': 1.0,
#  'AAMP': 1.0,
#  'AAR2': 1.0,
#  'AARSD1': 1.0,
#  'ABAT': 1.0,
#  'ABCA1': 1.0,
#  'ABCA3': 1.0,
#  'ABCA4': 1.0,
#  'ABCA7': 1.0,
#  'ABCB1': 1.0,
#  'ABCB4': 1.0,
#  'ABCB6': 1.0,
#  'ABCC1': 1.0,
#  'ABCC12': 1.0,
#  'ABCC2': 1.0,
#  'ABCC3': 1.0,
#  'ABCC4': 1.0,
#  'ABCC6': 1.0,
#  'ABCC8': 1.0,
#  'ABCC9': 1.0,
#  'ABCD1': 1.0,
#  'ABCD3': 1.0,
#  'ABCD4': 1.0,
#  'ABCF3': 1.0,
#  'ABCG1': 1.0,
#  'ABCG2': 1.0,
#  'ABHD11': 1.0,
#  'ABHD6': 1.0,
#  'ABI3': 1.0,
#  'ABI3BP': 1.0,
#  'ABL1': 1.0,
#  'ABL2': 1.0,
#  'ABO': 1.0,
#  'ABTB1': 1.0,
#  'ABTB2': 1.0,
#  'ACAA2': 1.0,
#  'ACACA': 1.0,
#  'ACACB': 1.0,
#  'ACAP1': 1.0,
#  'ACAP2': 1.0,
#  'ACAT1': 1.0,
#  'ACE': 1.0,
#  'ACE2': 1.0,
#  'ACHE': 1.0,
#  'ACKR3': 1.0,
#  'ACLY': 1.0,
#  'ACOD1': 1.0,
#  'ACP5': 1.0,
#  'ACPP': 1.0,
#  'ACRBP': 1.0,
#  'ACRV1': 1.0,
#  'ACSL4': 1.0,
#  'ACTBL2': 1.0,
#  'ACTL6A': 1.0,
#  'ACTL7A': 1.0,
#  'ACTN1': 1.0,
#  'ACTN2': 1.0,
#  'ACTN4': 1.0,
#  'ACVR1': 1.0,
#  'ACVR1B': 1.0,
#  'ACVR2A': 1.0,
#  'ACVRL1': 1.0,
#  'ACYP2': 1.0,
#  'ADA': 1.0,
#  'ADAM10': 1.0,
#  'ADAM12': 1.0,
#  'ADAM17': 1.0,
#  'ADAM28': 1.0,
#  'ADAM33': 1.0,
#  'ADAM8': 1.0,
#  'ADAM9': 1.0,
#  'ADAMDEC1': 1.0,
#  'ADAMTS1': 1.0,
#  'ADAMTS12': 1.0,
#  'ADAMTS19': 1.0,
#  'ADAMTS2': 1.0,
#  'ADAMTS4': 1.0,
#  'ADAMTS5': 1.0,
#  'ADAMTSL3': 1.0,
#  'ADAR': 1.0,
#  'ADCY2': 1.0,
#  'ADCYAP1': 1.0,
#  'ADCYAP1R1': 1.0,
#  'ADD1': 1.0,
#  'ADGRA1': 1.0,
#  'ADGRA2': 1.0,
#  'ADGRA3': 1.0,
#  'ADGRB1': 1.0,
#  'ADGRB2': 1.0,
#  'ADGRD1': 1.0,
#  'ADGRD2': 1.0,
#  'ADGRE1': 1.0,
#  'ADGRE2': 1.0,
#  'ADGRE5': 1.0,
#  'ADGRG5': 1.0,
#  'ADGRG6': 1.0,
#  'ADGRL1': 1.0,
#  'ADGRL4': 1.0,
#  'ADIPOQ': 1.0,
#  'ADIPOR1': 1.0,
#  'ADIPOR2': 1.0,
#  'ADM': 1.0,
#  'ADNP': 1.0,
#  'ADORA1': 1.0,
#  'ADORA2A': 1.0,
#  'ADORA2B': 1.0,
#  'ADORA3': 1.0,
#  'ADRA1A': 1.0,
#  'ADRA1B': 1.0,
#  'ADRA1D': 1.0,
#  'ADRA2A': 1.0,
#  'ADRA2B': 1.0,
#  'ADRA2C': 1.0,
#  'ADRB1': 1.0,
#  'ADRB2': 1.0,
#  'ADRB3': 1.0,
#  'ADTRP': 1.0,
#  'AEBP1': 1.0,
#  'AFAP1L2': 1.0,
#  'AFF1': 1.0,
#  'AFF2': 1.0,
#  'AFG1L': 1.0,
#  'AFM': 1.0,
#  'AGAP1': 1.0,
#  'AGAP3': 1.0,
#  'AGER': 1.0,
#  'AGMAT': 1.0,
#  'AGO1': 1.0,
#  'AGR3': 1.0,
#  'AGRP': 1.0,
#  'AGTR1': 1.0,
#  'AGTR2': 1.0,
#  'AGXT': 1.0,
#  'AHCY': 1.0,
#  'AHR': 1.0,
#  'AHRR': 1.0,
#  'AHSG': 1.0,
#  'AICDA': 1.0,
#  'AIF1L': 1.0,
#  'AIFM1': 1.0,
#  'AIM2': 1.0,
#  'AIMP2': 1.0,
#  'AIP': 1.0,
#  'AIRE': 1.0,
#  'AJAP1': 1.0,
#  'AKAP11': 1.0,
#  'AKAP4': 1.0,
#  'AKAP8': 1.0,
#  'AKR1B1': 1.0,
#  'AKR1C3': 1.0,
#  'AKT1': 1.0,
#  'AKT2': 1.0,
#  'AKT3': 1.0,
#  'AKTIP': 1.0,
#  'ALAD': 1.0,
#  'ALCAM': 1.0,
#  'ALDH1B1': 1.0,
#  'ALDH2': 1.0,
#  'ALDH3A2': 1.0,
#  'ALDH7A1': 1.0,
#  'ALDOA': 1.0,
#  'ALG11': 1.0,
#  'ALG13': 1.0,
#  'ALG2': 1.0,
#  'ALG6': 1.0,
#  'ALG9': 1.0,
#  'ALK': 1.0,
#  'ALKBH5': 1.0,
#  'ALOX12': 1.0,
#  'ALOX15': 1.0,
#  'ALOX5': 1.0,
#  'ALPK1': 1.0,
#  'ALPK3': 1.0,
#  'ALPL': 1.0,
#  'ALX1': 1.0,
#  'ALYREF': 1.0,
#  'AMACR': 1.0,
#  'AMER1': 1.0,
#  'AMFR': 1.0,
#  'AMH': 1.0,
#  'AMIGO1': 1.0,
#  'AMIGO3': 1.0,
#  'AMOT': 1.0,
#  'ANAPC1': 1.0,
#  'ANGPT1': 1.0,
#  'ANGPT2': 1.0,
#  'ANGPTL2': 1.0,
#  'ANGPTL3': 1.0,
#  'ANGPTL4': 1.0,
#  'ANGPTL6': 1.0,
#  'ANGPTL7': 1.0,
#  'ANGPTL8': 1.0,
#  'ANK1': 1.0,
#  'ANKHD1': 1.0,
#  'ANKK1': 1.0,
#  'ANKRD13A': 1.0,
#  'ANKRD13D': 1.0,
#  'ANKRD17': 1.0,
#  'ANKRD30A': 3.0,
#  'ANKRD40': 1.0,
#  'ANKRD44': 1.0,
#  'ANKRD6': 1.0,
#  'ANKS1A': 1.0,
#  'ANKS6': 1.0,
#  'ANKZF1': 1.0,
#  'ANO1': 1.0,
#  'ANO3': 1.0,
#  'ANP32E': 1.0,
#  'ANPEP': 2.0,
#  'ANXA10': 1.0,
#  'ANXA2': 1.0,
#  'ANXA3': 1.0,
#  'ANXA5': 1.0,
#  'ANXA8': 1.0,
#  'AOAH': 1.0,
#  'AOC3': 1.0,
#  'AOX1': 1.0,
#  'AP1B1': 1.0,
#  'AP1M1': 1.0,
#  'AP1S3': 1.0,
#  'AP2A1': 1.0,
#  'AP2A2': 1.0,
#  'AP2M1': 1.0,
#  'AP3B2': 1.0,
#  'AP3D1': 1.0,
#  'AP3M2': 1.0,
#  'AP5B1': 1.0,
#  'APAF1': 1.0,
#  'APC': 1.0,
#  'APCDD1': 1.0,
#  'APELA': 1.0,
#  'APEX1': 1.0,
#  'APEX2': 1.0,
#  'APH1B': 1.0,
#  'API5': 1.0,
#  'APLF': 1.0,
#  'APLN': 1.0,
#  'APLNR': 1.0,
#  'APMAP': 1.0,
#  'APOB': 1.0,
#  'APOBEC3B': 1.0,
#  'APOBEC3C': 1.0,
#  'APOBEC3D': 1.0,
#  'APOBEC3F': 1.0,
#  'APOBEC3G': 1.0,
#  'APOL1': 1.0,
#  'APOL2': 1.0,
#  'APOL3': 1.0,
#  'APOL6': 1.0,
#  'APOM': 1.0,
#  'APP': 1.0,
#  'APPBP2': 1.0,
#  'APTX': 1.0,
#  'AQP4': 2.0,
#  'AQP5': 1.0,
#  'AQP7': 1.0,
#  'AQP8': 3.0,
#  'AQP9': 1.0,
#  'AR': 1.0,
#  'ARC': 1.0,
#  'ARF1': 1.0,
#  'ARF6': 1.0,
#  'ARFIP1': 1.0,
#  'ARG1': 1.0,
#  'ARG2': 1.0,
#  'ARHGAP35': 1.0,
#  'ARHGAP36': 1.0,
#  'ARHGEF2': 1.0,
#  'ARHGEF7': 1.0,
#  'ARID1A': 1.0,
#  'ARID3B': 1.0,
#  'ARL4D': 1.0,
#  'ARL8B': 1.0,
#  'ARMC5': 1.0,
#  'ARMC7': 1.0,
#  'ARMH3': 1.0,
#  'ARNT': 1.0,
#  'ARNTL': 1.0,
#  'ARR3': 1.0,
#  'ARRB1': 1.0,
#  'ARRB2': 1.0,
#  'ARRDC3': 1.0,
#  'ART1': 1.0,
#  'ART3': 1.0,
#  'ART4': 1.0,
#  'ARX': 1.0,
#  'ASCC2': 1.0,
#  'ASCC3': 1.0,
#  'ASCL1': 1.0,
#  'ASCL2': 1.0,
#  'ASF1B': 1.0,
#  'ASH2L': 1.0,
#  'ASIC1': 1.0,
#  'ASPM': 1.0,
#  'ASPN': 1.0,
#  'ASTN2': 1.0,
#  'ASXL1': 1.0,
#  'ATAD3A': 1.0,
#  'ATF1': 1.0,
#  'ATF2': 1.0,
#  'ATF3': 1.0,
#  'ATF4': 1.0,
#  'ATF6': 1.0,
#  'ATG10': 1.0,
#  'ATG16L1': 1.0,
#  'ATG2A': 1.0,
#  'ATG5': 1.0,
#  'ATG7': 1.0,
#  'ATIC': 1.0,
#  'ATL1': 1.0,
#  'ATL2': 1.0,
#  'ATL3': 1.0,
#  'ATM': 1.0,
#  'ATOH1': 1.0,
#  'ATOH7': 1.0,
#  'ATOH8': 1.0,
#  'ATP10D': 1.0,
#  'ATP13A2': 1.0,
#  'ATP1A1': 1.0,
#  'ATP2A2': 1.0,
#  'ATP2B1': 1.0,
#  'ATP5F1A': 1.0,
#  'ATP5F1C': 1.0,
#  'ATP6V1B1': 1.0,
#  'ATP6V1H': 1.0,
#  'ATP7A': 1.0,
#  'ATP7B': 1.0,
#  'ATPAF1': 1.0,
#  'ATPSCKMT': 1.0,
#  'ATR': 1.0,
#  'ATRX': 1.0,
#  'ATXN1': 1.0,
#  'ATXN1L': 1.0,
#  'ATXN2': 1.0,
#  'ATXN2L': 1.0,
#  'ATXN3': 1.0,
#  'ATXN7L2': 1.0,
#  'AUNIP': 1.0,
#  'AURKA': 1.0,
#  'AURKB': 1.0,
#  'AURKC': 1.0,
#  'AVPR1A': 1.0,
#  'AVPR1B': 1.0,
#  'AVPR2': 1.0,
#  'AXIN1': 1.0,
#  'AXIN2': 1.0,
#  'AXL': 1.0,
#  'B3GAT1': 1.0,
#  'B4GAT1': 1.0,
#  'BAALC': 1.0,
#  'BAAT': 1.0,
#  'BACE1': 1.0,
#  'BACE2': 1.0,
#  'BACH2': 1.0,
#  'BAD': 1.0,
#  'BAG2': 1.0,
#  'BAG3': 1.0,
#  'BAG6': 1.0,
#  'BAIAP2': 1.0,
#  'BAK1': 1.0,
#  'BANK1': 1.0,
#  'BAP1': 1.0,
#  'BARD1': 1.0,
#  'BARHL2': 1.0,
#  'BARX2': 1.0,
#  'BATF': 1.0,
#  'BATF3': 1.0,
#  'BAX': 1.0,
#  'BAZ2B': 1.0,
#  'BBC3': 1.0,
#  'BCAM': 1.0,
#  'BCAN': 1.0,
#  'BCAR1': 1.0,
#  'BCAR3': 1.0,
#  'BCAR4': 1.0,
#  'BCAS3': 1.0,
#  'BCCIP': 1.0,
#  'BCHE': 1.0,
#  'BCKDK': 1.0,
#  'BCL10': 1.0,
#  'BCL11A': 1.0,
#  'BCL11B': 1.0,
#  'BCL2': 1.0,
#  'BCL2A1': 1.0,
#  'BCL2L1': 1.0,
#  'BCL2L11': 1.0,
#  'BCL2L12': 1.0,
#  'BCL2L13': 1.0,
#  'BCL2L2': 1.0,
#  'BCL3': 1.0,
#  'BCL6': 1.0,
#  'BCL6B': 1.0,
#  'BCL7B': 1.0,
#  'BCL7C': 1.0,
#  'BCOR': 1.0,
#  'BCORL1': 1.0,
#  'BCR': 1.0,
#  'BDKRB1': 1.0,
#  'BDKRB2': 1.0,
#  'BDNF': 1.0,
#  'BEAN1': 1.0,
#  'BECN1': 1.0,
#  'BEX2': 1.0,
#  'BFSP1': 1.0,
#  'BFSP2': 1.0,
#  'BHMT': 1.0,
#  'BICRAL': 1.0,
#  'BID': 1.0,
#  'BIK': 1.0,
#  'BIRC2': 1.0,
#  'BIRC5': 1.0,
#  'BIRC7': 1.0,
#  'BLK': 1.0,
#  'BLM': 1.0,
#  'BLNK': 1.0,
#  'BLOC1S2': 1.0,
#  'BLVRA': 1.0,
#  'BMI1': 1.0,
#  'BMP2': 1.0,
#  'BMP2K': 1.0,
#  'BMP4': 1.0,
#  'BMP5': 1.0,
#  'BMP6': 1.0,
#  'BMP7': 1.0,
#  'BMP8A': 1.0,
#  'BMP8B': 1.0,
#  'BMPER': 1.0,
#  'BMPR1A': 1.0,
#  'BMPR1B': 1.0,
#  'BMPR2': 1.0,
#  'BNC1': 1.0,
#  'BNC2': 1.0,
#  'BNIP3': 1.0,
#  'BOLL': 1.0,
#  'BRAF': 1.0,
#  'BRCA1': 1.0,
#  'BRCA2': 1.0,
#  'BRD3': 1.0,
#  'BRD4': 1.0,
#  'BRDT': 1.0,
#  'BRI3BP': 1.0,
#  'BRINP1': 1.0,
#  'BRIP1': 1.0,
#  'BRIX1': 1.0,
#  'BRSK2': 1.0,
#  'BSDC1': 1.0,
#  'BST1': 1.0,
#  'BTAF1': 1.0,
#  'BTBD9': 1.0,
#  'BTK': 1.0,
#  'BTLA': 1.0,
#  'BTN3A1': 1.0,
#  'BTNL2': 1.0,
#  'BTRC': 1.0,
#  'BUB1': 1.0,
#  'BUB1B': 1.0,
#  'BVES': 1.0,
#  'C1QBP': 1.0,
#  'C1QL3': 2.0,
#  'C1QTNF1': 1.0,
#  'C1QTNF6': 1.0,
#  'C1QTNF9': 1.0,
#  'C1RL': 1.0,
#  'C3AR1': 1.0,
#  'C4A': 1.0,
#  'C4B': 1.0,
#  'C5': 1.0,
#  'C5AR1': 1.0,
#  'C6': 1.0,
#  'C8B': 1.0,
#  'C8G': 1.0,
#  'C9': 1.0,
#  'CA10': 1.0,
#  'CA12': 1.0,
#  'CA14': 1.0,
#  'CA4': 1.0,
#  'CA9': 1.0,
#  'CABCOCO1': 1.0,
#  'CABP4': 1.0,
#  'CABYR': 1.0,
#  'CACNA1B': 1.0,
#  'CACNA1C': 1.0,
#  'CACNA1D': 1.0,
#  'CACNA1G': 1.0,
#  'CACNA1H': 1.0,
#  'CACNA2D1': 1.0,
#  'CACNG3': 1.0,
#  'CACNG4': 1.0,
#  'CACNG5': 1.0,
#  'CACUL1': 1.0,
#  'CACYBP': 1.0,
#  'CAD': 1.0,
#  'CADM3': 1.0,
#  'CADM4': 1.0,
#  'CALB1': 1.0,
#  'CALB2': 1.0,
#  'CALCA': 1.0,
#  'CALCB': 1.0,
#  'CALCR': 1.0,
#  'CALCRL': 1.0,
#  'CALM3': 1.0,
#  'CALML3': 1.0,
#  'CALR3': 1.0,
#  'CAMK1': 1.0,
#  'CAMK2A': 1.0,
#  'CAMK2B': 1.0,
#  'CAMK2D': 1.0,
#  'CAMK2G': 1.0,
#  'CAMKV': 1.0,
#  'CAMP': 1.0,
#  'CAMSAP2': 1.0,
#  'CAND1': 1.0,
#  'CANX': 1.0,
#  'CAPN1': 1.0,
#  'CAPN3': 1.0,
#  'CARD10': 1.0,
#  'CARD11': 1.0,
#  'CARD14': 1.0,
#  'CARD8': 1.0,
#  'CARD9': 1.0,
#  'CARF': 1.0,
#  'CARM1': 1.0,
#  'CARTPT': 1.0,
#  'CASC8': 1.0,
#  'CASK': 1.0,
#  'CASP1': 1.0,
#  'CASP10': 1.0,
#  'CASP2': 1.0,
#  'CASP3': 1.0,
#  'CASP6': 1.0,
#  'CASP7': 1.0,
#  'CASP8': 1.0,
#  'CASP8AP2': 1.0,
#  'CASP9': 1.0,
#  'CASQ2': 1.0,
#  'CASR': 1.0,
#  'CASS4': 1.0,
#  'CASZ1': 1.0,
#  'CAT': 1.0,
#  'CATSPER2': 1.0,
#  'CAV2': 1.0,
#  'CAVIN2': 1.0,
#  'CAVIN3': 1.0,
#  'CBARP': 1.0,
#  'CBFB': 1.0,
#  'CBL': 1.0,
#  'CBLB': 1.0,
#  'CBLIF': 1.0,
#  'CBLN1': 1.0,
#  'CBLN3': 1.0,
#  'CBLN4': 1.0,
#  'CBR1': 1.0,
#  'CBS': 1.0,
#  'CBSL': 1.0,
#  'CBWD2': 1.0,
#  'CBX1': 1.0,
#  'CBX3': 1.0,
#  'CBX5': 1.0,
#  'CBX7': 1.0,
#  'CC2D1A': 1.0,
#  'CCAR2': 1.0,
#  'CCAT2': 1.0,
#  'CCBE1': 1.0,
#  'CCDC102B': 1.0,
#  'CCDC103': 1.0,
#  'CCDC113': 1.0,
#  'CCDC124': 1.0,
#  'CCDC136': 1.0,
#  'CCDC137': 1.0,
#  'CCDC14': 1.0,
#  'CCDC141': 1.0,
#  'CCDC170': 1.0,
#  'CCDC27': 1.0,
#  'CCDC33': 1.0,
#  'CCDC43': 1.0,
#  'CCDC50': 1.0,
#  'CCDC51': 1.0,
#  'CCDC57': 1.0,
#  'CCDC6': 1.0,
#  'CCDC61': 1.0,
#  'CCDC62': 1.0,
#  'CCDC7': 1.0,
#  'CCDC77': 1.0,
#  'CCDC80': 1.0,
#  'CCDC86': 1.0,
#  'CCDC9': 1.0,
#  'CCDC91': 1.0,
#  'CCK': 3.0,
#  'CCKAR': 1.0,
#  'CCKBR': 1.0,
#  'CCL1': 1.0,
#  'CCL11': 1.0,
#  'CCL13': 1.0,
#  'CCL14': 1.0,
#  'CCL15': 1.0,
#  'CCL16': 1.0,
#  'CCL17': 1.0,
#  'CCL18': 1.0,
#  'CCL19': 1.0,
#  'CCL20': 1.0,
#  'CCL22': 1.0,
#  'CCL23': 1.0,
#  'CCL24': 1.0,
#  'CCL25': 1.0,
#  'CCL26': 1.0,
#  'CCL27': 1.0,
#  'CCL28': 1.0,
#  'CCL7': 1.0,
#  'CCL8': 1.0,
#  'CCN1': 1.0,
#  'CCN2': 1.0,
#  'CCN3': 1.0,
#  'CCN4': 1.0,
#  'CCN5': 1.0,
#  'CCNA1': 1.0,
#  'CCNA2': 1.0,
#  'CCNB1': 1.0,
#  'CCNB2': 1.0,
#  'CCNB3': 1.0,
#  'CCND1': 2.0,
#  'CCND2': 1.0,
#  'CCND3': 1.0,
#  'CCNDBP1': 1.0,
#  'CCNE1': 1.0,
#  'CCNO': 1.0,
#  'CCNT1': 1.0,
#  'CCNY': 1.0,
#  'CCR1': 1.0,
#  'CCR2': 1.0,
#  'CCR3': 1.0,
#  'CCR4': 1.0,
#  'CCR5': 1.0,
#  'CCR6': 1.0,
#  'CCR7': 1.0,
#  'CCR8': 1.0,
#  'CCR9': 1.0,
#  'CCRL2': 1.0,
#  'CCT2': 1.0,
#  'CCT3': 1.0,
#  'CCT5': 1.0,
#  'CCT6A': 1.0,
#  'CCT7': 1.0,
#  'CCT8': 1.0,
#  'CD101': 1.0,
#  'CD109': 1.0,
#  'CD14': 1.0,
#  'CD151': 1.0,
#  'CD160': 1.0,
#  'CD163': 1.0,
#  'CD177': 1.0,
#  'CD180': 1.0,
#  'CD19': 1.0,
#  'CD1A': 1.0,
#  'CD1B': 1.0,
#  'CD1C': 1.0,
#  'CD1D': 1.0,
#  'CD1E': 1.0,
#  'CD2': 1.0,
#  'CD200': 1.0,
#  'CD207': 1.0,
#  'CD209': 1.0,
#  'CD22': 1.0,
#  'CD226': 1.0,
#  'CD244': 1.0,
#  'CD247': 1.0,
#  'CD248': 1.0,
#  'CD27': 1.0,
#  'CD274': 1.0,
#  'CD276': 1.0,
#  'CD28': 1.0,
#  'CD2AP': 1.0,
#  'CD2BP2': 1.0,
#  'CD300A': 1.0,
#  'CD300C': 1.0,
#  'CD300E': 1.0,
#  'CD302': 1.0,
#  'CD320': 1.0,
#  'CD33': 1.0,
#  'CD34': 1.0,
#  'CD36': 1.0,
#  'CD38': 1.0,
#  'CD3E': 1.0,
#  'CD3EAP': 1.0,
#  'CD3G': 1.0,
#  'CD4': 1.0,
#  'CD40': 1.0,
#  'CD40LG': 1.0,
#  'CD44': 1.0,
#  'CD46': 1.0,
#  'CD47': 1.0,
#  'CD5': 1.0,
#  'CD55': 1.0,
#  'CD58': 1.0,
#  'CD59': 1.0,
#  'CD5L': 1.0,
#  'CD6': 1.0,
#  'CD68': 1.0,
#  'CD7': 1.0,
#  'CD70': 1.0,
#  'CD72': 1.0,
#  'CD79A': 2.0,
#  'CD79B': 1.0,
#  'CD80': 1.0,
#  'CD82': 1.0,
#  'CD83': 1.0,
#  'CD84': 1.0,
#  'CD86': 1.0,
#  'CD8A': 1.0,
#  'CD8B': 1.0,
#  'CD93': 1.0,
#  'CD96': 1.0,
#  'CD99': 1.0,
#  'CDA': 1.0,
#  'CDAN1': 1.0,
#  'CDC123': 1.0,
#  'CDC14A': 1.0,
#  'CDC20': 1.0,
#  'CDC25A': 1.0,
#  'CDC25C': 1.0,
#  'CDC27': 1.0,
#  'CDC34': 1.0,
#  'CDC37': 1.0,
#  'CDC42': 1.0,
#  'CDC42BPG': 1.0,
#  'CDC6': 1.0,
#  'CDC73': 1.0,
#  'CDCA2': 1.0,
#  'CDCA3': 1.0,
#  'CDCA7L': 1.0,
#  'CDCP1': 1.0,
#  'CDH1': 1.0,
#  'CDH11': 1.0,
#  'CDH13': 1.0,
#  'CDH16': 2.0,
#  'CDH2': 1.0,
#  'CDH22': 1.0,
#  'CDH23': 1.0,
#  'CDH3': 1.0,
#  'CDH5': 1.0,
#  'CDH6': 1.0,
#  'CDH7': 1.0,
#  'CDHR1': 1.0,
#  'CDHR2': 1.0,
#  'CDK1': 1.0,
#  'CDK10': 1.0,
#  'CDK14': 1.0,
#  'CDK16': 1.0,
#  'CDK17': 1.0,
#  'CDK18': 1.0,
#  'CDK2': 1.0,
#  'CDK3': 1.0,
#  'CDK4': 1.0,
#  'CDK5': 1.0,
#  'CDK5RAP1': 1.0,
#  'CDK6': 1.0,
#  'CDK7': 1.0,
#  'CDK8': 1.0,
#  'CDK9': 1.0,
#  'CDKAL1': 1.0,
#  'CDKL1': 1.0,
#  'CDKL3': 1.0,
#  'CDKN1A': 1.0,
#  'CDKN1B': 1.0,
#  'CDKN1C': 1.0,
#  'CDKN2A': 1.0,
#  'CDKN2AIP': 1.0,
#  'CDKN2B': 1.0,
#  'CDKN3': 1.0,
#  'CDR2L': 1.0,
#  'CDSN': 1.0,
#  'CDV3': 1.0,
#  'CDX1': 1.0,
#  'CDX2': 1.0,
#  'CEACAM1': 1.0,
#  'CEACAM3': 1.0,
#  'CEACAM8': 1.0,
#  'CEBPA': 1.0,
#  'CELSR1': 1.0,
#  'CELSR2': 1.0,
#  'CELSR3': 1.0,
#  'CEMIP2': 1.0,
#  'CENPA': 1.0,
#  'CENPB': 1.0,
#  'CENPF': 1.0,
#  'CENPV': 1.0,
#  'CEP112': 1.0,
#  'CEP128': 1.0,
#  'CEP170': 1.0,
#  'CEP19': 1.0,
#  'CEP44': 1.0,
#  'CEP55': 1.0,
#  'CEP85': 1.0,
#  'CES1': 1.0,
#  'CETP': 1.0,
#  'CFAP20': 1.0,
#  'CFAP43': 1.0,
#  'CFAP46': 1.0,
#  'CFAP47': 1.0,
#  'CFB': 2.0,
#  'CFC1': 1.0,
#  'CFDP1': 1.0,
#  'CFH': 1.0,
#  'CFHR1': 2.0,
#  'CFL2': 1.0,
#  'CFLAR': 1.0,
#  'CFP': 1.0,
#  'CFTR': 2.0,
#  'CGAS': 1.0,
#  'CGB3': 1.0,
#  'CGNL1': 1.0,
#  'CGRRF1': 1.0,
#  'CH25H': 1.0,
#  'CHAD': 1.0,
#  'CHAF1A': 1.0,
#  'CHAMP1': 1.0,
#  'CHD3': 1.0,
#  'CHD5': 1.0,
#  'CHD7': 1.0,
#  'CHEK1': 1.0,
#  'CHEK2': 1.0,
#  'CHFR': 1.0,
#  'CHIT1': 1.0,
#  'CHKA': 1.0,
#  'CHODL': 1.0,
#  'CHRAC1': 1.0,
#  'CHRDL2': 1.0,
#  'CHRM1': 1.0,
#  'CHRM2': 1.0,
#  'CHRM3': 1.0,
#  'CHRM4': 1.0,
#  'CHRM5': 1.0,
#  'CHRNA2': 1.0,
#  'CHRNA3': 1.0,
#  'CHRNA4': 1.0,
#  'CHRNA5': 1.0,
#  'CHRNA6': 1.0,
#  'CHRNA7': 1.0,
#  'CHRNB1': 1.0,
#  'CHRNB2': 1.0,
#  'CHRNB3': 1.0,
#  'CHRNB4': 1.0,
#  'CHST8': 1.0,
#  'CHUK': 1.0,
#  'CIDEC': 1.0,
#  'CIITA': 1.0,
#  'CILP2': 1.0,
#  'CINP': 1.0,
#  'CIP2A': 1.0,
#  'CISD2': 1.0,
#  'CKAP2': 1.0,
#  'CKAP4': 1.0,
#  'CKAP5': 1.0,
#  'CKS2': 1.0,
#  'CLCN3': 1.0,
#  'CLCN4': 1.0,
#  'CLCN5': 1.0,
#  'CLDN1': 1.0,
#  'CLDN18': 1.0,
#  'CLDN5': 1.0,
#  'CLDN7': 1.0,
#  'CLEC10A': 1.0,
#  'CLEC12A': 1.0,
#  'CLEC14A': 1.0,
#  'CLEC16A': 1.0,
#  'CLEC2A': 1.0,
#  'CLEC4A': 1.0,
#  'CLEC4C': 1.0,
#  'CLEC4D': 1.0,
#  'CLEC4M': 1.0,
#  'CLEC5A': 1.0,
#  'CLEC6A': 1.0,
#  'CLEC7A': 1.0,
#  'CLEC9A': 1.0,
#  'CLGN': 1.0,
#  'CLIC3': 1.0,
#  'CLIC4': 1.0,
#  'CLIC6': 3.0,
#  'CLK2': 1.0,
#  'CLK3': 1.0,
#  'CLK4': 1.0,
#  'CLN3': 1.0,
#  'CLN5': 1.0,
#  'CLNK': 1.0,
#  'CLOCK': 1.0,
#  'CLPTM1L': 1.0,
#  'CLPX': 1.0,
#  'CLSTN1': 1.0,
#  'CLSTN3': 1.0,
#  'CLTC': 1.0,
#  'CMA1': 1.0,
#  'CMKLR1': 1.0,
#  'CMSS1': 1.0,
#  'CMTM5': 1.0,
#  'CMTM8': 1.0,
#  'CMYA5': 1.0,
#  'CNDP1': 2.0,
#  'CNGB1': 1.0,
#  'CNGB3': 1.0,
#  'CNIH4': 1.0,
#  'CNKSR3': 1.0,
#  'CNMD': 1.0,
#  'CNNM1': 1.0,
#  'CNNM3': 1.0,
#  'CNOT1': 1.0,
#  'CNP': 1.0,
#  'CNR1': 1.0,
#  'CNR2': 1.0,
#  'CNRIP1': 1.0,
#  'CNST': 1.0,
#  'CNTF': 1.0,
#  'CNTLN': 1.0,
#  'CNTN2': 2.0,
#  'CNTN6': 1.0,
#  'CNTNAP1': 1.0,
#  'CNTNAP3': 1.0,
#  'CNTNAP4': 1.0,
#  'CNTROB': 1.0,
#  'COASY': 1.0,
#  'COBLL1': 1.0,
#  'COCH': 1.0,
#  'COIL': 1.0,
#  'COL10A1': 1.0,
#  'COL11A1': 1.0,
#  'COL17A1': 1.0,
#  'COL18A1': 1.0,
#  'COL23A1': 1.0,
#  'COL25A1': 1.0,
#  'COL2A1': 1.0,
#  'COL4A1': 1.0,
#  'COL4A2': 1.0,
#  'COL4A3': 1.0,
#  'COL4A4': 1.0,
#  'COL4A5': 1.0,
#  'COL5A1': 1.0,
#  'COL5A2': 1.0,
#  'COL7A1': 1.0,
#  'COLEC12': 1.0,
#  'COLQ': 1.0,
#  'COMP': 1.0,
#  'COMT': 1.0,
#  'COPS5': 1.0,
#  'COQ8A': 1.0,
#  'CORIN': 1.0,
#  'CORO1B': 1.0,
#  'CORO1C': 1.0,
#  'CORT': 1.0,
#  'CP': 1.0,
#  'CPA4': 1.0,
#  'CPA5': 1.0,
#  'CPA6': 1.0,
#  'CPB2': 1.0,
#  'CPEB1': 1.0,
#  'CPEB2': 1.0,
#  'CPEB3': 1.0,
#  'CPLX3': 1.0,
#  'CPNE9': 1.0,
#  'CPS1': 1.0,
#  'CPSF6': 1.0,
#  'CPT1A': 1.0,
#  'CPVL': 1.0,
#  'CPXM2': 1.0,
#  'CPZ': 1.0,
#  'CR1': 1.0,
#  'CR2': 1.0,
#  'CRB2': 1.0,
#  'CREB1': 1.0,
#  'CREB3': 1.0,
#  'CREB5': 1.0,
#  'CREBBP': 1.0,
#  'CREG1': 1.0,
#  'CREG2': 1.0,
#  'CRH': 1.0,
#  'CRHR1': 1.0,
#  'CRHR2': 1.0,
#  'CRIPT': 1.0,
#  'CRK': 1.0,
#  'CRKL': 1.0,
#  'CRNDE': 1.0,
#  'CRNN': 1.0,
#  'CRTAC1': 1.0,
#  'CRTAM': 1.0,
#  'CRY2': 1.0,
#  'CRYAA': 1.0,
#  'CRYBB3': 1.0,
#  'CRYBG1': 1.0,
#  'CRYBG3': 1.0,
#  'CRYGC': 1.0,
#  'CRYGS': 1.0,
#  'CRYZ': 1.0,
#  'CRYZL1': 1.0,
#  'CSE1L': 1.0,
#  'CSF1': 1.0,
#  'CSF1R': 1.0,
#  'CSF2': 1.0,
#  'CSF2RA': 1.0,
#  'CSF2RB': 1.0,
#  'CSF3': 1.0,
#  'CSF3R': 1.0,
#  'CSK': 1.0,
#  'CSNK1A1': 1.0,
#  ...}

# %%
add_genes = [
    gene for gene in gene_median.keys() 
    if gene not in tokens and not gene.startswith("Human")
]

# %%
add_genes
# Out:
# ['A2ML1',
#  'AAMP',
#  'AAR2',
#  'AARSD1',
#  'ABAT',
#  'ABCA1',
#  'ABCA3',
#  'ABCA4',
#  'ABCA7',
#  'ABCB1',
#  'ABCB4',
#  'ABCB6',
#  'ABCC1',
#  'ABCC12',
#  'ABCC3',
#  'ABCC4',
#  'ABCC6',
#  'ABCD1',
#  'ABCD3',
#  'ABCD4',
#  'ABCF3',
#  'ABCG1',
#  'ABCG2',
#  'ABHD11',
#  'ABHD6',
#  'ABI3',
#  'ABI3BP',
#  'ABL1',
#  'ABL2',
#  'ABO',
#  'ABTB1',
#  'ABTB2',
#  'ACAA2',
#  'ACACA',
#  'ACAP1',
#  'ACAP2',
#  'ACAT1',
#  'ACKR3',
#  'ACLY',
#  'ACOD1',
#  'ACP5',
#  'ACPP',
#  'ACRBP',
#  'ACRV1',
#  'ACSL4',
#  'ACTBL2',
#  'ACTL6A',
#  'ACTL7A',
#  'ACTN2',
#  'ACTN4',
#  'ACVR1',
#  'ACVR1B',
#  'ACVR2A',
#  'ACVRL1',
#  'ACYP2',
#  'ADA',
#  'ADAM10',
#  'ADAM33',
#  'ADAM8',
#  'ADAMDEC1',
#  'ADAMTS19',
#  'ADAMTS2',
#  'ADAMTS4',
#  'ADAMTS5',
#  'ADAMTSL3',
#  'ADAR',
#  'ADCY2',
#  'ADCYAP1',
#  'ADCYAP1R1',
#  'ADD1',
#  'ADGRA1',
#  'ADGRA2',
#  'ADGRA3',
#  'ADGRB1',
#  'ADGRB2',
#  'ADGRD1',
#  'ADGRD2',
#  'ADGRE2',
#  'ADGRG5',
#  'ADGRG6',
#  'ADGRL1',
#  'ADIPOR1',
#  'ADIPOR2',
#  'ADM',
#  'ADNP',
#  'ADORA1',
#  'ADORA2A',
#  'ADORA2B',
#  'ADORA3',
#  'ADRA1D',
#  'ADRA2B',
#  'ADRA2C',
#  'ADRB1',
#  'ADRB2',
#  'ADRB3',
#  'ADTRP',
#  'AFF1',
#  'AFF2',
#  'AFG1L',
#  'AFM',
#  'AGAP1',
#  'AGAP3',
#  'AGMAT',
#  'AGO1',
#  'AGRP',
#  'AGTR2',
#  'AGXT',
#  'AHCY',
#  'AHR',
#  'AHRR',
#  'AHSG',
#  'AICDA',
#  'AIF1L',
#  'AIFM1',
#  'AIMP2',
#  'AIP',
#  'AJAP1',
#  'AKAP11',
#  'AKAP4',
#  'AKAP8',
#  'AKR1B1',
#  'AKT2',
#  'AKT3',
#  'AKTIP',
#  'ALAD',
#  'ALCAM',
#  'ALDH2',
#  'ALDH3A2',
#  'ALDH7A1',
#  'ALDOA',
#  'ALG11',
#  'ALG13',
#  'ALG2',
#  'ALG6',
#  'ALG9',
#  'ALKBH5',
#  'ALOX12',
#  'ALOX15',
#  'ALPK1',
#  'ALPK3',
#  'ALX1',
#  'ALYREF',
#  'AMACR',
#  'AMER1',
#  'AMFR',
#  'AMH',
#  'AMIGO1',
#  'AMIGO3',
#  'AMOT',
#  'ANAPC1',
#  'ANGPTL2',
#  'ANGPTL3',
#  'ANGPTL4',
#  'ANGPTL6',
#  'ANGPTL7',
#  'ANGPTL8',
#  'ANKHD1',
#  'ANKK1',
#  'ANKRD13A',
#  'ANKRD13D',
#  'ANKRD17',
#  'ANKRD40',
#  'ANKRD44',
#  'ANKRD6',
#  'ANKS1A',
#  'ANKS6',
#  'ANKZF1',
#  'ANO1',
#  'ANP32E',
#  'ANXA10',
#  'ANXA2',
#  'ANXA5',
#  'ANXA8',
#  'AOAH',
#  'AOC3',
#  'AOX1',
#  'AP1B1',
#  'AP1M1',
#  'AP1S3',
#  'AP2A1',
#  'AP2A2',
#  'AP2M1',
#  'AP3B2',
#  'AP3D1',
#  'AP3M2',
#  'AP5B1',
#  'APAF1',
#  'APELA',
#  'APEX1',
#  'APEX2',
#  'APH1B',
#  'API5',
#  'APLF',
#  'APMAP',
#  'APOBEC3C',
#  'APOBEC3D',
#  'APOBEC3F',
#  'APOBEC3G',
#  'APOL1',
#  'APOL2',
#  'APOL3',
#  'APOL6',
#  'APOM',
#  'APPBP2',
#  'APTX',
#  'AQP5',
#  'AQP7',
#  'ARC',
#  'ARF6',
#  'ARFIP1',
#  'ARG2',
#  'ARHGAP35',
#  'ARHGAP36',
#  'ARHGEF2',
#  'ARHGEF7',
#  'ARID3B',
#  'ARL4D',
#  'ARL8B',
#  'ARMC5',
#  'ARMC7',
#  'ARMH3',
#  'ARNT',
#  'ARNTL',
#  'ARR3',
#  'ARRB1',
#  'ARRB2',
#  'ARRDC3',
#  'ART1',
#  'ART3',
#  'ASCC2',
#  'ASCC3',
#  'ASF1B',
#  'ASH2L',
#  'ASIC1',
#  'ASPM',
#  'ASTN2',
#  'ASXL1',
#  'ATAD3A',
#  'ATF1',
#  'ATF2',
#  'ATG10',
#  'ATG16L1',
#  'ATG2A',
#  'ATG5',
#  'ATIC',
#  'ATL1',
#  'ATL2',
#  'ATL3',
#  'ATOH7',
#  'ATOH8',
#  'ATP10D',
#  'ATP13A2',
#  'ATP1A1',
#  'ATP2A2',
#  'ATP2B1',
#  'ATP5F1A',
#  'ATP5F1C',
#  'ATP6V1B1',
#  'ATP6V1H',
#  'ATP7A',
#  'ATP7B',
#  'ATPAF1',
#  'ATPSCKMT',
#  'ATR',
#  'ATRX',
#  'ATXN1',
#  'ATXN1L',
#  'ATXN2',
#  'ATXN2L',
#  'ATXN3',
#  'ATXN7L2',
#  'AUNIP',
#  'AURKA',
#  'AURKB',
#  'AURKC',
#  'AVPR1B',
#  'AVPR2',
#  'AXIN1',
#  'B3GAT1',
#  'B4GAT1',
#  'BAAT',
#  'BACH2',
#  'BAD',
#  'BAG2',
#  'BAG3',
#  'BAG6',
#  'BAIAP2',
#  'BAK1',
#  'BAP1',
#  'BARD1',
#  'BARHL2',
#  'BARX2',
#  'BAZ2B',
#  'BBC3',
#  'BCAM',
#  'BCAR1',
#  'BCAR3',
#  'BCAR4',
#  'BCAS3',
#  'BCCIP',
#  'BCHE',
#  'BCKDK',
#  'BCL10',
#  'BCL11A',
#  'BCL11B',
#  'BCL2L12',
#  'BCL2L13',
#  'BCL2L2',
#  'BCL3',
#  'BCL6',
#  'BCL6B',
#  'BCL7B',
#  'BCL7C',
#  'BCOR',
#  'BCORL1',
#  'BCR',
#  'BDKRB1',
#  'BDKRB2',
#  'BDNF',
#  'BEAN1',
#  'BECN1',
#  'BEX2',
#  'BFSP1',
#  'BFSP2',
#  'BHMT',
#  'BICRAL',
#  'BID',
#  'BIK',
#  'BIRC2',
#  'BIRC7',
#  'BLM',
#  'BLNK',
#  'BLOC1S2',
#  'BLVRA',
#  'BMI1',
#  'BMP2K',
#  'BMP6',
#  'BMP7',
#  'BMP8A',
#  'BMP8B',
#  'BMPER',
#  'BMPR1A',
#  'BMPR1B',
#  'BNC1',
#  'BNC2',
#  'BNIP3',
#  'BOLL',
#  'BRCA1',
#  'BRD3',
#  'BRD4',
#  'BRDT',
#  'BRI3BP',
#  'BRINP1',
#  'BRIP1',
#  'BRIX1',
#  'BRSK2',
#  'BSDC1',
#  'BST1',
#  'BTAF1',
#  'BTBD9',
#  'BTK',
#  'BTLA',
#  'BTN3A1',
#  'BTNL2',
#  'BTRC',
#  'BUB1B',
#  'BVES',
#  'C1QTNF1',
#  'C1QTNF6',
#  'C1QTNF9',
#  'C1RL',
#  'C4A',
#  'C4B',
#  'C5',
#  'C6',
#  'C8B',
#  'C8G',
#  'C9',
#  'CA10',
#  'CA12',
#  'CA14',
#  'CA9',
#  'CABCOCO1',
#  'CABP4',
#  'CABYR',
#  'CACNA1B',
#  'CACNA1C',
#  'CACNA1D',
#  'CACNA1G',
#  'CACNA1H',
#  'CACNA2D1',
#  'CACNG3',
#  'CACNG5',
#  'CACUL1',
#  'CACYBP',
#  'CAD',
#  'CADM3',
#  'CADM4',
#  'CALB1',
#  'CALCB',
#  'CALCR',
#  'CALM3',
#  'CALML3',
#  'CALR3',
#  'CAMK1',
#  'CAMK2A',
#  'CAMK2B',
#  'CAMK2D',
#  'CAMK2G',
#  'CAMKV',
#  'CAMP',
#  'CAMSAP2',
#  'CAND1',
#  'CANX',
#  'CAPN1',
#  'CARD10',
#  'CARD11',
#  'CARD14',
#  'CARD8',
#  'CARD9',
#  'CARF',
#  'CARM1',
#  'CARTPT',
#  'CASC8',
#  'CASK',
#  'CASP1',
#  'CASP10',
#  'CASP2',
#  'CASP3',
#  'CASP6',
#  'CASP7',
#  'CASP8',
#  'CASP8AP2',
#  'CASP9',
#  'CASQ2',
#  'CASR',
#  'CASS4',
#  'CASZ1',
#  'CAT',
#  'CATSPER2',
#  'CAV2',
#  'CAVIN3',
#  'CBARP',
#  'CBFB',
#  'CBL',
#  'CBLB',
#  'CBLIF',
#  'CBLN1',
#  'CBLN3',
#  'CBLN4',
#  'CBR1',
#  'CBS',
#  'CBSL',
#  'CBWD2',
#  'CBX1',
#  'CBX3',
#  'CBX5',
#  'CBX7',
#  'CC2D1A',
#  'CCAR2',
#  'CCAT2',
#  'CCBE1',
#  'CCDC102B',
#  'CCDC103',
#  'CCDC113',
#  'CCDC124',
#  'CCDC136',
#  'CCDC137',
#  'CCDC14',
#  'CCDC141',
#  'CCDC170',
#  'CCDC27',
#  'CCDC33',
#  'CCDC43',
#  'CCDC50',
#  'CCDC51',
#  'CCDC57',
#  'CCDC61',
#  'CCDC62',
#  'CCDC7',
#  'CCDC77',
#  'CCDC86',
#  'CCDC9',
#  'CCDC91',
#  'CCKAR',
#  'CCKBR',
#  'CCL1',
#  'CCL17',
#  'CCL23',
#  'CCL24',
#  'CCL25',
#  'CCN1',
#  'CCN3',
#  'CCN4',
#  'CCN5',
#  'CCNA2',
#  'CCNB1',
#  'CCNB3',
#  'CCND2',
#  'CCNDBP1',
#  'CCNE1',
#  'CCNO',
#  'CCNT1',
#  'CCNY',
#  'CCR8',
#  'CCR9',
#  'CCRL2',
#  'CCT2',
#  'CCT3',
#  'CCT5',
#  'CCT6A',
#  'CCT7',
#  'CCT8',
#  'CD101',
#  'CD109',
#  'CD151',
#  'CD160',
#  'CD180',
#  'CD1D',
#  'CD200',
#  'CD209',
#  'CD22',
#  'CD226',
#  'CD244',
#  'CD248',
#  'CD2AP',
#  'CD2BP2',
#  'CD300A',
#  'CD300C',
#  'CD302',
#  'CD320',
#  'CD33',
#  'CD3EAP',
#  'CD46',
#  'CD55',
#  'CD58',
#  'CD59',
#  'CD72',
#  'CD82',
#  'CD84',
#  'CD99',
#  'CDA',
#  'CDAN1',
#  'CDC123',
#  'CDC14A',
#  'CDC25A',
#  'CDC25C',
#  'CDC27',
#  'CDC34',
#  'CDC37',
#  'CDC42',
#  'CDC42BPG',
#  'CDC6',
#  'CDC73',
#  'CDCA2',
#  'CDCA3',
#  'CDCA7L',
#  'CDCP1',
#  'CDH13',
#  'CDH22',
#  'CDH23',
#  'CDH3',
#  'CDH7',
#  'CDHR1',
#  'CDHR2',
#  'CDK10',
#  'CDK14',
#  'CDK16',
#  'CDK17',
#  'CDK18',
#  'CDK3',
#  'CDK5',
#  'CDK5RAP1',
#  'CDK7',
#  'CDK8',
#  'CDK9',
#  'CDKAL1',
#  'CDKL1',
#  'CDKL3',
#  'CDKN2AIP',
#  'CDKN3',
#  'CDR2L',
#  'CDSN',
#  'CDV3',
#  'CEACAM3',
#  'CEBPA',
#  'CELSR1',
#  'CELSR2',
#  'CELSR3',
#  'CENPA',
#  'CENPB',
#  'CEP112',
#  'CEP128',
#  'CEP170',
#  'CEP19',
#  'CEP44',
#  'CEP55',
#  'CEP85',
#  'CETP',
#  'CFAP20',
#  'CFAP43',
#  'CFAP46',
#  'CFAP47',
#  'CFDP1',
#  'CFH',
#  'CFL2',
#  'CFLAR',
#  'CFP',
#  'CGAS',
#  'CGB3',
#  'CGNL1',
#  'CGRRF1',
#  'CHAF1A',
#  'CHAMP1',
#  'CHD3',
#  'CHD5',
#  'CHD7',
#  'CHEK1',
#  'CHEK2',
#  'CHFR',
#  'CHKA',
#  'CHRAC1',
#  'CHRDL2',
#  'CHRM1',
#  'CHRM2',
#  'CHRM4',
#  'CHRM5',
#  'CHRNA2',
#  'CHRNA3',
#  'CHRNA4',
#  'CHRNA5',
#  'CHRNA6',
#  'CHRNA7',
#  'CHRNB1',
#  'CHRNB2',
#  'CHRNB3',
#  'CHRNB4',
#  'CHST8',
#  'CHUK',
#  'CIDEC',
#  'CIITA',
#  'CILP2',
#  'CINP',
#  'CIP2A',
#  'CISD2',
#  'CKAP2',
#  'CKAP5',
#  'CKS2',
#  'CLCN3',
#  'CLCN4',
#  'CLCN5',
#  'CLDN18',
#  'CLDN7',
#  'CLEC16A',
#  'CLEC2A',
#  'CLEC4A',
#  'CLEC4C',
#  'CLEC4D',
#  'CLEC4M',
#  'CLEC5A',
#  'CLEC6A',
#  'CLEC7A',
#  'CLGN',
#  'CLIC3',
#  'CLIC4',
#  'CLK2',
#  'CLK3',
#  'CLK4',
#  'CLN3',
#  'CLN5',
#  'CLNK',
#  'CLOCK',
#  'CLPTM1L',
#  'CLPX',
#  'CLSTN1',
#  'CLSTN3',
#  'CLTC',
#  'CMSS1',
#  'CMTM5',
#  'CMTM8',
#  'CMYA5',
#  'CNGB1',
#  'CNGB3',
#  'CNIH4',
#  'CNKSR3',
#  'CNNM1',
#  'CNNM3',
#  'CNOT1',
#  'CNP',
#  'CNR1',
#  'CNR2',
#  'CNRIP1',
#  'CNST',
#  'CNTF',
#  'CNTLN',
#  'CNTN6',
#  'CNTNAP1',
#  'CNTNAP4',
#  'CNTROB',
#  'COASY',
#  'COBLL1',
#  'COIL',
#  'COL18A1',
#  'COL23A1',
#  'COL4A1',
#  'COL4A2',
#  'COL4A4',
#  'COL4A5',
#  'COL5A1',
#  'COL7A1',
#  'COLEC12',
#  'COLQ',
#  'COMT',
#  'COPS5',
#  'COQ8A',
#  'CORIN',
#  'CORO1B',
#  'CORO1C',
#  'CORT',
#  'CPA4',
#  'CPA5',
#  'CPA6',
#  'CPB2',
#  'CPEB1',
#  'CPEB2',
#  'CPEB3',
#  'CPLX3',
#  'CPNE9',
#  'CPS1',
#  'CPSF6',
#  'CPT1A',
#  'CPXM2',
#  'CPZ',
#  'CR1',
#  'CRB2',
#  'CREB1',
#  'CREB3',
#  'CREB5',
#  'CREBBP',
#  'CREG1',
#  'CREG2',
#  'CRH',
#  'CRHR1',
#  'CRHR2',
#  'CRIPT',
#  'CRK',
#  'CRKL',
#  'CRNDE',
#  'CRNN',
#  'CRTAC1',
#  'CRTAM',
#  'CRY2',
#  'CRYAA',
#  'CRYBB3',
#  'CRYBG1',
#  'CRYBG3',
#  'CRYGC',
#  'CRYGS',
#  'CRYZ',
#  'CRYZL1',
#  'CSE1L',
#  'CSF2',
#  'CSF2RB',
#  'CSF3R',
#  'CSK',
#  'CSNK1A1',
#  'CSNK1A1L',
#  'CSNK1E',
#  'CSNK1G1',
#  'CSNK2A1',
#  'CSNK2A2',
#  'CSNK2B',
#  'CSPP1',
#  'CSRP1',
#  'CSRP3',
#  'CST2',
#  'CST4',
#  'CST5',
#  'CTAG1B',
#  'CTBP1',
#  'CTBP2',
#  'CTCF',
#  'CTCFL',
#  'CTDSPL',
#  'CTNNA1',
#  'CTNNAL1',
#  'CTNND1',
#  'CTNND2',
#  'CTRL',
#  'CTSC',
#  'CTTNBP2NL',
#  'CTXN3',
#  'CUBN',
#  'CUEDC2',
#  'CUL1',
#  'CUL2',
#  'CUL3',
#  'CUL4A',
#  'CUL4B',
#  'CUL5',
#  'CUTA',
#  'CUZD1',
#  'CX3CL1',
#  'CYBA',
#  'CYBC1',
#  'CYCS',
#  'CYFIP2',
#  'CYHR1',
#  'CYLD',
#  'CYP11A1',
#  'CYP11B2',
#  'CYP17A1',
#  'CYP19A1',
#  'CYP1A2',
#  'CYP20A1',
#  'CYP24A1',
#  'CYP27A1',
#  'CYP27B1',
#  'CYP2A6',
#  'CYP2C19',
#  'CYP2C8',
#  'CYP2C9',
#  'CYP2D6',
#  'CYP2J2',
#  'CYP3A5',
#  'CYP46A1',
#  'CYP4F2',
#  'CYP7A1',
#  'CYREN',
#  'CYSLTR1',
#  'CYSLTR2',
#  'CYTH2',
#  'CYTOR',
#  'DAB1',
#  'DAB2',
#  'DACH1',
#  'DACH2',
#  'DACT2',
#  'DAG1',
#  'DAO',
#  'DAOA',
#  'DAP',
#  'DAP3',
#  'DAPK1',
#  'DAXX',
#  'DAZAP1',
#  'DAZAP2',
#  'DAZL',
#  'DBN1',
#  'DBR1',
#  'DCAF1',
#  'DCDC1',
#  'DCTN1',
#  'DCX',
#  'DDB1',
#  'DDB2',
#  'DDC',
#  'DDI2',
#  'DDIT4L',
#  'DDR1',
#  'DDX1',
#  'DDX10',
#  'DDX19A',
#  'DDX20',
#  'DDX21',
#  'DDX25',
#  'DDX27',
#  'DDX28',
#  'DDX31',
#  'DDX39B',
#  'DDX3X',
#  'DDX3Y',
#  'DDX43',
#  'DDX50',
#  'DDX51',
#  'DDX53',
#  'DDX55',
#  'DDX58',
#  'DDX6',
#  'DEFA1',
#  'DEFA6',
#  'DEFB103B',
#  'DEFB4A',
#  'DEK',
#  'DEPDC7',
#  'DEPTOR',
#  'DGAT1',
#  'DHCR24',
#  'DHCR7',
#  'DHDDS',
#  'DHODH',
#  'DHRS1',
#  'DHX29',
#  'DHX30',
#  'DHX34',
#  'DHX57',
#  'DHX9',
#  'DIABLO',
#  'DICER1',
#  'DIP2A',
#  'DIP2B',
#  'DIS3',
#  'DIS3L2',
#  'DISC1',
#  'DISP1',
#  'DKC1',
#  'DLD',
#  'DLEC1',
#  'DLEU1',
#  'DLEU2',
#  'DLG1',
#  'DLG4',
#  'DLK2',
#  'DLL1',
#  'DLL3',
#  'DLL4',
#  'DLX4',
#  'DMBX1',
#  'DMD',
#  'DMPK',
#  'DMRT2',
#  'DMWD',
#  'DMXL1',
#  'DMXL2',
#  'DNAH1',
#  'DNAH10',
#  'DNAH11',
#  'DNAH12',
#  'DNAH14',
#  'DNAH2',
#  'DNAH5',
#  'DNAH7',
#  'DNAH8',
#  'DNAH9',
#  'DNAI1',
#  'DNAJA1',
#  'DNAJA3',
#  'DNAJB12',
#  'DNAJB2',
#  'DNAJB4',
#  'DNAJB5',
#  'DNAJC10',
#  'DNAJC17',
#  'DNAJC9',
#  'DNM1',
#  'DNM2',
#  'DNMT1',
#  'DNMT3A',
#  'DNMT3B',
#  'DNPEP',
#  'DNTT',
#  'DOC2A',
#  'DOCK9',
#  'DOK5',
#  'DOK7',
#  'DOT1L',
#  'DPAGT1',
#  'DPF2',
#  'DPF3',
#  'DPM1',
#  'DPP4',
#  'DPP8',
#  'DPPA2',
#  'DPY19L2',
#  'DPYD',
#  'DPYSL2',
#  'DRAM1',
#  'DRC1',
#  'DRC3',
#  'DRD1',
#  'DRD2',
#  'DRD3',
#  'DRD5',
#  'DRG1',
#  'DSG1',
#  'DSG2',
#  'DSG3',
#  'DTNA',
#  'DTNBP1',
#  'DTX1',
#  'DUOXA1',
#  'DUOXA2',
#  'DUSP13',
#  'DUSP23',
#  'DUSP28',
#  'DUSP6',
#  'DUX4',
#  'DVL1',
#  'DVL2',
#  'DVL3',
#  'DYDC1',
#  'DYNC1H1',
#  'DYRK1A',
#  'DYRK1B',
#  'DZIP1L',
#  'E2F3',
#  'E2F4',
#  'E4F1',
#  'EBF1',
#  'EBF2',
#  ...]

# %%
len(add_genes)
# Out:
# 4115

# %%
last_token + len(add_genes)
# Out:
# 6064

# %%
last_token = list(tokens.values())[-1]

# %%
add_dict = dict(zip(add_genes, range(last_token+1, last_token + len(add_genes)+1)))
final_dict = {**tokens,**add_dict}

# %%
 len([i for i in range(last_token+1, last_token + len(add_genes) +1)])
# Out:
# 4115

# %% [markdown]
# save it!

# %%
with open("/scratch/project_465001820/Spatialformer/tokenizer/tokenv5.json", "w") as f2:
    
    json.dump(final_dict, f2, indent=5)

# %%
list(gene_median.keys())[-10:]
# Out:
# ['IGFBP6',
#  'IQCJ',
#  'ISLR',
#  'LRRC31',
#  'NXPH1',
#  'SNX20',
#  'SRGN',
#  'TAPBP',
#  'CD45RA',
#  'CD45RO']

# %%
len(add_genes)
# Out:
# 4126

# %%
"RGS8" in add_genes
# Out:
# True
