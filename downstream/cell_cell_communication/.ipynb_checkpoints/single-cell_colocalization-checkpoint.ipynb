# %% [markdown]
# # Lung single-cell RNA seq data
# Objective:
# - We want to verify whether our model can find the cell-cell contact between SMG serous and B Plasma lgA.

# %%
import scanpy as sc
import pandas as pd
import scipy.io
from scipy.sparse import csr_matrix

# %% [markdown]
# Loading the single-cell pulmonary fabrosis samples

# %%
mtx_path = "/scratch/project_465001027/Spatialformer/downstream/cell_cell_communication/data/GSE136831_RawCounts_Sparse.mtx.gz"
meta_path = "/scratch/project_465001027/Spatialformer/downstream/cell_cell_communication/data/GSE136831_AllCells.Samples.CellType.MetadataTable.txt.gz"
geneid_path = "/scratch/project_465001027/Spatialformer/downstream/cell_cell_communication/data/GSE136831_AllCells.GeneIDs.txt.gz"
# Load the sparse matrix from the .mtx file
mtx_data = scipy.io.mmread(mtx_path).tocsr()
mtx_data = mtx_data.transpose()
# Load metadata (cell annotations)
meta_data = pd.read_csv(meta_path, sep="\t", index_col=0)

# Load gene identifiers
gene_ids = pd.read_csv(geneid_path, sep="\t", header=0)

# Verify the data shapes
print("Matrix shape:", mtx_data.shape)
print("Metadata shape:", meta_data.shape)
print("Gene IDs:", len(gene_ids))

# Create AnnData object
adata = sc.AnnData(X=mtx_data)

# Set the cell metadata
adata.obs = meta_data

# Set the gene identifiers
adata.var = gene_ids

# Display the AnnData object
print(adata)
# Out:
# Matrix shape: (312928, 45947)
# Metadata shape: (312928, 8)
# Gene IDs: 45947
# AnnData object with n_obs × n_vars = 312928 × 45947
#     obs: 'nUMI', 'nGene', 'CellType_Category', 'Manuscript_Identity', 'Subclass_Cell_Identity', 'Disease_Identity', 'Subject_Identity', 'Library_Identity'
#     var: 'Ensembl_GeneID', 'HGNC_EnsemblAlt_GeneID'

# %%
#select the specific cell types in single-cell dataset
adata.obs["Manuscript_Identity"].unique()
# Out:
# array(['ncMonocyte', 'Macrophage_Alveolar', 'NK', 'cMonocyte',
#        'Lymphatic', 'Macrophage', 'Fibroblast', 'Basal', 'Myofibroblast',
#        'Multiplet', 'cDC2', 'B', 'VE_Venous', 'T', 'ATII', 'ATI',
#        'VE_Capillary_A', 'VE_Arterial', 'Ciliated', 'Club',
#        'VE_Capillary_B', 'B_Plasma', 'ILC_A', 'T_Cytotoxic', 'Goblet',
#        'T_Regulatory', 'Mesothelial', 'ILC_B', 'SMC', 'cDC1',
#        'DC_Langerhans', 'Mast', 'pDC', 'DC_Mature', 'VE_Peribronchial',
#        'Pericyte', 'Aberrant_Basaloid', 'Ionocyte', 'PNEC'], dtype=object)

# %% [markdown]
# Only selecting the overlapping cell types

# %%
import numpy as np
def sample_fraction(adata, cell_type_column, frac=0.1):
    df = adata.obs.copy()
    df['sample_index'] = np.arange(len(df))
    sampled_indices = (df.groupby(cell_type_column)
                         .apply(lambda x: x.sample(frac=frac))
                         .reset_index(drop=True)['sample_index'])
    return adata[sampled_indices]

# %%
ovlp_ct = ["ATI", "ATII", "Basal", "Ciliated", "NK", "Lymphatic", "Macrophage", "Fibroblast", "B",
          "T", "Mesothelial", "Mast", "pDC", "SMC"]

# %%
from scipy.sparse import csr_matrix
#rename the gene columns
adata.var['gene_name'] = adata.var['HGNC_EnsemblAlt_GeneID'].astype(str)

#to csr matrix
adata.X = csr_matrix(adata.X)
#selecting the cell types and getting the certain fraction of cell types
adata_subset = adata[adata.obs["Manuscript_Identity"].isin(ovlp_ct)]

# Sample 10% from each cell type in the filtered AnnData object
adata_subset_10fra = sample_fraction(adata_subset, "Manuscript_Identity", 0.003)

# %%
adata_subset.X
# Out:
# <168705x45947 sparse matrix of type '<class 'numpy.int64'>'
# 	with 357777864 stored elements in Compressed Sparse Row format>

# %%
adata_subset_10fra
# Out:
# View of AnnData object with n_obs × n_vars = 506 × 45947
#     obs: 'nUMI', 'nGene', 'CellType_Category', 'Manuscript_Identity', 'Subclass_Cell_Identity', 'Disease_Identity', 'Subject_Identity', 'Library_Identity'
#     var: 'Ensembl_GeneID', 'HGNC_EnsemblAlt_GeneID', 'gene_name'

# %% [markdown]
# Saving the anndata

# %%
selected_cells = adata_subset_10fra.obs.index

# %%
# adata_subset_10fra.var['gene_name'] = adata_subset_10fra.var['gene_name'].astype(str)
adata_subset_10fra.write("/scratch/project_465001027/Spatialformer/spatialformer/tools/test.h5ad")
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/anndata/_core/anndata.py:1230: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# ... storing 'CellType_Category' as categorical
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/anndata/_core/anndata.py:1230: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# ... storing 'Manuscript_Identity' as categorical
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/anndata/_core/anndata.py:1230: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# ... storing 'Subclass_Cell_Identity' as categorical
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/anndata/_core/anndata.py:1230: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# ... storing 'Disease_Identity' as categorical
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/anndata/_core/anndata.py:1230: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# ... storing 'Subject_Identity' as categorical
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/anndata/_core/anndata.py:1230: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# ... storing 'Library_Identity' as categorical

# %% [markdown]
# loading the anndata

# %%
adata_subset_10fra = sc.read("/scratch/project_465001027/Spatialformer/spatialformer/tools/test.h5ad")

# %%
adata_subset_10fra
# Out:
# AnnData object with n_obs × n_vars = 506 × 45947
#     obs: 'nUMI', 'nGene', 'CellType_Category', 'Manuscript_Identity', 'Subclass_Cell_Identity', 'Disease_Identity', 'Subject_Identity', 'Library_Identity'
#     var: 'Ensembl_GeneID', 'HGNC_EnsemblAlt_GeneID', 'gene_name'

# %%
from tqdm import tqdm
import sys
sys.path.append("/scratch/project_465001027/Spatialformer")
sys.path.append("/scratch/project_465001027/Spatialformer/scripts")
from train import manual_train_fm
import scanpy as sc
import spatialformer as sp
import importlib
importlib.reload(sp)
# Out:
# <module 'spatialformer' from '/scratch/project_465001027/Spatialformer/spatialformer/__init__.py'>

# %%
# %%time

# If you want to reload only the `spatialformer` package
importlib.reload(sp)
batch_size = 16
tissue = "Lung"
condition = "Disease"
# model_ckp_path = "/scratch/project_465001027/Spatialformer/output/checkpoints/step=0096000-train_total_loss=-2.9351-val_total_loss=0.0000.ckpt"
model_ckp_path = "/scratch/project_465001027/Spatialformer/output/checkpoints/step=0100000-train_total_loss=-2.2727-val_total_loss=0.0000.ckpt"
method = "cls" #getting the cls token embeddings

pred = np.zeros((len(selected_cells), len(selected_cells), 2))

for i, query in enumerate(selected_cells):
    key_cells = selected_cells
    querys = len(selected_cells)*[query]
    
    _,paired = sp.tl.embed_data(adata_subset_10fra, 
                                  tissue,
                                  condition,
                                   method,
                                model_ckp_path, 
                                batch_size,
                                mode = "pair",
                                threshold = 0.7,
                                num_workers = 8,
                                left_cell = querys,
                                right_cell = key_cells
                               )
    all_paired = np.vstack(paired)
    pred[i] = all_paired
np.save("/scratch/project_465001027/Spatialformer/downstream/cell_cell_communication/data/pred.npy", pred)
# Out:
# Spatialformer - INFO - Loading the SpatialFormer model...
# [rank: 0] Global seed set to 42
# require grad: True
# Spatialformer - INFO - Setting the model to the evaluation mode...
# Spatialformer - INFO - The model is mapped into cuda
# Spatialformer - INFO - Encoding the data into the batch...
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:15
#
# File /scratch/project_465001027/Spatialformer/spatialformer/tools/get_embeddings.py:89, in embed_data(adata, tissue, condition, method, model_ckp_path, batch_size, config_path, token_path, mode, threshold, left_cell, right_cell, num_workers)
#      87 all_prob = []
#      88 with torch.no_grad():
# ---> 89     for i, batch in tqdm(enumerate(dataloader)):
#      90
#      91         #getting the last layer
#      92         last_hidden_repr, probabilities = model.get_embeddings(batch, [-1], True, False)
#      93         cls_embeddings = last_hidden_repr[0][:,0]
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File /scratch/project_465001027/Spatialformer/spatialformer/tools/get_embeddings.py:385, in collate_fn(batch)
#     383 exclude_cls = prefix_tokens[1:]
#     384 padded_indice = prefix_tokens + token1 + end_tokens + exclude_cls + end_tokens
# --> 385 pad_size = 500 - padded_indice
#     386 attention_mask = [1]*len(padded_indice) + [0]*pad_size
#     387 padded_indice += [0] * pad_size
#
# TypeError: unsupported operand type(s) for -: 'int' and 'list'

# %%
embed_adata[1]
# Out:
# [array([[0.3204924 , 0.67950755],
#         [0.5018142 , 0.49818584],
#         [0.09493702, 0.905063  ],
#         [0.5903626 , 0.4096374 ],
#         [0.36404976, 0.6359502 ],
#         [0.64090663, 0.35909334],
#         [0.6179879 , 0.3820121 ],
#         [0.5663605 , 0.43363953],
#         [0.25865218, 0.74134785],
#         [0.16984412, 0.83015585]], dtype=float32)]

# %% [markdown]
# # Visualization of the umap for two cell types

# %%
sc.pp.normalize_total(adata_subset, target_sum=1e4)
# sc.pp.log1p(adata_subset)
# Perform PCA to reduce dimensionality
sc.pp.pca(adata_subset, n_comps=10)  # You can adjust the number of components

# Compute nearest neighbors using the PCA representation
sc.pp.neighbors(adata_subset, use_rep='X_pca')


sc.tl.umap(adata_subset, spread =8, min_dist = 5)
sc.pl.umap(adata_subset,color=['Celltypes'], 
                   wspace=0.3, size=10, ncols=1, 
                   frameon=False)
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:169: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:196: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# 2025-01-01 16:03:33.873747: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-01 16:03:44.774828: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/cray/pe/papi/7.1.0.1/lib64:/opt/cray/libfabric/1.15.2.0/lib64
# 2025-01-01 16:03:44.775600: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-01-01 16:04:04.225632: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/cray/pe/papi/7.1.0.1/lib64:/opt/cray/libfabric/1.15.2.0/lib64
# 2025-01-01 16:04:04.226917: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/cray/pe/papi/7.1.0.1/lib64:/opt/cray/libfabric/1.15.2.0/lib64
# 2025-01-01 16:04:04.226939: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/umap/umap_.py:1394: RuntimeWarning: divide by zero encountered in power
#   return 1.0 / (1.0 + a * x ** (2 * b))
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Generating the SpatialFormer results

# %%
import sys
sys.path.append("/scratch/project_465001027/Spatialformer")
sys.path.append("/scratch/project_465001027/Spatialformer/scripts")
from train import manual_train_fm
import scanpy as sc
import spatialformer as sp
import importlib
# If you want to reload only the `spatialformer` package
importlib.reload(sp)
# Out:
# <module 'spatialformer' from '/scratch/project_465001027/Spatialformer/spatialformer/__init__.py'>

# %%
adata_subset.obs
# Out:
#                                            Celltypes Celltypes_master_high  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0    B_plasma_IgA                Immune
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0    B_plasma_IgA                Immune
# CACACCTAGTGTACCT-1-WTDAtest7888002-0    B_plasma_IgA                Immune
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0    B_plasma_IgA                Immune
# ACCTTTACACAACTGT-1-HCATisStab7732261-0  B_plasma_IgA                Immune
# ...                                              ...                   ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1    SMG_Serous             Epithelia
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1    SMG_Serous             Epithelia
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1    SMG_Serous             Epithelia
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1    SMG_Serous             Epithelia
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1    SMG_Serous             Epithelia
#
#                                        Celltypes_master_higher  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0                    Immune
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0                    Immune
# CACACCTAGTGTACCT-1-WTDAtest7888002-0                    Immune
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0                    Immune
# ACCTTTACACAACTGT-1-HCATisStab7732261-0                  Immune
# ...                                                        ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1               Epithelia
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1               Epithelia
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1               Epithelia
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1               Epithelia
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1               Epithelia
#
#                                        Celltypes_master_higher_immune  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0                           B_cell
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0                           B_cell
# CACACCTAGTGTACCT-1-WTDAtest7888002-0                           B_cell
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0                           B_cell
# ACCTTTACACAACTGT-1-HCATisStab7732261-0                         B_cell
# ...                                                               ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1              Submucosal_Glands
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1              Submucosal_Glands
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1              Submucosal_Glands
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1              Submucosal_Glands
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1              Submucosal_Glands
#
#                                              Loc_true Material Donor  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0     d_LowLeftPar    cells   A32
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0        a_Trachea    cells   A32
# CACACCTAGTGTACCT-1-WTDAtest7888002-0        a_Trachea    cells   A32
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0        a_Trachea    cells   A32
# ACCTTTACACAACTGT-1-HCATisStab7732261-0   d_LowLeftPar    cells   A26
# ...                                               ...      ...   ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1  b_Bronchi.2.3   nuclei   A42
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1  b_Bronchi.2.3   nuclei   A42
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1  b_Bronchi.2.3   nuclei   A42
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1  b_Bronchi.2.3   nuclei   A42
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1  b_Bronchi.2.3   nuclei   A42
#
#                                        Donor_ID_2 Gender             Sample  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0         411C      M    WTDAtest7887999
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0         411C      M    WTDAtest7888002
# CACACCTAGTGTACCT-1-WTDAtest7888002-0         411C      M    WTDAtest7888002
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0         411C      M    WTDAtest7888002
# ACCTTTACACAACTGT-1-HCATisStab7732261-0       386C      F  HCATisStab7732261
# ...                                           ...    ...                ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1        nan    nan  WSSS_A_LNG8757929
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1        nan    nan  WSSS_A_LNG8757929
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1        nan    nan  WSSS_A_LNG8757929
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1        nan    nan  WSSS_A_LNG8757929
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1        nan    nan  WSSS_A_LNG8757929
#
#                                         ...       Version         Study  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0    ...  10x3prime_v2  dissociation
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0    ...  10x3prime_v2  dissociation
# CACACCTAGTGTACCT-1-WTDAtest7888002-0    ...  10x3prime_v2  dissociation
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0    ...  10x3prime_v2  dissociation
# ACCTTTACACAACTGT-1-HCATisStab7732261-0  ...  10x3prime_v2  dissociation
# ...                                     ...           ...           ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1  ...           nan           nan
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1  ...           nan           nan
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1  ...           nan           nan
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1  ...           nan           nan
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1  ...           nan           nan
#
#                                        PoolDon DonorPool scDonor_snBatch  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0       nan       nan       A32_cells
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0       nan       nan       A32_cells
# CACACCTAGTGTACCT-1-WTDAtest7888002-0       nan       nan       A32_cells
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0       nan       nan       A32_cells
# ACCTTTACACAACTGT-1-HCATisStab7732261-0     nan       nan       A26_cells
# ...                                        ...       ...             ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1     A42   A42none      A42_nuclei
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1     A42   A42none      A42_nuclei
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1     A42   A42none      A42_nuclei
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1     A42   A42none      A42_nuclei
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1     A42   A42none      A42_nuclei
#
#                                        n_genes n_genes_by_counts  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0       226               226
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0      1612              1612
# CACACCTAGTGTACCT-1-WTDAtest7888002-0      1360              1360
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0       912               912
# ACCTTTACACAACTGT-1-HCATisStab7732261-0     673               673
# ...                                        ...               ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1    1211              1211
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1    3140              3140
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1    2999              2999
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1    1411              1411
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1    1371              1371
#
#                                         total_counts  total_counts_mt  \
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0      768.994751         5.476773
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0    15639.706055        39.134060
# CACACCTAGTGTACCT-1-WTDAtest7888002-0     8899.969727        97.390213
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0     7684.337891        28.812786
# ACCTTTACACAACTGT-1-HCATisStab7732261-0   2663.664307        90.278954
# ...                                              ...              ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1   1877.946289         0.000000
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1   8934.666992         0.000000
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1   8775.594727         0.000000
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1   2388.664551         0.000000
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1   2435.939453         0.000000
#
#                                         pct_counts_mt
# AAACGGGCAACCGCCA-1-WTDAtest7887999-0         0.712199
# AAACGGGCAACCGCCA-1-WTDAtest7888002-0         0.250222
# CACACCTAGTGTACCT-1-WTDAtest7888002-0         1.094276
# TGGACGCAGAAGGACA-1-WTDAtest7888002-0         0.374955
# ACCTTTACACAACTGT-1-HCATisStab7732261-0       3.389277
# ...                                               ...
# TTTCACAGTACGGATG-1-WSSS_A_LNG8757929-1       0.000000
# TTTCATGTCTAGTGAC-1-WSSS_A_LNG8757929-1       0.000000
# TTTCCTCCAAATAGCA-1-WSSS_A_LNG8757929-1       0.000000
# TTTGATCTCAAAGAAC-1-WSSS_A_LNG8757929-1       0.000000
# TTTGGAGAGCGACATG-1-WSSS_A_LNG8757929-1       0.000000
#
# [6024 rows x 22 columns]

# %%
adata_subset.var["gene_name"] = adata_subset.var["gene_ids-0"]
# Out:
# /tmp/ipykernel_210179/2113051746.py:1: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_subset.var["gene_name"] = adata_subset.var["gene_ids-0"]

# %%
from scipy.sparse import csr_matrix

adata_subset.X = csr_matrix(adata_subset.X)

# %%
adata_subset.obs["Celltypes"].unique()
# Out:
# ['B_plasma_IgA', 'B_naive', 'SMG_Serous', 'Fibro_perichondrial', 'Myoepithelial']
# Categories (5, object): ['B_naive', 'B_plasma_IgA', 'Fibro_perichondrial', 'Myoepithelial', 'SMG_Serous']

# %%
SMG_index = np.array(adata_subset[adata_subset.obs["Celltypes"] == "SMG_Serous"].obs.index)

# %%
Myo_index = np.array(adata_subset[adata_subset.obs["Celltypes"] == "Myoepithelial"].obs.index)

# %%
IgA_index = np.array(adata_subset[adata_subset.obs["Celltypes"] == "B_plasma_IgA"].obs.index)

# %%
Fib_index = np.array(adata_subset[adata_subset.obs["Celltypes"] == "Fibro_perichondrial"].obs.index)

# %%
import numpy as np
querys = np.random.choice(SMG_index, 10)
paired = np.random.choice(IgA_index, 10)
nonpaired1 = np.random.choice(Myo_index, 10)
nonpaired2 = np.random.choice(Fib_index, 10)

# %%
# %%time
batch_size = 16
tissue = "Lung"
condition = "Disease"
# model_ckp_path = "/scratch/project_465001027/Spatialformer/output/checkpoints/step=0096000-train_total_loss=-2.9351-val_total_loss=0.0000.ckpt"
model_ckp_path = "/scratch/project_465001027/Spatialformer/output/checkpoints/step=0100000-train_total_loss=-2.2727-val_total_loss=0.0000.ckpt"
method = "cls" #getting the cls token embeddings
left_cell = ["TGCGCAGTCAGCATGT-1-WTDAtest7732266-0", "TGCGCAGTCAGCATGT-1-WTDAtest7732266-0"]
right_cell = ["CTAGGTATCTGAGTCA-1-HCA_A_LNG9387709-1", "ACCTTTACACAACTGT-1-HCATisStab7732261-0"]
embed_adata = sp.tl.embed_data(adata_subset, 
                              tissue,
                              condition,
                               method,
                            model_ckp_path, 
                            batch_size,
                            mode = "pair",
                            threshold = 0.7,
                            num_workers = 8,
                            left_cell = querys,
                            right_cell = nonpaired1
                           )
# Out:
# Spatialformer - INFO - Loading the SpatialFormer model...
# [rank: 0] Global seed set to 42
# require grad: True
# Spatialformer - INFO - Setting the model to the evaluation mode...
# Spatialformer - INFO - The model is mapped into cpu
# Spatialformer - INFO - Encoding the data into the batch...
# 1it [00:04,  4.36s/it]
# CPU times: user 5min 19s, sys: 1min 4s, total: 6min 24s
# Wall time: 5.58 s

# %%
embed_adata[1]
# Out:
# [array([[0.67687786, 0.3231222 ],
#         [0.1053376 , 0.89466244],
#         [0.27369574, 0.7263043 ],
#         [0.21698321, 0.7830168 ],
#         [0.47570375, 0.5242963 ],
#         [0.23972856, 0.7602714 ],
#         [0.04522088, 0.9547791 ],
#         [0.06388779, 0.93611217],
#         [0.0455498 , 0.95445013],
#         [0.32241958, 0.6775805 ]], dtype=float32)]

# %%
embed_adata[1]
# Out:
# [array([[0.01087793, 0.9891221 ],
#         [0.00730892, 0.9926911 ],
#         [0.01357403, 0.986426  ],
#         [0.01017198, 0.989828  ],
#         [0.00588342, 0.99411654],
#         [0.00890717, 0.99109286],
#         [0.02120329, 0.9787967 ],
#         [0.00570099, 0.99429893],
#         [0.01887678, 0.98112315],
#         [0.00914746, 0.99085253]], dtype=float32)]

# %%
embed_adata[0][0].shape
# Out:
# (512,)

# %%
adata_subset.var
# Out:
#                mt  gene_ids-0  n_cells-0  n_cells_by_counts-0  mean_counts-0  \
# HES4        False        HES4      16580                16580       0.302786
# TNFRSF18    False    TNFRSF18       5391                 5391       0.055908
# TNFRSF4     False     TNFRSF4       5113                 5113       0.054750
# AL645728.1  False  AL645728.1       1166                 1166       0.008344
# TTC34       False       TTC34        707                  707       0.005823
# ...           ...         ...        ...                  ...            ...
# UBASH3A     False     UBASH3A       2057                 2057       0.015399
# RSPH1       False       RSPH1       3765                 3765       0.404490
# COL18A1     False     COL18A1      13232                13232       0.149136
# COL6A1      False      COL6A1      14127                14127       0.513421
# COL6A2      False      COL6A2      16267                16267       0.612974
#
#             pct_dropout_by_counts-0  total_counts-0       gene_ids-1  \
# HES4                      88.689619    44385.750000  ENSG00000188290
# TNFRSF18                  96.322421     8195.559570  ENSG00000186891
# TNFRSF4                   96.512064     8025.812988  ENSG00000186827
# AL645728.1                99.204590     1223.174438  ENSG00000215014
# TTC34                     99.517706      853.601624  ENSG00000215912
# ...                             ...             ...              ...
# UBASH3A                   98.596776     2257.323975  ENSG00000160185
# RSPH1                     97.431629    59294.632812  ENSG00000160188
# COL18A1                   90.973525    21861.937500  ENSG00000182871
# COL6A1                    90.362983    75262.882812  ENSG00000142156
# COL6A2                    88.903139    89856.523438  ENSG00000142173
#
#             n_cells-1  n_cells_by_counts-1  ...  n_cells  highly_variable  \
# HES4             5369                 5369  ...    18879             True
# TNFRSF18          570                  570  ...     5383             True
# TNFRSF4           521                  521  ...     5170             True
# AL645728.1        367                  367  ...     1251             True
# TTC34            2557                 2557  ...     1571             True
# ...               ...                  ...  ...      ...              ...
# UBASH3A          1330                 1330  ...     2619             True
# RSPH1            3671                 3671  ...     5024             True
# COL18A1          6512                 6512  ...    16562             True
# COL6A1          10117                10117  ...    19712             True
# COL6A2          10974                10974  ...    22146             True
#
#                means dispersions  dispersions_norm  highly_variable_nbatches  \
# HES4        0.348015    2.407703          0.858933                         2
# TNFRSF18    0.090583    2.411408          0.957952                         2
# TNFRSF4     0.103728    2.507761          1.110371                         2
# AL645728.1  0.020191    2.200457          0.519287                         2
# TTC34       0.040115    2.175078          0.452723                         2
# ...              ...         ...               ...                       ...
# UBASH3A     0.076424    2.345723          0.911611                         2
# RSPH1       0.237395    2.757026          1.647012                         2
# COL18A1     0.321884    2.337140          0.801880                         2
# COL6A1      0.514242    2.488781          0.826094                         2
# COL6A2      0.657928    2.699069          1.050830                         2
#
#             highly_variable_intersection          mean       std   gene_name
# HES4                                True -4.553251e-11  0.512652        HES4
# TNFRSF18                            True -2.240157e-11  0.252654    TNFRSF18
# TNFRSF4                             True  1.818045e-11  0.274860     TNFRSF4
# AL645728.1                          True -9.707694e-12  0.115668  AL645728.1
# TTC34                               True -1.262883e-11  0.133543       TTC34
# ...                                  ...           ...       ...         ...
# UBASH3A                             True  2.340285e-12  0.203516     UBASH3A
# RSPH1                               True -2.383287e-11  0.381427       RSPH1
# COL18A1                             True  9.382796e-12  0.458006     COL18A1
# COL6A1                              True -8.717349e-12  0.586709      COL6A1
# COL6A2                              True  4.136420e-11  0.685193      COL6A2
#
# [1147 rows x 24 columns]
