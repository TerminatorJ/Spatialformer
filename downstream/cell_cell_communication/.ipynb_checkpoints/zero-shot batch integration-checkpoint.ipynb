# %% [markdown]
# # Getting all the Cell embeddings from the model

# %% [markdown]
# We want to prove:
# 1) generalizability of the pretraining and the transferability
# 2) robustness of the features learned from the Xenium dataset
# 3) demonstrates strong conservation of biological signals

# %% [markdown]
# ## COVID-19 dataset Integration

# %% [markdown]
# ### loading the dataset

# %%
import scanpy as sc
import matplotlib.pyplot as plt
covid_data = sc.read_h5ad("/scratch/project_465001027/Spatialformer/downstream/cell_cell_communication/data/covid_subsampled.h5ad")

# %% [markdown]
# ### loading the model

# %%
import sys
sys.path.append("/scratch/project_465001027/Spatialformer")
import scanpy as sc
import spatialformer as sp


#configuring the model
model_ckp_path = "/scratch/project_465001027/Spatialformer/output/checkpoints/step=0025000-train_total_loss=-1.3222-val_total_loss=0.0000.ckpt"
tissue = "Lung"
condition = "Disease"

# %% [markdown]
# ### Getting the embeddings

# %%
# %%time
batch_size = 8
embed_adata = sp.tl.embed_data(covid_data, 
                              tissue,
                              condition,
                            model_ckp_path, 
                            batch_size,
                            mode = "single",
                            threshold = 0.7,
                            num_workers = 8
                            )
# Out:
# Spatialformer - INFO - Loading the SpatialFormer model...
# [rank: 0] Global seed set to 42
# require grad: True
# Spatialformer - INFO - Setting the model to the evaluation mode...
# Spatialformer - INFO - The model is mapped into cuda
# Spatialformer - INFO - Encoding the data into the batch...
# 2500it [09:09,  4.55it/s]
# CPU times: user 19min 32s, sys: 4min 12s, total: 23min 45s
# Wall time: 9min 24s

# %% [markdown]
# ### Visualization of the Spatialformer embeddings

# %%
cell_type_key = "celltype"
batch_key = "str_batch"
import sys
from pathlib import Path
sys.path = [str(p) if isinstance(p, Path) else p for p in sys.path]
sc.pp.neighbors(embed_adata, use_rep="X_SpaF")
sc.tl.umap(embed_adata)
sc.pl.umap(embed_adata, 
           color=[cell_type_key], 
           frameon=False, 
           wspace=0.4, 
           title=["COVID19 - SpatialFormer zero-shot: cell type"])
# Out:
# 2024-11-16 20:16:35.844825: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-16 20:16:46.519861: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/cray/pe/papi/7.1.0.1/lib64:/opt/cray/libfabric/1.15.2.0/lib64
# 2024-11-16 20:16:46.520437: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %% [markdown]
# ### visualizing the batch

# %%
sc.pl.umap(embed_adata, 
           color=[batch_key], 
           frameon=False, 
           title=["COVID19 - SpatialFormer zero-shot: batch label"])
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### Computing the score of the metrics - batch correction effect

# %%
def scib_eval(adata, batch_key, cell_type_key, embed_key):
    results = scib.metrics.metrics(
        adata,
        adata_int=adata,
        batch_key=batch_key,
        label_key=cell_type_key,
        embed=embed_key,
        isolated_labels_asw_=False,
        silhouette_=True,
        hvg_score_=False,
        graph_conn_=True,
        pcr_=True,
        isolated_labels_f1_=False,
        trajectory_=False,
        nmi_=True,  # use the clustering, bias to the best matching
        ari_=True,  # use the clustering, bias to the best matching
        cell_cycle_=False,
        kBET_=False, 
        ilisi_=False,
        clisi_=False,
    )
    result_dict = results[0].to_dict()
    
    # compute avgBIO metrics
    result_dict["avg_bio"] = np.mean(
        [
            result_dict["NMI_cluster/label"],
            result_dict["ARI_cluster/label"],
            result_dict["ASW_label"],
        ]
    )
    
    # compute avgBATCH metrics
    result_dict["avg_batch"] = np.mean(
        [
            result_dict["graph_conn"],
            result_dict["ASW_label/batch"],
        ]
    )
    
    result_dict = {k: v for k, v in result_dict.items() if not np.isnan(v)}
    
    return result_dict

# %%
import scib
import numpy as np
scib_result_dict = scib_eval(
    embed_adata,
    batch_key=batch_key,
    cell_type_key=cell_type_key,
    embed_key="X_SpaF",
)
print("AvgBIO: {:.4f}".format(scib_result_dict["avg_bio"]))
print("AvgBATCH: {:.4f}".format(scib_result_dict["avg_batch"]))
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scib/metrics/metrics.py:293: DeprecationWarning: Call to deprecated function (or staticmethod) opt_louvain.
#   res_max, nmi_max, nmi_all = opt_louvain(
# ...
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# AvgBIO: 0.5214
# AvgBATCH: 0.8323

# %% [markdown]
# #For 20000 ckp:
# AvgBIO: 0.3745
# AvgBATCH: 0.8244
#
# #For 15000 ckp:
# AvgBIO: 0.3543
# AvgBATCH: 0.8229
#
# #For 10000 ckp:
# AvgBIO: 0.3424
# AvgBATCH: 0.8161

# %% [markdown]
# # if we only see the CD4+ T cells

# %%
embed_adata_cd4 = embed_adata[embed_adata.obs["celltype"] == "CD4+ T cells"]
embed_adata_cd4_flt = embed_adata_cd4[~embed_adata_cd4.obs[batch_key].isin(["Oetjen_A", "Oetjen_P", "Oetjen_U"])]
sc.pp.neighbors(embed_adata_cd4_flt, use_rep="X_SpaF")
sc.tl.umap(embed_adata_cd4_flt)
with plt.rc_context({"figure.figsize": (13, 8), "figure.dpi": (300)}):
    sc.pl.umap(embed_adata_cd4_flt, 
               color=[cell_type_key, batch_key], 
               frameon=False, 
               title=["COVID19 - SpatialFormer zero-shot: CD4+ T cells"],
               save='CD4_T_cells.png')
sc.tl.louvain(embed_adata_cd4_flt, resolution=0.1)
sc.pl.umap(embed_adata_cd4_flt, color='louvain', title='Leiden Clustering based on X_SpaF')
# Out:
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.
# WARNING: saving figure to file figures/umapCD4_T_cells.png
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Calculating the different expression genes for different clusters

# %%
sc.tl.rank_genes_groups(embed_adata_cd4_flt, groupby='louvain', method='t-test')
sc.pl.rank_genes_groups(embed_adata_cd4_flt, n_genes=10, groupby='louvain')
# Extract the results
results = embed_adata_cd4_flt.uns['rank_genes_groups']

# Prepare a DataFrame to hold the filtered DEGs
filtered_degs = []

for cluster in results['names'].dtype.names:  # Loop through each cluster
    # Convert the data to a DataFrame for easy manipulation
    degs = pd.DataFrame({
        'gene': results['names'][cluster],
        'pval': results['pvals'][cluster],
        'pval_adj': results['pvals_adj'][cluster],  # Assuming you have adjusted p-values available
        'logfoldchanges': results['logfoldchanges'][cluster],
        'cluster': cluster  # Add cluster information
    })
    
    # Filter for current cluster if it's within 1 to 5 and adjusted p < 0.05
    if int(cluster) in range(0, 5):
        filtered_degs.append(degs[degs['pval_adj'] < 0.05])  # Add filtered DEGs for each cluster

# Concatenate all filtered DEGs into a single DataFrame
all_filtered_degs = pd.concat(filtered_degs, ignore_index=True)

# Save to CSV
all_filtered_degs.to_csv("filtered_differentially_expressed_genes_adj.csv", index=False)
# Out:
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.

# %% [markdown]
# ### Doing the GSEA analysis

# %%
all_filtered_degs
# Out:
#      gene          pval      pval_adj  logfoldchanges cluster
# 0     LTB  8.041650e-62  4.824990e-59        8.078968       0
# 1    NPM1  4.546446e-46  1.818578e-43        4.055139       0
# 2    SELL  7.451590e-42  2.235477e-39        3.562541       0
# 3    YBX1  1.598746e-29  3.836989e-27        2.403040       0
# 4    IER2  1.065352e-28  2.130705e-26        3.136789       0
# ..    ...           ...           ...             ...     ...
# 781   HBB  1.216604e-18  4.866416e-16      -26.587593       4
# 782  SELL  1.665000e-14  2.220000e-12       -3.158142       4
# 783  FOSB  2.092917e-18  6.278751e-16       -3.275297       4
# 784   FXN  1.756197e-24  1.053718e-21      -26.339039       4
# 785  LST1  2.159144e-34  2.590973e-31      -27.442690       4
#
# [786 rows x 5 columns]

# %%
cluster = 4

# %%
results.res2d
# Out:
#                        Gene_set                                     Term  \
# 0    GO_Cellular_Component_2021     secretory granule lumen (GO:0034774)
# 1    GO_Cellular_Component_2021  secretory granule membrane (GO:0030667)
# 2    GO_Cellular_Component_2021      platelet alpha granule (GO:0031091)
# 3    GO_Cellular_Component_2021            specific granule (GO:0042581)
# 4    GO_Cellular_Component_2021            tertiary granule (GO:0070820)
# ..                          ...                                      ...
# 128  GO_Cellular_Component_2021                     vesicle (GO:0031982)
# 129  GO_Cellular_Component_2021      mitochondrial membrane (GO:0031966)
# 130  GO_Cellular_Component_2021      lytic vacuole membrane (GO:0098852)
# 131  GO_Cellular_Component_2021          lysosomal membrane (GO:0005765)
# 132  GO_Cellular_Component_2021              Golgi membrane (GO:0000139)
#
#     Overlap       P-value  Adjusted P-value  Old P-value  \
# ...

# %%
import gseapy as gp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

filtered_degs = all_filtered_degs[all_filtered_degs["cluster"] == str(cluster)]
degs = list(filtered_degs.set_index(["gene"]).index)
deg_df = filtered_degs.set_index(["gene"])
results = gp.enrichr(gene_list=degs,
 gene_sets=['GO_Cellular_Component_2021'],
 organism='Human', 
 outdir=None,
 cutoff=0.5
 )
from gseapy.plot import barplot, dotplot
barplot(results.res2d,title=f'GO Cellular_Component cluster {cluster}',color = 'r')
# Out:
# <Axes: title={'center': 'GO Cellular_Component cluster 4'}, xlabel='$- \\log_{10}$ (Adjusted P-value)'>

# %%
#pair gene GO analysis:

# %%
pair_gene_list = list(set([gene for pair in embed_adata_cd4_flt.obs["Gene_Pairs"][0] for gene in pair]))

results = gp.enrichr(gene_list=pair_gene_list,
 gene_sets=['GO_Cellular_Component_2021'],
 organism='Human', 
 outdir=None,
 cutoff=0.5
 )
from gseapy.plot import barplot, dotplot
barplot(results.res2d,title=f'GO Cellular_Component cluster paired genes',color = 'r')
# Out:
# <Axes: title={'center': 'GO Cellular_Component cluster paired genes'}, xlabel='$- \\log_{10}$ (Adjusted P-value)'>

# %% [markdown]
# # Visualize the DEG

# %%
sc.pl.umap(embed_adata_cd4_flt, 
           color=["CXCR4", "SRGN", "ID2", "CFB", "HLA-DPB1"], 
           frameon=False, 
           title=["COVID19 - SpatialFormer zero-shot: CD4+ T cells"])
# Out:
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.

# %%
embed_adata_mac = embed_adata[embed_adata.obs["celltype"] == "Macrophages"]
sc.pp.neighbors(embed_adata_mac, use_rep="X_SpaF")
sc.tl.umap(embed_adata_mac)
sc.pl.umap(embed_adata_mac, 
           color=[cell_type_key, batch_key], 
           frameon=False, 
           title=["COVID19 - SpatialFormer zero-shot: Macrophages"])
sc.tl.louvain(embed_adata_mac, resolution=0.2)
sc.pl.umap(embed_adata_mac, color='louvain', title='Leiden Clustering based on X_SpaF')
# Out:
# WARNING: The title list is shorter than the number of panels. Using 'color' value instead for some plots.
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### Comparison with HGV+PCs

# %%
sc.pp.pca(covid_data, n_comps=40)
sc.pp.neighbors(covid_data, use_rep="X_pca")
sc.tl.umap(covid_data)
sc.pl.umap(
    covid_data,
    color=[cell_type_key, batch_key],
    frameon=False,
    wspace=0.4,
    title=["HVG+PCs: cell type", "HVG+PCs: batch label"],
    ncols=1,
)
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
covid_data_cd4 = covid_data[covid_data.obs["celltype"] == "CD4+ T cells"]
#get rid of the three noise batch
covid_data_cd4_flt = covid_data_cd4[~covid_data_cd4.obs[batch_key].isin(["Oetjen_A", "Oetjen_P", "Oetjen_U"])]
sc.pp.neighbors(covid_data_cd4_flt, use_rep="X_pca")
sc.tl.umap(covid_data_cd4_flt)

with plt.rc_context({"figure.figsize": (8, 8), "figure.dpi": (300)}):
    sc.pl.umap(
        covid_data_cd4_flt,
        color=[cell_type_key, batch_key],
        frameon=False,
        wspace=0.4,
        title=["HVG+PCs: cell type", "HVG+PCs: batch label"],
        ncols=1,
        save='CD4_T_cells_HGV.png'
        
    )
# Out:
# WARNING: saving figure to file figures/umapCD4_T_cells_HGV.png
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
covid_data_mac = covid_data[covid_data.obs["celltype"] == "Macrophages"]
sc.pp.neighbors(covid_data_mac, use_rep="X_pca")
sc.tl.umap(covid_data_mac)
sc.pl.umap(
    covid_data_mac,
    color=[cell_type_key, batch_key],
    frameon=False,
    wspace=0.4,
    title=["HVG+PCs: cell type", "HVG+PCs: batch label"],
    ncols=1,
)
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pp.pca(covid_data, n_comps=40)
sc.pp.neighbors(covid_data, use_rep="X_pca")

sc.pp.neighbors(covid_data, use_rep="X_pca")
sc.tl.umap(covid_data)
sc.pl.umap(
    covid_data,
    color=[cell_type_key, batch_key],
    frameon=False,
    wspace=0.4,
    title=["HVG+PCs: cell type", "HVG+PCs: batch label"],
    ncols=1,
)
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
scib_result_dict = scib_eval(
    covid_data,
    batch_key=batch_key,
    cell_type_key=cell_type_key,
    embed_key="X_pca",
)
print("AvgBIO: {:.4f}".format(scib_result_dict["avg_bio"]))
print("AvgBATCH: {:.4f}".format(scib_result_dict["avg_batch"]))
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scib/metrics/metrics.py:293: DeprecationWarning: Call to deprecated function (or staticmethod) opt_louvain.
#   res_max, nmi_max, nmi_all = opt_louvain(
# ...
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# AvgBIO: 0.3392
# AvgBATCH: 0.6722

# %% [markdown]
# ### MS dataset

# %%
import anndata

# %%
gene_col = "gene_name"
cell_type_key = "celltype"
batch_key = "Sample Characteristic[individual]"

train_data = sc.read_h5ad('/scratch/project_465001027/Spatialformer/downstream/cell_cell_communication/data/c_data.h5ad')
test_data = sc.read_h5ad('/scratch/project_465001027/Spatialformer/downstream/cell_cell_communication/data/filtered_ms_adata.h5ad')
test_data.var.index = test_data.var[gene_col]
adata = anndata.concat([train_data, test_data], join='outer')
adata.var[gene_col] = adata.var.index

tissue = "Brain"
condition = "Disease"

embed_adata = sp.tl.embed_data(adata, 
                              tissue,
                              condition,
                            model_ckp_path, 
                            batch_size,
                            mode = "single",
                            threshold = 0.7
                            )
# Out:
# Spatialformer - INFO - Loading the SpatialFormer model...
# [rank: 0] Global seed set to 42
# /scratch/project_465001027/Spatialformer/spatialformer/model/Spaformer_pair.py:144: ResourceWarning: unclosed file <_io.BufferedReader name='/scratch/project_465001027/Spatialformer/spatial_embeddings/gene_embeddings_GraphSAGE_pandavid.pkl'>
#   pretrained_weights = pickle.load(open(embedding_path, "rb"))
# ...
# require grad: True
# Spatialformer - INFO - Setting the model to the evaluation mode...
# Spatialformer - INFO - The model is mapped into cuda
# Spatialformer - INFO - Encoding the data into the batch...
# 2664it [08:43,  5.09it/s]

# %% [markdown]
# ### Visualization of the MS embeddings

# %%
import sys
from pathlib import Path
sys.path = [str(p) if isinstance(p, Path) else p for p in sys.path]
sc.pp.neighbors(embed_adata, use_rep="X_SpaF")
sc.tl.umap(embed_adata)
sc.pl.umap(embed_adata, 
           color=[cell_type_key], 
           frameon=False, 
           wspace=0.4, 
           title=["MS - SpatialFormer zero-shot: cell type"])
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Visualization of the batch effects

# %%
sc.pp.neighbors(embed_adata, use_rep="X_SpaF")
sc.tl.umap(embed_adata)
sc.pl.umap(embed_adata, 
           color=[batch_key], 
           frameon=False, 
           title=["MS - X_SpaF zero-shot: batch label"])
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### Getting the evaluation metric of the MS classification dataset

# %%
import scib
import numpy as np
scib_result_dict = scib_eval(
    embed_adata,
    batch_key=batch_key,
    cell_type_key=cell_type_key,
    embed_key="X_SpaF",
)
print("AvgBIO: {:.4f}".format(scib_result_dict["avg_bio"]))
print("AvgBATCH: {:.4f}".format(scib_result_dict["avg_batch"]))
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scib/metrics/metrics.py:293: DeprecationWarning: Call to deprecated function (or staticmethod) opt_louvain.
#   res_max, nmi_max, nmi_all = opt_louvain(
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# AvgBIO: 0.3086
# AvgBATCH: 0.8450
