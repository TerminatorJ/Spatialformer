# %% [markdown]
# # Fine-tuning SpatialFormer for Cell-type Annotation with Probe network¶

# %% [markdown]
# In this tutorial, we demonstrate how to fine-tune a pre-trained model on a spatial  for the cell type annotation task. We use the Xenium pulmonary fabrosis dataset as an example and fine-tune on the pre-trained single input model. Please download the dataset folder from https://drive.google.com/drive/folders/12-vuL-gx_wKiLcZlT_ie_mfZEwiNzeND?usp=drive_link
#
# We summarize the fine-tuning pipeline in the following steps, which can be used as a general recipe for finetuning on cell-type annotation tasks and beyond:
#
#  1. Set up the probe neural network
#
#  2. Load and pre-process data
#
#  3. Load the pre-trained SpatialFormer model
#
#  4. Finetune  with task-specific objectives
#
#  5. Evaluate fine-tuned SpatialFormer
#
#  6. Visualization of the SpatialFormer
