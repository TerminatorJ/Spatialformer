# %% [markdown]
# # Gene perturbation analysis

# %% [markdown]
# Try to predict the cell type only using the gene-gene co-occurrence

# %%
from datasets import load_from_disk, load_dataset

# %%
#Loading the data
data = load_dataset("TerminatorJ/xenium_25_lung_dataset_update4", cache_dir = "/scratch/project_465001027/spatialformer/cache2")
# Out:
# ...
# Loading dataset shards:   0%|          | 0/17 [00:00<?, ?it/s]

# %% [markdown]
# Getting the gene-gene co-occurrent information
