# %% [markdown]
# # Traing a model using the pre-trained Graph Neural network to predict the patterns.

# %%
# Add the path to the system path list
import sys
from pathlib import Path
# Get the current working directory
current_dir = Path.cwd()

# Assuming your notebook is in a subdirectory of the project, adjust as needed
project_root = current_dir.parent.parent

# Add the project root to sys.path
sys.path.append(str(project_root))
import spatialformer as sp

# %% [markdown]
# 1) building the graph for each gene within each cell

# %%
#if you use the simulation data, suggested threshold should be 10
#if the Xenium data provided, suggested threshold can be 3-5

dataloader = sp.pp.build_graph(data_path = "/scratch/project_465001027/Spatialformer/downstream/subcellular_localization_prediction/data/transcripts.csv",
                 vocab_path = "/scratch/project_465001027/Spatialformer/spatialformer/tokenizer/tokenv3.json",
                 batch_size = 32,
                 graph_path = "/scratch/project_465001027/Spatialformer/downstream/subcellular_localization_prediction/data",
                 threshold = 10,
                 split = True)
train_dataloader, val_dataloader, test_dataloader = dataloader
# Out:
# loading the saved data

# %% [markdown]
# 2) loading the pre-trained GraphSAGE model

# %%
#Step 2: Loading the pre-trained model

model = sp.pp.load_pretrained_model(
                            vocab_path = "/scratch/project_465001027/Spatialformer/spatialformer/tokenizer/tokenv3.json",
                            hidden_dim = 256,
                            output_dim = 512,
                            batch_size = 32,
                            checkpoint = "/scratch/project_465001027/Spatialformer/output/GraphSAGE_model/checkpoints/step=0010000-train_loss=0.3983-val_loss=0.0000-train_acc=0.8256.ckpt",
                            device = "cuda")

# %% [markdown]
# 3) training the pattern model

# %%
sp.pp.train_pattern_model(
                        model,
                        lr = 0.0001,
                        output_dim = 512,
                        strategy = "ddp_notebook"
                        output_dir = "/scratch/project_465001027/Spatialformer/output/GraphSAGE_model/checkpoints",
                        train_dataloader = train_dataloader,
                        val_dataloader = val_dataloader)
# Out:
# training the model
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: junwang666 (junwanggroup). Use `wandb login --relogin` to force relogin
# wandb version 0.18.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/scratch/project_465001027/Spatialformer/output/GraphSAGE_model/checkpoints/wandb/run-20241026_005230-2nql2033</code>
# Syncing run <strong><a href='https://wandb.ai/junwanggroup/Spaformer/runs/2nql2033' target="_blank">GraphSAGE_pattern</a></strong> to <a href='https://wandb.ai/junwanggroup/Spaformer' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/junwanggroup/Spaformer' target="_blank">https://wandb.ai/junwanggroup/Spaformer</a>
#  View run at <a href='https://wandb.ai/junwanggroup/Spaformer/runs/2nql2033' target="_blank">https://wandb.ai/junwanggroup/Spaformer/runs/2nql2033</a>
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/lightning_fabric/plugins/environments/slurm.py:166: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /scratch/project_465001027/deeploc_torch/lib/python3 ...
#   rank_zero_warn(
# Using bfloat16 Automatic Mixed Precision (AMP)
# ---------------------------------------------------------------------------
# MisconfigurationException                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sp.pp.train_pattern_model(
#       2                         model,
#       3                         lr = 0.0001,
#       4                         output_dim = 512,
#       5                         output_dir = "/scratch/project_465001027/Spatialformer/output/GraphSAGE_model/checkpoints",
#       6                         train_dataloader = train_dataloader,
#       7                         val_dataloader = val_dataloader)
#
# File /pfs/lustrep4/scratch/project_465001027/Spatialformer/spatialformer/processor.py:85, in Processor.train_pattern_model(cls, model, lr, output_dim, output_dir, train_dataloader, val_dataloader)
#      75 @classmethod
#      76 def train_pattern_model(cls,
#      77                 model,
#    (...)
#      82                 val_dataloader
#      83                 ):
#      84     cls.graphsagepattern_instance = GraphSAGEModule()
# ---> 85     cls.graphsage_instance.train_model(
#      86                             model,
#      87                             lr,
#      88                             output_dim,
#      89                             output_dir,
#      90                             train_dataloader,
#      91                             val_dataloader
#      92                          )
#
# File /pfs/lustrep4/scratch/project_465001027/Spatialformer/spatialformer/graphsage.py:329, in GraphSAGEModule.train_model(self, model, lr, output_dim, output_dir, train_dataloader, val_dataloader)
#     327 self.trainer = PatternTrainer(model, lr, output_dim, output_dir, train_dataloader, val_dataloader, None)
#     328 print("training the model")
# --> 329 self.trainer.train()
#
# File /pfs/lustrep4/scratch/project_465001027/Spatialformer/spatialformer/GraphSAGE.py:581, in PatternTrainer.train(self)
#     579 def train(self):
#     580     # import pdb; pdb.set_trace()
# --> 581     self.set_trainer()
#     582     self.trainer.fit(self.plmodel)
#
# File /pfs/lustrep4/scratch/project_465001027/Spatialformer/spatialformer/GraphSAGE.py:539, in PatternTrainer.set_trainer(self)
#     533 self.logger = WandbLogger(project = "Spaformer",
#     534                           name = "GraphSAGE_pattern",
#     535                           log_model = "all",
#     536                           save_dir = self.output_dir)
#     537 # self.logger = CSVLogger("/home/sxr280/Spatialformer/output", name="my_experiment")
# --> 539 self.trainer = pl.Trainer(
#     540     accelerator="auto",
#     541     devices=self.gpus,
#     542     max_steps=10000,
#     543     val_check_interval = 0.1,
#     544     default_root_dir=self.output_dir,
#     545     callbacks=self.make_callback(),
#     546     log_every_n_steps=50,
#     547     logger=self.logger,
#     548     precision='bf16',
#     549     strategy = "ddp",
#     550     num_nodes = 1
#     551 )
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/pytorch_lightning/utilities/argparse.py:348, in _defaults_from_env_vars.<locals>.insert_env_defaults(self, *args, **kwargs)
#     345 kwargs = dict(list(env_variables.items()) + list(kwargs.items()))
#     347 # all args were already moved to kwargs
# --> 348 return fn(self, **kwargs)
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py:420, in Trainer.__init__(self, logger, enable_checkpointing, callbacks, default_root_dir, gradient_clip_val, gradient_clip_algorithm, num_nodes, num_processes, devices, gpus, auto_select_gpus, tpu_cores, ipus, enable_progress_bar, overfit_batches, track_grad_norm, check_val_every_n_epoch, fast_dev_run, accumulate_grad_batches, max_epochs, min_epochs, max_steps, min_steps, max_time, limit_train_batches, limit_val_batches, limit_test_batches, limit_predict_batches, val_check_interval, log_every_n_steps, accelerator, strategy, sync_batchnorm, precision, enable_model_summary, num_sanity_val_steps, resume_from_checkpoint, profiler, benchmark, deterministic, reload_dataloaders_every_n_epochs, auto_lr_find, replace_sampler_ddp, detect_anomaly, auto_scale_batch_size, plugins, amp_backend, amp_level, move_metrics_to_cpu, multiple_trainloader_mode, inference_mode)
#     417 # init connectors
#     418 self._data_connector = DataConnector(self, multiple_trainloader_mode)
# --> 420 self._accelerator_connector = AcceleratorConnector(
#     421     num_processes=num_processes,
#     422     devices=devices,
#     423     tpu_cores=tpu_cores,
#     424     ipus=ipus,
#     425     accelerator=accelerator,
#     426     strategy=strategy,
#     427     gpus=gpus,
#     428     num_nodes=num_nodes,
#     429     sync_batchnorm=sync_batchnorm,
#     430     benchmark=benchmark,
#     431     replace_sampler_ddp=replace_sampler_ddp,
#     432     deterministic=deterministic,
#     433     auto_select_gpus=auto_select_gpus,
#     434     precision=precision,
#     435     amp_type=amp_backend,
#     436     amp_level=amp_level,
#     437     plugins=plugins,
#     438 )
#     439 self._logger_connector = LoggerConnector(self)
#     440 self._callback_connector = CallbackConnector(self)
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:220, in AcceleratorConnector.__init__(self, devices, num_nodes, accelerator, strategy, plugins, precision, amp_type, amp_level, sync_batchnorm, benchmark, replace_sampler_ddp, deterministic, auto_select_gpus, num_processes, tpu_cores, ipus, gpus)
#     217 self.precision_plugin = self._check_and_init_precision()
#     219 # 6. Instantiate Strategy - Part 2
# --> 220 self._lazy_init_strategy()
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:848, in AcceleratorConnector._lazy_init_strategy(self)
#     845 self.strategy._configure_launcher()
#     847 if _IS_INTERACTIVE and self.strategy.launcher and not self.strategy.launcher.is_interactive_compatible:
# --> 848     raise MisconfigurationException(
#     849         f"`Trainer(strategy={self.strategy.strategy_name!r})` is not compatible with an interactive"
#     850         " environment. Run your code as a script, or choose one of the compatible strategies:"
#     851         f" `Fabric(strategy=None|'dp'|'ddp_notebook')`."
#     852         " In case you are spawning processes yourself, make sure to include the Trainer"
#     853         " creation inside the worker function."
#     854     )
#     856 # TODO: should be moved to _check_strategy_and_fallback().
#     857 # Current test check precision first, so keep this check here to meet error order
#     858 if isinstance(self.accelerator, TPUAccelerator) and not isinstance(
#     859     self.strategy, (SingleTPUStrategy, TPUSpawnStrategy)
#     860 ):
#
# MisconfigurationException: `Trainer(strategy='ddp')` is not compatible with an interactive environment. Run your code as a script, or choose one of the compatible strategies: `Fabric(strategy=None|'dp'|'ddp_notebook')`. In case you are spawning processes yourself, make sure to include the Trainer creation inside the worker function.

# %%
model.eval()
embeddings = model(self.train_dataset.x, self.train_dataset.edge_index)

# %%
class GraphSAGESpatialEmbedding(nn.Module):
    def __init__(self, freeze, embedding_path):
        super().__init__()
        pretrained_weights = pickle.load(open(embedding_path, "rb"))
        self.emb = nn.Embedding.from_pretrained(pretrained_weights, freeze=freeze)
        print("require grad:", self.emb.weight.requires_grad)

    def forward(self, x):
        return self.emb(x)

# %%
import pickle
pretrained_weights = pickle.load(open("/scratch/project_465001027/Spatialformer/spatial_embeddings/gene_embeddings_GraphSAGE_pandavid.pkl", "rb"))

# %%
pretrained_weights.shape
# Out:
# torch.Size([1949, 512])
