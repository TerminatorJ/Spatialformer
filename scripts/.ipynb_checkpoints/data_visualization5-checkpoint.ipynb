# %% [markdown]
# # The gene pair inspection

# %% [markdown]
# loading the data

# %%
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
# Correct and verified path to the file
output_h5ad_path = "/scratch/project_465001027/Spatialformer/data/gene_pair.h5ad"
# Load the AnnData object from the .h5ad file
adata = sc.read_h5ad(output_h5ad_path)

# %% [markdown]
# Calculating the quality score

# %%
sc.pp.calculate_qc_metrics(
    adata, inplace=True, log1p=True
)

# %%
ax = sc.pl.violin(
    adata,
    ["n_genes_by_counts"],
    jitter=0.4,
    multi_panel=True,
    palette=["blue"],
    show=False
)

# Access the current figure
fig = plt.gcf()
ax = plt.gca()  # Get the current axes
# # Add more padding between the annotations and the figure
plt.tight_layout()
# # Show and save the modified plot
plt.show()
# Save the figure using matplotlib's savefig
fig.savefig("/scratch/project_465001027/Spatialformer/Figure/n_genes_by_counts_violin.png", dpi=300, bbox_inches='tight', format='png')

# Close the figure to free up memory, especially in scripts
plt.close(fig)
# Out:
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_anndata.py:793: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.catplot(

# %% [markdown]
# Normalization

# %%
# Saving count data
# adata.layers["counts"] = adata.X.copy()
# Normalizing to median total counts
# sc.pp.normalize_total(adata)
# Logarithmize the data
# sc.pp.log1p(adata)

# %% [markdown]
# Get highvariale genes

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=2000)

# %%
sc.pl.highly_variable_genes(adata)

# %% [markdown]
# Dimension reduction of the features

# %%
if not np.issubdtype(adata.X.dtype, np.floating):
    adata.X = adata.X.astype(np.float64)  # Convert to float
sc.tl.pca(adata)

# %%
sc.pl.pca_variance_ratio(adata, n_pcs=50, log=True)

# %% [markdown]
# Subsetting the data according to the annotations

# %%
# Define the fraction of samples to keep from each category
frac_to_keep = 0.1
print("subsetting")
# Group by 'Annotations' and sample the desired fraction from each category
sampled_indices = (adata.obs.groupby("Annotations")
                   .apply(lambda x: x.sample(frac=frac_to_keep, random_state=42))
                   .index.get_level_values(1))

# Create a subset AnnData object using the sampled indices
subann_adata = adata[sampled_indices].copy()
# Out:
# subsetting

# %%
# Subset the data by these highly variable genes
adata_hvg = adata[:, adata.var.highly_variable].copy()
subann_adata_hvg = subann_adata[:, subann_adata.var.highly_variable].copy()

# %% [markdown]
# plotting UMAP

# %%
# Assume 'adata' is your original AnnData object

sc.pp.neighbors(subann_adata_hvg)
# Run UMAP on the subset data
sc.tl.umap(subann_adata_hvg)
# Plot the UMAP
sc.pl.umap(subann_adata_hvg, color='Annotations', title="UMAP - 10% Sampled Annotations")
# Out:
# 2024-10-19 18:23:09.238987: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-19 18:23:15.625823: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/cray/pe/papi/7.1.0.1/lib64:/opt/cray/libfabric/1.15.2.0/lib64
# 2024-10-19 18:23:15.626292: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-10-19 18:23:30.912996: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/cray/pe/papi/7.1.0.1/lib64:/opt/cray/libfabric/1.15.2.0/lib64
# 2024-10-19 18:23:30.914256: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/cray/pe/papi/7.1.0.1/lib64:/opt/cray/libfabric/1.15.2.0/lib64
# 2024-10-19 18:23:30.914276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# Using the igraph implementation and a fixed number of iterations can be significantly faster, especially for larger datasets
# sc.tl.leiden(subann_adata_hvg, resolution=1.0, random_state=42, n_iterations=2)
# sc.pl.umap(subann_adata_hvg, color=["leiden"])

# %% [markdown]
# Calculating the differential expression genes

# %%
import pandas as pd
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(adata_hvg, groupby="Annotations", method="wilcoxon")
# Save the DataFrame to a CSV file
# List to store DataFrames for each group
df_list = []

# Retrieve the list of groups
groups = adata_hvg.uns['rank_genes_groups']['names'].dtype.names

# Iterate through each group and compile the results
for group in groups:
    # Extract the DataFrame for the current group
    ranked_genes_df = sc.get.rank_genes_groups_df(adata_hvg, group=group)
    
    # Add a new column to indicate the group
    ranked_genes_df['group'] = group
    
    # Append the DataFrame to the list
    df_list.append(ranked_genes_df)

# Concatenate all group DataFrames into a single DataFrame
all_groups_df = pd.concat(df_list, ignore_index=True)

# Save the combined DataFrame to a CSV file
output_csv_path = "/scratch/project_465001027/Spatialformer/data/ranked_genes_all_groups.csv"
all_groups_df.to_csv(output_csv_path, index=False)

print(f"Complete differential expression results saved to {output_csv_path}")
# Out:
# WARNING: It seems you use rank_genes_groups on the raw count data. Please logarithmize your data before calling rank_genes_groups.
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# Complete differential expression results saved to /scratch/project_465001027/Spatialformer/data/ranked_genes_all_groups.csv

# %% [markdown]
# i want to make a heatmap of all these filtered gene pairs

# %%
#selecting the top 10 gene pairs for cell types according to logfoldchanges
# Assuming 'logfoldchanges' column is available and you want to sort by it
# ranked_genes_df_sorted = ranked_genes_df.sort_values(by='logfoldchanges', ascending=False)
# Retrieve the list of groups (clusters) analyzed
groups = adata_hvg.uns['rank_genes_groups']['names'].dtype.names
# Create a DataFrame to store top markers for all groups
top_markers_all_clusters = pd.DataFrame()
# Iterate over each group/cluster
for group in groups:
    # Extract ranked genes for the current group
    ranked_genes_df = sc.get.rank_genes_groups_df(adata_hvg, group=group)
    positive_logfc_df = ranked_genes_df[(ranked_genes_df['logfoldchanges'] > 0) & (ranked_genes_df['pvals_adj'] < 0.05)]
    
    # Sort by adjusted p-value ('pvals_adj') and log fold changes ('logfoldchanges')
    ranked_genes_df_sorted = positive_logfc_df.sort_values(by=['pvals_adj', 'logfoldchanges'], ascending=[True, False])
    
    # Select top 10 genes
    top_10_markers_df = ranked_genes_df_sorted.head(30)
    
    # Add a column for the cluster/group for clarity
    top_10_markers_df['cluster'] = group
    
    # Append to the main DataFrame
    top_markers_all_clusters = pd.concat([top_markers_all_clusters, top_10_markers_df], ignore_index=True)
# Out:
# /tmp/ipykernel_121462/131002423.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_markers_df['cluster'] = group

# %%
top_markers_all_clusters
# Out:
#                      names     scores  logfoldchanges          pvals  \
# 0       ('EPCAM', 'ICAM1')  27.602551        3.898141  1.036957e-167
# 1     ('CEACAM6', 'ICAM1')  24.896687        3.907086  8.081152e-137
# 2         ('FN1', 'ICAM1')  23.938461        3.589346  1.218622e-126
# 3       ('ITGB1', 'ICAM1')  22.493736        3.460304  4.780064e-112
# 4       ('NAPSA', 'ICAM1')  18.092785        3.264076   3.632617e-73
# ...                    ...        ...             ...            ...
# 996   ('COL1A2', 'JCHAIN')   5.565353        2.453264   2.616223e-08
# 997     ('HERPUD1', 'LUM')   4.631880        2.877627   3.623601e-06
# 998    ('XBP1', 'HLA-DRA')   4.372776        1.703267   1.226769e-05
# 999       ('STAT1', 'VIM')   4.135653        1.208622   3.539473e-05
# 1000    ('STAT1', 'PTGDS')   3.905088        2.895217   9.419125e-05
#
#           pvals_adj cluster
# 0     2.527324e-164     AT1
# 1     1.313053e-133     AT1
# 2     1.485043e-123     AT1
# 3     5.177872e-109     AT1
# 4      2.529599e-70     AT1
# ...             ...     ...
# 996    1.700371e-05    pDCs
# 997    2.078028e-03    pDCs
# 998    6.644315e-03    pDCs
# 999    1.816122e-02    pDCs
# 1000   4.591352e-02    pDCs
#
# [1001 rows x 6 columns]

# %%
#getting the dict of the group: markers
# Create a dictionary where each group is a key, and values are lists of names
marker_pairs_dict = top_markers_all_clusters.groupby("cluster")["names"].apply(list).to_dict()

# %%
marker_pairs_dict
# Out:
# {'AT1': ["('EPCAM', 'ICAM1')",
#   "('CEACAM6', 'ICAM1')",
#   "('FN1', 'ICAM1')",
#   "('ITGB1', 'ICAM1')",
#   "('NAPSA', 'ICAM1')",
#   "('ATF4', 'ICAM1')",
#   "('SFTPD', 'ICAM1')",
#   "('EPCAM', 'VIM')",
#   "('KRT8', 'VIM')",
#   "('ITGB1', 'RNASE1')",
#   "('KRT18', 'KRT8')",
#   "('VIM', 'RNASE1')",
#   "('SFTPD', 'VIM')",
#   "('CEACAM6', 'SFTPC')",
#   "('MGST1', 'ICAM1')",
#   "('ATF4', 'RNASE1')",
#   "('VIM', 'EPAS1')",
#   "('ICAM1', 'RNASE1')",
#   "('CEACAM6', 'NAPSA')",
#   "('ITGB1', 'SFTPC')",
#   "('NKX2-1', 'SFTPD')",
#   "('NAPSA', 'FN1')",
#   "('KRT18', 'SFTPD')",
#   "('ITGB1', 'CCN2')",
#   "('EPCAM', 'SFTPD')",
#   "('SFTPC', 'VIM')",
#   "('RNASE1', 'SFTPD')",
#   "('KRT8', 'SFTPD')",
#   "('MGST1', 'RNASE1')",
#   "('RHOA', 'NAPSA')"],
#  'AT2': ["('LAMP3', 'SFTPD')",
#   "('DUOX1', 'SFTPC')",
#   "('LAMP3', 'NAPSA')",
#   "('MGST1', 'SFTPD')",
#   "('LAMP3', 'CD44')",
#   "('EPAS1', 'SFTPD')",
#   "('DMBT1', 'SFTPC')",
#   "('XBP1', 'PGC')",
#   "('RNASE1', 'SFTPD')",
#   "('CD44', 'NAPSA')",
#   "('EPAS1', 'PGC')",
#   "('MGST1', 'DMBT1')",
#   "('NKX2-1', 'PGC')",
#   "('NKX2-1', 'SFTPD')",
#   "('EPAS1', 'NAPSA')",
#   "('PGC', 'DMBT1')",
#   "('XBP1', 'DMBT1')",
#   "('PGC', 'NAPSA')",
#   "('HLA-DRA', 'NAPSA')",
#   "('VIM', 'NAPSA')",
#   "('RNASE1', 'PGC')",
#   "('HLA-DRA', 'SFTPC')",
#   "('LAMP3', 'HLA-DRA')",
#   "('SOD2', 'NAPSA')",
#   "('RNASE1', 'DMBT1')",
#   "('YAP1', 'SFTPC')",
#   "('EPCAM', 'SFTPD')",
#   "('FN1', 'SFTPD')",
#   "('KRT8', 'SFTPD')",
#   "('ITGB1', 'SFTPD')"],
#  'Activated FBs': ["('VIM', 'COL1A1')",
#   "('POSTN', 'FN1')",
#   "('MEG3', 'COL3A1')",
#   "('MEG3', 'COL1A2')",
#   "('LUM', 'COL1A1')",
#   "('COL1A2', 'COL1A1')",
#   "('LUM', 'COL3A1')",
#   "('ACTA2', 'COL3A1')",
#   "('COL1A2', 'COL3A1')",
#   "('LUM', 'COL1A2')",
#   "('SPARCL1', 'COL1A1')",
#   "('COL1A1', 'COL3A1')",
#   "('FN1', 'LUM')",
#   "('FN1', 'VIM')",
#   "('ACTA2', 'COL1A1')",
#   "('VIM', 'POSTN')",
#   "('COL1A2', 'POSTN')",
#   "('SFRP4', 'VIM')",
#   "('DCN', 'POSTN')",
#   "('CCN2', 'COL1A2')",
#   "('SFRP2', 'COL1A1')",
#   "('COL1A2', 'FN1')",
#   "('ATF4', 'COL3A1')",
#   "('PDIA3', 'COL1A2')",
#   "('SPARCL1', 'VIM')",
#   "('RHOA', 'COL3A1')",
#   "('ATF4', 'COL1A2')",
#   "('SFRP2', 'COL1A2')",
#   "('RHOA', 'COL1A2')",
#   "('PDIA3', 'FN1')"],
#  'Adventitial FBs': ["('LUM', 'DCN')",
#   "('COL1A2', 'SFRP2')",
#   "('SPARCL1', 'SFRP2')",
#   "('SPARCL1', 'DCN')",
#   "('PTGDS', 'SFRP2')",
#   "('SPARCL1', 'VIM')",
#   "('SFRP2', 'VIM')",
#   "('COL1A2', 'LUM')",
#   "('SFRP4', 'VIM')",
#   "('COL1A1', 'COL1A2')",
#   "('COL3A1', 'VIM')",
#   "('PTGDS', 'VIM')",
#   "('COL3A1', 'LUM')",
#   "('COL1A1', 'COL3A1')",
#   "('SPARCL1', 'COL1A1')",
#   "('LUM', 'COL1A2')",
#   "('SFRP2', 'DCN')",
#   "('FN1', 'LUM')",
#   "('PTGDS', 'COL1A2')",
#   "('COL1A2', 'COL3A1')",
#   "('SOD2', 'SFRP2')",
#   "('LUM', 'COL3A1')",
#   "('MEG3', 'DCN')",
#   "('SFRP2', 'COL1A2')",
#   "('COL1A2', 'COL1A1')",
#   "('SOD2', 'DCN')",
#   "('LUM', 'COL1A1')",
#   "('RHOA', 'DCN')",
#   "('MEG3', 'COL1A2')",
#   "('ITGB1', 'SFRP2')"],
#  'Alveolar FBs': ["('SFTPC', 'VIM')",
#   "('COL1A2', 'FN1')",
#   "('COL1A2', 'COL3A1')",
#   "('FN1', 'VIM')",
#   "('PTGDS', 'FN1')",
#   "('COL1A1', 'COL3A1')",
#   "('COL3A1', 'VIM')",
#   "('SFTPC', 'COL3A1')",
#   "('COL1A1', 'FN1')",
#   "('EPAS1', 'FN1')",
#   "('SPARCL1', 'VIM')",
#   "('LUM', 'COL3A1')",
#   "('LUM', 'COL1A2')",
#   "('CCN2', 'VIM')",
#   "('COL1A2', 'SFTPC')",
#   "('HLA-DRA', 'FN1')",
#   "('COL1A1', 'COL1A2')",
#   "('COL1A2', 'LUM')",
#   "('LUM', 'SFTPC')",
#   "('NAPSA', 'FN1')",
#   "('SFTPD', 'VIM')",
#   "('COL1A2', 'COL1A1')",
#   "('FN1', 'LUM')",
#   "('PDIA3', 'FN1')",
#   "('PTGDS', 'VIM')",
#   "('LUM', 'COL1A1')",
#   "('HLA-DRA', 'LUM')",
#   "('COL3A1', 'LUM')",
#   "('ATF4', 'COL1A2')",
#   "('ATF4', 'COL3A1')"],
#  'Arteriole': ["('SPARCL1', 'VIM')",
#   "('VIM', 'EPAS1')",
#   "('ITGB1', 'EPAS1')",
#   "('PECAM1', 'FN1')",
#   "('FN1', 'VIM')",
#   "('HERPUD1', 'VIM')",
#   "('EPAS1', 'FN1')",
#   "('PDIA3', 'EPAS1')",
#   "('CD34', 'EPAS1')",
#   "('HLA-DRA', 'EPAS1')",
#   "('CCN2', 'VIM')",
#   "('RHOA', 'VIM')",
#   "('PECAM1', 'CCN2')",
#   "('CD34', 'PECAM1')",
#   "('BMPR2', 'EPAS1')",
#   "('ITGB1', 'SPARCL1')",
#   "('BMPR2', 'VIM')",
#   "('PTGDS', 'PECAM1')",
#   "('ATF4', 'PECAM1')",
#   "('HLA-DRA', 'PECAM1')",
#   "('FN1', 'CCN2')",
#   "('PDIA3', 'VIM')",
#   "('SPARCL1', 'CCN2')",
#   "('ITGB1', 'CCN2')",
#   "('RNASE1', 'SPARCL1')",
#   "('PDIA3', 'ACTA2')",
#   "('WWTR1', 'VIM')",
#   "('SOD2', 'EPAS1')",
#   "('PDIA3', 'FN1')",
#   "('CTNNB1', 'FN1')"],
#  'B cells': ["('VIM', 'HLA-DRA')",
#   "('CXCR4', 'VIM')",
#   "('HLA-DRA', 'VIM')",
#   "('PTPRC', 'HLA-DRA')",
#   "('JCHAIN', 'HLA-DRA')",
#   "('PTGDS', 'VIM')",
#   "('PTPRC', 'VIM')",
#   "('STAT1', 'HLA-DRA')",
#   "('HLA-DRA', 'LUM')",
#   "('HERPUD1', 'HLA-DRA')",
#   "('JCHAIN', 'VIM')",
#   "('COL3A1', 'HLA-DRA')",
#   "('SFRP2', 'HLA-DRA')",
#   "('VIM', 'JCHAIN')",
#   "('HLA-DQA1', 'LUM')",
#   "('VIM', 'PTGDS')",
#   "('HERPUD1', 'VIM')",
#   "('GPR183', 'HLA-DRA')",
#   "('CD52', 'VIM')"],
#  'Basal': ["('SCGB3A2', 'SCGB1A1')",
#   "('HLA-DRA', 'SCGB1A1')",
#   "('PDIA3', 'SCGB3A2')",
#   "('PDIA3', 'XBP1')",
#   "('MGST1', 'SCGB3A2')",
#   "('KRT18', 'SCGB3A2')",
#   "('SCGB1A1', 'XBP1')",
#   "('SCGB3A2', 'XBP1')",
#   "('KRT18', 'XBP1')",
#   "('WFDC2', 'XBP1')",
#   "('PKM', 'XBP1')",
#   "('RHOA', 'SCGB3A2')",
#   "('ICAM1', 'SCGB3A2')",
#   "('KRT18', 'CD44')",
#   "('KRT8', 'CD44')",
#   "('EPCAM', 'CD44')",
#   "('MGST1', 'RNASE1')",
#   "('EPCAM', 'HLA-DRA')",
#   "('PDIA3', 'CD44')",
#   "('XBP1', 'CD44')",
#   "('KRT8', 'XBP1')",
#   "('PKM', 'PDIA3')",
#   "('KRT18', 'KRT8')",
#   "('PDIA4', 'CD44')"],
#  'Ciliated': ["('AGR3', 'XBP1')",
#   "('SCGB3A2', 'SCGB1A1')",
#   "('SCGB1A1', 'XBP1')",
#   "('HLA-DRA', 'SCGB1A1')",
#   "('CCN2', 'XBP1')",
#   "('WFDC2', 'XBP1')",
#   "('XBP1', 'CCN2')",
#   "('PDIA3', 'XBP1')",
#   "('SCGB3A2', 'XBP1')",
#   "('KRT8', 'XBP1')",
#   "('CTNNB1', 'CCN2')",
#   "('KRT18', 'XBP1')",
#   "('EPCAM', 'HLA-DRA')",
#   "('RHOA', 'SCGB3A2')",
#   "('PDIA3', 'SCGB3A2')",
#   "('PKM', 'XBP1')",
#   "('KRT18', 'SCGB3A2')",
#   "('STAT1', 'HLA-DRA')",
#   "('MGST1', 'SCGB3A2')",
#   "('SOD2', 'CCN2')",
#   "('ITGB1', 'XBP1')",
#   "('XBP1', 'HLA-DRA')",
#   "('KRT18', 'KRT8')",
#   "('NUCB2', 'VIM')",
#   "('ITGB1', 'CCN2')",
#   "('EPCAM', 'VIM')"],
#  'DCs': ["('HLA-DQA1', 'LYZ')",
#   "('CST3', 'HLA-DRA')",
#   "('HLA-DRA', 'LYZ')",
#   "('VIM', 'HLA-DRA')",
#   "('LYZ', 'VIM')",
#   "('HLA-DRA', 'VIM')",
#   "('CD44', 'LYZ')",
#   "('CST3', 'LYZ')",
#   "('FN1', 'LYZ')",
#   "('PTPRC', 'VIM')",
#   "('COL3A1', 'HLA-DRA')",
#   "('PTPRC', 'HLA-DRA')",
#   "('STAT1', 'LYZ')",
#   "('STAT1', 'HLA-DRA')",
#   "('HERPUD1', 'HLA-DRA')",
#   "('GPR183', 'HLA-DRA')",
#   "('LUM', 'LYZ')",
#   "('FCER1G', 'HLA-DQA1')",
#   "('RHOA', 'HLA-DRA')",
#   "('HLA-DQB1', 'HLA-DQA1')",
#   "('HERPUD1', 'LYZ')",
#   "('COL3A1', 'LYZ')",
#   "('STAT1', 'VIM')",
#   "('MS4A7', 'VIM')",
#   "('IL7R', 'VIM')",
#   "('CD68', 'VIM')",
#   "('CD68', 'HLA-DRA')",
#   "('CCL18', 'HLA-DRA')",
#   "('SOD2', 'VIM')",
#   "('HERPUD1', 'VIM')"],
#  'Differentiating Ciliated': ["('WFDC2', 'XBP1')",
#   "('SCGB1A1', 'XBP1')",
#   "('AGR3', 'XBP1')",
#   "('PDIA3', 'XBP1')",
#   "('KRT18', 'XBP1')",
#   "('CCN2', 'XBP1')",
#   "('SCGB3A2', 'XBP1')",
#   "('HLA-DRA', 'SCGB1A1')",
#   "('PKM', 'XBP1')",
#   "('KRT8', 'XBP1')",
#   "('SCGB3A2', 'SCGB1A1')",
#   "('MGST1', 'SCGB3A2')",
#   "('PDIA3', 'SCGB3A2')",
#   "('RHOA', 'SCGB3A2')",
#   "('KRT18', 'SCGB3A2')",
#   "('NUCB2', 'VIM')",
#   "('CTNNB1', 'CCN2')",
#   "('EPCAM', 'VIM')",
#   "('PKM', 'PDIA3')",
#   "('ITGB1', 'XBP1')"],
#  'FABP4+ Macrophages': ["('MCEMP1', 'LYZ')",
#   "('MCEMP1', 'VIM')",
#   "('CD52', 'VIM')",
#   "('MRC1', 'FN1')",
#   "('PLIN2', 'LYZ')",
#   "('MARCO', 'VIM')",
#   "('CD44', 'MS4A7')",
#   "('HLA-DQA1', 'CD68')",
#   "('CD68', 'MS4A7')",
#   "('FCER1G', 'MS4A7')",
#   "('HLA-DQA1', 'MS4A7')",
#   "('RHOA', 'MS4A7')",
#   "('MS4A7', 'CD68')",
#   "('MRC1', 'CCL18')",
#   "('HLA-DQA1', 'FCER1G')",
#   "('RHOA', 'CD68')",
#   "('PLIN2', 'VIM')",
#   "('CD68', 'VIM')",
#   "('CD68', 'HLA-DRA')",
#   "('MS4A7', 'FCER1G')",
#   "('MS4A7', 'VIM')",
#   "('IDH1', 'LYZ')",
#   "('CD68', 'CCL18')",
#   "('CD44', 'CCL18')",
#   "('PECAM1', 'HLA-DRA')",
#   "('PKM', 'LYZ')",
#   "('CD44', 'LYZ')",
#   "('FN1', 'LYZ')",
#   "('HLA-DQA1', 'LYZ')",
#   "('CCL18', 'HLA-DRA')"],
#  'Fibroblasts': ["('MEG3', 'COL1A2')",
#   "('MEG3', 'COL3A1')",
#   "('PTGDS', 'COL1A1')",
#   "('SFRP2', 'COL1A1')",
#   "('SPARCL1', 'DCN')",
#   "('SFRP2', 'FN1')",
#   "('SPARCL1', 'SFRP2')",
#   "('SFRP2', 'COL1A2')",
#   "('SPARCL1', 'COL1A1')",
#   "('SFRP2', 'PTGDS')",
#   "('PTGDS', 'COL1A2')",
#   "('CCN2', 'LUM')",
#   "('CCN2', 'PTGDS')",
#   "('SOD2', 'COL1A1')",
#   "('FN1', 'LUM')",
#   "('VIM', 'COL1A1')",
#   "('COL1A2', 'PTGDS')",
#   "('PTGDS', 'SFRP2')",
#   "('SOD2', 'LUM')",
#   "('COL1A2', 'LUM')",
#   "('VIM', 'PTGDS')",
#   "('COL3A1', 'PTGDS')",
#   "('CCN2', 'COL1A2')",
#   "('PTGDS', 'FN1')",
#   "('COL3A1', 'LUM')",
#   "('LUM', 'COL1A1')",
#   "('COL1A1', 'COL1A2')",
#   "('COL1A2', 'COL1A1')",
#   "('LUM', 'COL1A2')",
#   "('LUM', 'COL3A1')"],
#  'Interstitial Macrophages': ["('S100A9', 'VIM')",
#   "('HLA-DRA', 'LYZ')",
#   "('PTPRC', 'VIM')",
#   "('CD44', 'LYZ')",
#   "('LYZ', 'VIM')",
#   "('EPAS1', 'LYZ')",
#   "('HLA-DRA', 'VIM')",
#   "('RHOA', 'VIM')",
#   "('SOD2', 'VIM')",
#   "('FN1', 'LYZ')",
#   "('SPARCL1', 'LYZ')",
#   "('CST3', 'LYZ')",
#   "('LUM', 'LYZ')",
#   "('COL3A1', 'LYZ')",
#   "('MS4A7', 'VIM')",
#   "('PKM', 'LYZ')",
#   "('PTPRC', 'HLA-DRA')",
#   "('SFTPC', 'VIM')",
#   "('RHOA', 'HLA-DRA')",
#   "('CST3', 'HLA-DRA')",
#   "('CD14', 'HLA-DRA')",
#   "('SOD2', 'EPAS1')",
#   "('HERPUD1', 'LYZ')",
#   "('GPR183', 'HLA-DRA')",
#   "('VIM', 'EPAS1')",
#   "('STAT1', 'LYZ')",
#   "('HSPA5', 'LYZ')",
#   "('HLA-DQA1', 'LYZ')",
#   "('MS4A7', 'FCER1G')",
#   "('EPAS1', 'HLA-DRA')"],
#  'KRT5-/KRT17+': ["('EPCAM', 'ICAM1')",
#   "('KRT8', 'VIM')",
#   "('EPCAM', 'VIM')",
#   "('CEACAM6', 'ICAM1')",
#   "('NAPSA', 'ICAM1')",
#   "('KRT18', 'KRT8')",
#   "('ITGB1', 'ICAM1')",
#   "('FN1', 'ICAM1')",
#   "('PDIA3', 'VIM')",
#   "('PDIA3', 'FN1')",
#   "('CTNNB1', 'COL1A1')",
#   "('MGST1', 'ICAM1')",
#   "('CTNNB1', 'FN1')",
#   "('NAPSA', 'FN1')",
#   "('RHOA', 'VIM')",
#   "('EPCAM', 'CD44')",
#   "('PDIA3', 'CD44')",
#   "('PKM', 'FN1')",
#   "('ATF4', 'ICAM1')",
#   "('VIM', 'COL1A1')",
#   "('COL1A2', 'COL1A1')",
#   "('COL1A1', 'FN1')",
#   "('KRT18', 'SCGB3A2')",
#   "('ICAM1', 'SCGB3A2')",
#   "('NAPSA', 'CD44')",
#   "('KRT18', 'CD44')",
#   "('HLA-DRA', 'FN1')",
#   "('XBP1', 'CD44')",
#   "('PDIA4', 'VIM')",
#   "('KRT8', 'CD44')"],
#  'Lipofibroblasts': ["('SPARCL1', 'VIM')",
#   "('COL3A1', 'VIM')",
#   "('CCN2', 'VIM')",
#   "('COL3A1', 'ACTA2')",
#   "('COL1A2', 'SPARCL1')",
#   "('ITGB1', 'SPARCL1')",
#   "('CCL21', 'VIM')",
#   "('COL1A1', 'COL1A2')",
#   "('PTGDS', 'VIM')",
#   "('COL1A1', 'COL3A1')",
#   "('JCHAIN', 'VIM')",
#   "('COL1A2', 'COL3A1')",
#   "('ACTA2', 'COL3A1')",
#   "('FN1', 'VIM')",
#   "('SFRP2', 'VIM')",
#   "('PTGDS', 'ACTA2')",
#   "('CD44', 'ACTA2')",
#   "('COL1A2', 'CCN2')",
#   "('CCN2', 'COL1A2')",
#   "('SPARCL1', 'CCN2')",
#   "('DCN', 'SPARCL1')",
#   "('LUM', 'COL1A2')",
#   "('ITGB1', 'CCN2')",
#   "('DCN', 'ACTA2')",
#   "('PTGDS', 'COL1A2')",
#   "('FN1', 'CCN2')",
#   "('LUM', 'COL3A1')",
#   "('PDIA3', 'ACTA2')",
#   "('SFRP2', 'SPARCL1')"],
#  'Lymphatic/DCs': ["('CCL21', 'VIM')",
#   "('FN1', 'VIM')",
#   "('JCHAIN', 'VIM')",
#   "('RHOA', 'VIM')",
#   "('PECAM1', 'FN1')",
#   "('PDIA3', 'VIM')",
#   "('WWTR1', 'VIM')",
#   "('COL3A1', 'VIM')",
#   "('SFRP2', 'VIM')",
#   "('PTGDS', 'VIM')",
#   "('PECAM1', 'LUM')",
#   "('PECAM1', 'COL3A1')",
#   "('ATF4', 'VIM')",
#   "('FN1', 'ITGB1')",
#   "('STAT1', 'VIM')",
#   "('PECAM1', 'COL1A2')"],
#  'MUC5B+': ["('WFDC2', 'XBP1')",
#   "('SCGB1A1', 'XBP1')",
#   "('PDIA3', 'XBP1')",
#   "('HLA-DRA', 'SCGB1A1')",
#   "('SCGB3A2', 'XBP1')",
#   "('SCGB3A2', 'SCGB1A1')",
#   "('KRT18', 'XBP1')",
#   "('AGR3', 'XBP1')",
#   "('CCN2', 'XBP1')",
#   "('PDIA3', 'SCGB3A2')",
#   "('MGST1', 'SCGB3A2')",
#   "('PKM', 'XBP1')",
#   "('KRT8', 'XBP1')",
#   "('KRT18', 'SCGB3A2')",
#   "('EPCAM', 'HLA-DRA')",
#   "('RHOA', 'SCGB3A2')",
#   "('EPCAM', 'VIM')",
#   "('NUCB2', 'VIM')",
#   "('STAT1', 'HLA-DRA')"],
#  'Macrophages': ["('CD14', 'HLA-DRA')",
#   "('VIM', 'HLA-DRA')",
#   "('MS4A7', 'VIM')",
#   "('LUM', 'LYZ')",
#   "('COL3A1', 'LYZ')",
#   "('STAT1', 'LYZ')",
#   "('HERPUD1', 'HLA-DRA')",
#   "('HLA-DQA1', 'LYZ')",
#   "('COL3A1', 'HLA-DRA')",
#   "('CD68', 'HLA-DRA')",
#   "('CCL18', 'HLA-DRA')",
#   "('CST3', 'HLA-DRA')",
#   "('STAT1', 'HLA-DRA')",
#   "('CD68', 'VIM')",
#   "('HLA-DRA', 'LYZ')",
#   "('FN1', 'LYZ')",
#   "('LYZ', 'VIM')",
#   "('CD44', 'LYZ')",
#   "('HLA-DRA', 'VIM')",
#   "('STAT1', 'VIM')",
#   "('RHOA', 'HLA-DRA')",
#   "('CST3', 'LYZ')",
#   "('CD68', 'CCL18')",
#   "('XBP1', 'HLA-DRA')",
#   "('GPR183', 'HLA-DRA')",
#   "('RNASE1', 'CCL18')",
#   "('JCHAIN', 'HLA-DRA')",
#   "('HLA-DQA1', 'MS4A7')",
#   "('FCER1G', 'HLA-DQA1')",
#   "('HERPUD1', 'LYZ')"],
#  'Mast': ["('TPSAB1', 'VIM')",
#   "('CPA3', 'VIM')",
#   "('PTGDS', 'VIM')",
#   "('COL3A1', 'VIM')",
#   "('JCHAIN', 'VIM')",
#   "('FN1', 'VIM')",
#   "('SFRP2', 'VIM')",
#   "('PTGDS', 'FN1')",
#   "('PLIN2', 'VIM')",
#   "('CD44', 'LUM')",
#   "('COL1A2', 'FN1')",
#   "('COL1A2', 'PTGDS')",
#   "('LUM', 'COL1A2')",
#   "('COL1A2', 'LUM')",
#   "('PTGDS', 'COL1A2')",
#   "('COL1A1', 'COL1A2')",
#   "('FN1', 'LUM')",
#   "('VIM', 'JCHAIN')",
#   "('CD44', 'JCHAIN')",
#   "('COL1A2', 'JCHAIN')",
#   "('COL3A1', 'PTGDS')"],
#  'NK cells': ["('PTPRC', 'VIM')", "('VIM', 'EPAS1')"],
#  'Peribronchial FBs': ["('COL1A2', 'LUM')",
#   "('FN1', 'LUM')",
#   "('SCGB1A1', 'VIM')",
#   "('SPARCL1', 'VIM')",
#   "('FN1', 'VIM')",
#   "('PTGDS', 'VIM')",
#   "('COL3A1', 'VIM')",
#   "('COL3A1', 'LUM')",
#   "('CCN2', 'VIM')",
#   "('COL1A2', 'COL3A1')",
#   "('COL1A1', 'COL3A1')",
#   "('CCN2', 'LUM')",
#   "('COL1A2', 'FN1')",
#   "('PTGDS', 'FN1')",
#   "('MEG3', 'COL3A1')",
#   "('FN1', 'CCN2')",
#   "('COL1A2', 'CCN2')",
#   "('COL1A1', 'COL1A2')",
#   "('LUM', 'COL3A1')",
#   "('COL1A1', 'FN1')",
#   "('MEG3', 'COL1A2')",
#   "('SPARCL1', 'CCN2')",
#   "('COL1A2', 'PTGDS')",
#   "('SFRP4', 'VIM')",
#   "('DCN', 'SPARCL1')",
#   "('SPARCL1', 'DCN')",
#   "('PTGDS', 'COL1A2')",
#   "('CCN2', 'COL1A2')",
#   "('HLA-DRA', 'LUM')",
#   "('SPARCL1', 'COL1A1')"],
#  'Plasma': ["('PIM2', 'XBP1')",
#   "('SEC11C', 'HERPUD1')",
#   "('ITM2C', 'XBP1')",
#   "('SEC11C', 'JCHAIN')",
#   "('ITM2C', 'JCHAIN')",
#   "('PRDX4', 'XBP1')",
#   "('ITM2C', 'VIM')",
#   "('PRDX4', 'VIM')",
#   "('VIM', 'JCHAIN')",
#   "('COL3A1', 'XBP1')",
#   "('UBE2J1', 'VIM')",
#   "('COL1A2', 'JCHAIN')",
#   "('SPCS3', 'VIM')",
#   "('HERPUD1', 'VIM')",
#   "('PDIA4', 'VIM')",
#   "('JCHAIN', 'VIM')",
#   "('ATF4', 'VIM')",
#   "('HYOU1', 'XBP1')",
#   "('SPCS2', 'VIM')",
#   "('SFRP2', 'JCHAIN')",
#   "('CD44', 'JCHAIN')",
#   "('PDIA3', 'XBP1')",
#   "('PTGDS', 'VIM')",
#   "('SOD2', 'JCHAIN')",
#   "('CCN2', 'XBP1')",
#   "('HERPUD1', 'LUM')",
#   "('HERPUD1', 'PTGDS')",
#   "('SPARCL1', 'JCHAIN')",
#   "('NUCB2', 'VIM')",
#   "('ITGB1', 'XBP1')"],
#  'Proliferating Endothelial': ["('RHOA', 'VIM')",
#   "('SPARCL1', 'VIM')",
#   "('ATF4', 'VIM')",
#   "('PDIA3', 'VIM')",
#   "('ITGB1', 'EPAS1')",
#   "('CD34', 'EPAS1')",
#   "('PDIA3', 'EPAS1')",
#   "('HLA-DRA', 'EPAS1')",
#   "('FN1', 'VIM')",
#   "('SFTPC', 'VIM')",
#   "('VIM', 'EPAS1')",
#   "('CD34', 'PECAM1')",
#   "('ITGB1', 'SPARCL1')",
#   "('ATF4', 'PECAM1')",
#   "('STAT1', 'VIM')",
#   "('S100A9', 'VIM')",
#   "('PECAM1', 'FN1')",
#   "('HLA-DRA', 'PECAM1')",
#   "('HLA-DRA', 'SPARCL1')"],
#  'Proliferating Epithelial': ["('DMBT1', 'SFTPC')",
#   "('CD44', 'NAPSA')",
#   "('HLA-DRA', 'NAPSA')",
#   "('HLA-DRA', 'SFTPC')",
#   "('MGST1', 'SFTPD')",
#   "('PGC', 'NAPSA')",
#   "('VIM', 'NAPSA')",
#   "('LAMP3', 'NAPSA')",
#   "('RHOA', 'NAPSA')",
#   "('LAMP3', 'SFTPD')",
#   "('RNASE1', 'SFTPD')",
#   "('PDIA3', 'SFTPC')",
#   "('ICAM1', 'NAPSA')",
#   "('RNASE1', 'PGC')",
#   "('XBP1', 'PGC')",
#   "('ITGB1', 'SFTPC')",
#   "('NKX2-1', 'SFTPD')",
#   "('MGST1', 'DMBT1')",
#   "('PKM', 'NAPSA')",
#   "('DUOX1', 'SFTPC')",
#   "('PGC', 'DMBT1')",
#   "('EPCAM', 'SFTPD')",
#   "('XBP1', 'DMBT1')",
#   "('ITGB1', 'SFTPD')",
#   "('FN1', 'SFTPD')",
#   "('EPCAM', 'CD44')",
#   "('RNASE1', 'DMBT1')",
#   "('NKX2-1', 'PGC')",
#   "('XBP1', 'CD44')",
#   "('LAMP3', 'CD44')"],
#  'Proliferating Lymphoid': ["('PTPRC', 'VIM')",
#   "('VIM', 'JCHAIN')",
#   "('PIM2', 'XBP1')",
#   "('STAT1', 'VIM')",
#   "('IL7R', 'VIM')",
#   "('HERPUD1', 'VIM')",
#   "('UBE2J1', 'VIM')",
#   "('JCHAIN', 'VIM')",
#   "('PTPRC', 'HLA-DRA')",
#   "('CXCR4', 'VIM')",
#   "('SEC11C', 'JCHAIN')",
#   "('HLA-DRA', 'VIM')",
#   "('ITM2C', 'XBP1')",
#   "('SEC11C', 'HERPUD1')",
#   "('SPCS3', 'VIM')",
#   "('PRDX4', 'XBP1')",
#   "('PDIA4', 'VIM')"],
#  'Proliferating Mesenchymal': ["('FN1', 'VIM')",
#   "('COL1A2', 'COL3A1')",
#   "('COL3A1', 'VIM')",
#   "('LUM', 'COL3A1')",
#   "('COL1A1', 'COL3A1')",
#   "('LUM', 'COL1A2')",
#   "('LUM', 'COL1A1')",
#   "('COL1A2', 'COL1A1')",
#   "('COL1A1', 'COL1A2')",
#   "('SPARCL1', 'VIM')",
#   "('COL1A2', 'FN1')",
#   "('FN1', 'LUM')",
#   "('MEG3', 'COL1A2')",
#   "('MEG3', 'COL3A1')",
#   "('VIM', 'COL1A1')",
#   "('COL1A1', 'FN1')",
#   "('COL1A2', 'LUM')",
#   "('PTGDS', 'COL1A2')",
#   "('SPARCL1', 'COL1A1')",
#   "('PTGDS', 'VIM')",
#   "('PTGDS', 'FN1')",
#   "('RHOA', 'COL1A2')",
#   "('PDIA3', 'COL1A2')",
#   "('PTGDS', 'COL1A1')",
#   "('RHOA', 'COL3A1')",
#   "('ATF4', 'COL1A2')",
#   "('COL3A1', 'LUM')",
#   "('PDIA3', 'FN1')",
#   "('ACTA2', 'COL3A1')",
#   "('ATF4', 'COL3A1')"],
#  'Proliferating Myeloid': ["('LYZ', 'VIM')",
#   "('HLA-DRA', 'VIM')",
#   "('HLA-DRA', 'LYZ')",
#   "('FN1', 'LYZ')",
#   "('CD44', 'LYZ')",
#   "('MS4A7', 'VIM')",
#   "('CD68', 'VIM')",
#   "('HLA-DQA1', 'LYZ')",
#   "('RHOA', 'HLA-DRA')",
#   "('FN1', 'VIM')",
#   "('RHOA', 'VIM')",
#   "('CD68', 'HLA-DRA')",
#   "('PKM', 'LYZ')",
#   "('PDIA3', 'VIM')",
#   "('CST3', 'LYZ')",
#   "('CD68', 'CCL18')",
#   "('CST3', 'HLA-DRA')",
#   "('CD44', 'CCL18')",
#   "('CCL18', 'HLA-DRA')",
#   "('PTPRC', 'VIM')",
#   "('PTPRC', 'HLA-DRA')",
#   "('HLA-DRA', 'FN1')",
#   "('PKM', 'FN1')",
#   "('PKM', 'CCL18')",
#   "('ATF4', 'HLA-DRA')",
#   "('IDH1', 'LYZ')",
#   "('PLIN2', 'VIM')",
#   "('LUM', 'LYZ')",
#   "('MCEMP1', 'VIM')",
#   "('COL3A1', 'LYZ')"],
#  'SCGB3A2+': ["('ICAM1', 'SCGB3A2')",
#   "('KRT18', 'SCGB3A2')",
#   "('PDIA3', 'SCGB3A2')",
#   "('MGST1', 'SCGB3A2')",
#   "('RHOA', 'SCGB3A2')",
#   "('CEACAM6', 'ICAM1')"],
#  'SCGB3A2+/SCGB1A1+': ["('SCGB3A2', 'XBP1')",
#   "('MGST1', 'SCGB3A2')",
#   "('PDIA3', 'SCGB3A2')",
#   "('WFDC2', 'XBP1')",
#   "('KRT18', 'SCGB3A2')",
#   "('ICAM1', 'SCGB3A2')",
#   "('PDIA3', 'XBP1')",
#   "('SCGB3A2', 'SCGB1A1')",
#   "('SCGB1A1', 'XBP1')",
#   "('KRT18', 'XBP1')",
#   "('RHOA', 'SCGB3A2')",
#   "('HLA-DRA', 'SCGB1A1')",
#   "('AGR3', 'XBP1')",
#   "('MGST1', 'RNASE1')",
#   "('KRT8', 'XBP1')",
#   "('VIM', 'RNASE1')",
#   "('CCN2', 'XBP1')",
#   "('ICAM1', 'RNASE1')",
#   "('PKM', 'XBP1')",
#   "('EPCAM', 'HLA-DRA')",
#   "('MGST1', 'ICAM1')",
#   "('HSPA5', 'HLA-DRA')",
#   "('EPCAM', 'VIM')",
#   "('CEACAM6', 'ICAM1')",
#   "('ATF4', 'RNASE1')",
#   "('EPCAM', 'ICAM1')",
#   "('EPCAM', 'CD44')",
#   "('HYOU1', 'XBP1')"],
#  'SMCs': ["('COL3A1', 'ACTA2')",
#   "('COL1A2', 'SPARCL1')",
#   "('ITGB1', 'SPARCL1')",
#   "('YAP1', 'VIM')",
#   "('SPARCL1', 'VIM')",
#   "('COL1A2', 'FN1')",
#   "('FN1', 'VIM')",
#   "('COL3A1', 'VIM')",
#   "('CCN2', 'VIM')",
#   "('YAP1', 'SPARCL1')",
#   "('CD44', 'ACTA2')",
#   "('PTGDS', 'ACTA2')",
#   "('DCN', 'ACTA2')",
#   "('PDIA3', 'ACTA2')",
#   "('COL1A1', 'FN1')",
#   "('ATF4', 'SPARCL1')",
#   "('COL1A2', 'ITGB1')",
#   "('DCN', 'SPARCL1')",
#   "('EPAS1', 'FN1')",
#   "('YAP1', 'COL1A2')",
#   "('COL1A1', 'COL1A2')",
#   "('SPARCL1', 'ITGB1')",
#   "('ITGB1', 'CCN2')",
#   "('FN1', 'ITGB1')",
#   "('ATF4', 'VIM')",
#   "('YAP1', 'COL3A1')",
#   "('CST3', 'SPARCL1')",
#   "('COL1A2', 'CCN2')",
#   "('SPARCL1', 'CCN2')",
#   "('CTNNB1', 'FN1')"],
#  'SPP1+ Macrophages': ["('MARCO', 'VIM')",
#   "('PKM', 'CCL18')",
#   "('PKM', 'FCER1G')",
#   "('IDH1', 'LYZ')",
#   "('MS4A7', 'CD44')",
#   "('CD68', 'CCL18')",
#   "('RHOA', 'CD68')",
#   "('PDIA3', 'FCER1G')",
#   "('CD68', 'CD44')",
#   "('CD44', 'CCL18')",
#   "('CD68', 'FCER1G')",
#   "('PKM', 'LYZ')",
#   "('MS4A7', 'CD68')",
#   "('HMOX1', 'VIM')",
#   "('MS4A7', 'FCER1G')",
#   "('CD68', 'VIM')",
#   "('CD68', 'HLA-DRA')",
#   "('CD44', 'LYZ')",
#   "('PLIN2', 'VIM')",
#   "('FN1', 'LYZ')",
#   "('MS4A7', 'VIM')",
#   "('HLA-DRA', 'LYZ')",
#   "('PKM', 'FN1')",
#   "('CCL18', 'HLA-DRA')",
#   "('LYZ', 'VIM')",
#   "('RHOA', 'HLA-DRA')",
#   "('HLA-DQA1', 'LYZ')",
#   "('HLA-DRA', 'VIM')",
#   "('PDIA3', 'VIM')",
#   "('RHOA', 'VIM')"],
#  'T-cells': ["('IL7R', 'VIM')",
#   "('PTPRC', 'VIM')",
#   "('CXCR4', 'VIM')",
#   "('PTGDS', 'VIM')",
#   "('JCHAIN', 'VIM')",
#   "('CD44', 'LUM')",
#   "('PTPRC', 'HLA-DRA')",
#   "('STAT1', 'VIM')",
#   "('CD44', 'JCHAIN')",
#   "('SFRP2', 'VIM')",
#   "('VIM', 'JCHAIN')",
#   "('SOD2', 'VIM')",
#   "('HLA-DRA', 'LUM')",
#   "('COL1A2', 'PTGDS')",
#   "('VIM', 'PTGDS')",
#   "('COL3A1', 'LUM')",
#   "('SFRP2', 'PTGDS')"],
#  'Transitional AT2': ["('CEACAM6', 'NAPSA')",
#   "('CEACAM6', 'SFTPC')",
#   "('CEACAM6', 'ICAM1')",
#   "('ICAM1', 'SCGB3A2')",
#   "('SFTPD', 'ICAM1')",
#   "('NAPSA', 'ICAM1')",
#   "('MGST1', 'ICAM1')",
#   "('ICAM1', 'NAPSA')",
#   "('RNASE1', 'PGC')",
#   "('HLA-DRA', 'NAPSA')",
#   "('XBP1', 'PGC')",
#   "('CD44', 'NAPSA')",
#   "('VIM', 'NAPSA')",
#   "('RHOA', 'NAPSA')",
#   "('PGC', 'NAPSA')",
#   "('RNASE1', 'SFTPD')",
#   "('PDIA3', 'SFTPC')",
#   "('HLA-DRA', 'SFTPC')",
#   "('DMBT1', 'SFTPC')",
#   "('EPCAM', 'ICAM1')",
#   "('PKM', 'NAPSA')",
#   "('KRT8', 'PGC')",
#   "('FN1', 'ICAM1')",
#   "('XBP1', 'CD44')",
#   "('MGST1', 'RNASE1')",
#   "('MGST1', 'SFTPD')",
#   "('KRT18', 'SCGB3A2')",
#   "('KRT18', 'SFTPD')",
#   "('KRT8', 'SFTPD')",
#   "('KRT18', 'CD44')"],
#  'Venous': ["('ACKR1', 'VIM')",
#   "('PLVAP', 'VIM')",
#   "('PECAM1', 'POSTN')",
#   "('EPAS1', 'POSTN')",
#   "('PECAM1', 'CCN2')",
#   "('HLA-DRA', 'SPARCL1')",
#   "('ITGB1', 'SPARCL1')",
#   "('SPARCL1', 'VIM')",
#   "('CCN2', 'VIM')",
#   "('COL1A2', 'SPARCL1')",
#   "('CD34', 'PECAM1')",
#   "('SPARCL1', 'CCN2')",
#   "('ITGB1', 'EPAS1')",
#   "('ATF4', 'SPARCL1')",
#   "('HLA-DRA', 'POSTN')",
#   "('HLA-DRA', 'PECAM1')",
#   "('PTGDS', 'PECAM1')",
#   "('JCHAIN', 'VIM')",
#   "('ITGB1', 'CCN2')",
#   "('PDIA3', 'POSTN')",
#   "('ATF4', 'PECAM1')",
#   "('PDIA3', 'EPAS1')",
#   "('PDIA3', 'VIM')",
#   "('COL1A2', 'POSTN')",
#   "('HLA-DRA', 'EPAS1')",
#   "('VIM', 'POSTN')",
#   "('RNASE1', 'SPARCL1')",
#   "('RHOA', 'VIM')",
#   "('CD34', 'EPAS1')",
#   "('PTGDS', 'VIM')"],
#  'aCap': ["('VIM', 'EPAS1')",
#   "('RHOA', 'VIM')",
#   "('ITGB1', 'EPAS1')",
#   "('HLA-DRA', 'EPAS1')",
#   "('HLA-DRA', 'PECAM1')",
#   "('SFTPC', 'VIM')",
#   "('ATF4', 'PECAM1')",
#   "('SPARCL1', 'VIM')",
#   "('SFTPC', 'EPAS1')",
#   "('PDIA3', 'EPAS1')",
#   "('BMPR2', 'EPAS1')",
#   "('BMPR2', 'VIM')",
#   "('ATF4', 'VIM')",
#   "('CD34', 'EPAS1')",
#   "('CD34', 'PECAM1')",
#   "('PTGDS', 'PECAM1')",
#   "('HLA-DRA', 'SPARCL1')",
#   "('KRT8', 'VIM')",
#   "('SOD2', 'EPAS1')",
#   "('PDIA3', 'VIM')",
#   "('STAT1', 'VIM')",
#   "('PECAM1', 'HLA-DRA')",
#   "('ITGB1', 'SPARCL1')",
#   "('HLA-DRA', 'VIM')",
#   "('ATF4', 'SPARCL1')",
#   "('PECAM1', 'COL3A1')",
#   "('ITGB1', 'RHOA')",
#   "('IL7R', 'VIM')",
#   "('CCN2', 'VIM')",
#   "('EPAS1', 'HLA-DRA')"],
#  'gCap': ["('VIM', 'EPAS1')",
#   "('SFTPC', 'EPAS1')",
#   "('HLA-DRA', 'EPAS1')",
#   "('ITGB1', 'EPAS1')",
#   "('IL7R', 'VIM')",
#   "('CD34', 'EPAS1')",
#   "('PDIA3', 'EPAS1')",
#   "('SFTPC', 'VIM')",
#   "('SPARCL1', 'VIM')",
#   "('BMPR2', 'EPAS1')",
#   "('HLA-DRA', 'PECAM1')",
#   "('ATF4', 'PECAM1')",
#   "('BMPR2', 'VIM')",
#   "('CD34', 'PECAM1')",
#   "('PTGDS', 'PECAM1')",
#   "('HLA-DRA', 'SPARCL1')",
#   "('PECAM1', 'FN1')",
#   "('RHOA', 'VIM')",
#   "('EPAS1', 'SFTPC')",
#   "('SOD2', 'EPAS1')",
#   "('ATF4', 'SPARCL1')",
#   "('SFTPD', 'VIM')",
#   "('PECAM1', 'HLA-DRA')",
#   "('RNASE1', 'SPARCL1')",
#   "('STAT1', 'VIM')",
#   "('PECAM1', 'LUM')",
#   "('ATF4', 'VIM')",
#   "('PECAM1', 'COL3A1')",
#   "('ITGB1', 'SPARCL1')",
#   "('PECAM1', 'COL1A2')"],
#  'not available': ["('PDIA3', 'FN1')",
#   "('VIM', 'COL1A1')",
#   "('YAP1', 'VIM')",
#   "('COL1A2', 'COL1A1')",
#   "('COL1A2', 'COL3A1')",
#   "('LUM', 'COL1A1')",
#   "('LUM', 'COL3A1')",
#   "('PKM', 'NAPSA')",
#   "('RHOA', 'COL3A1')",
#   "('ITGB1', 'ICAM1')",
#   "('KRT18', 'KRT8')",
#   "('ATF4', 'COL3A1')",
#   "('EPCAM', 'ICAM1')",
#   "('PKM', 'PDIA3')",
#   "('ITGB1', 'PDIA3')",
#   "('PKM', 'FN1')",
#   "('RHOA', 'COL1A2')",
#   "('PDIA3', 'COL1A2')",
#   "('ATF4', 'COL1A2')",
#   "('CTNNB1', 'FN1')",
#   "('FN1', 'ICAM1')",
#   "('RHOA', 'NAPSA')",
#   "('ATF4', 'PDIA3')",
#   "('MGST1', 'ICAM1')",
#   "('EPCAM', 'HLA-DRA')",
#   "('PKM', 'XBP1')",
#   "('ATF4', 'ICAM1')",
#   "('EPCAM', 'CD44')",
#   "('HLA-DRA', 'NAPSA')",
#   "('CEACAM6', 'ICAM1')"],
#  'pDCs': ["('HERPUD1', 'VIM')",
#   "('VIM', 'JCHAIN')",
#   "('JCHAIN', 'VIM')",
#   "('HERPUD1', 'HLA-DRA')",
#   "('HERPUD1', 'PTGDS')",
#   "('CXCR4', 'VIM')",
#   "('VIM', 'PTGDS')",
#   "('ITM2C', 'JCHAIN')",
#   "('JCHAIN', 'HLA-DRA')",
#   "('GPR183', 'HLA-DRA')",
#   "('HLA-DRA', 'VIM')",
#   "('ITM2C', 'VIM')",
#   "('VIM', 'HLA-DRA')",
#   "('COL1A2', 'JCHAIN')",
#   "('HERPUD1', 'LUM')",
#   "('XBP1', 'HLA-DRA')",
#   "('STAT1', 'VIM')",
#   "('STAT1', 'PTGDS')"]}

# %%
#define the marker gene 
#Here i select the top 5 gene pair markers
# Reorder columns in adata by specified 'ordered_labels'
# adata_hvg = adata_hvg[:, np.array([marker for marker in marker_pairs_dict])]
adata_sorted = adata_hvg[adata_hvg.obs.sort_values("Annotations").index].copy()



ax = sc.pl.heatmap(
    adata_sorted,
    marker_pairs_dict, 
    groupby="Annotations", 
    cmap="viridis", 
    dendrogram=True,
    figsize=(10, 20), 
    swap_axes=False,
    show=False
)
# Customize the heatmap aesthetics with matplotlib after plotting
fig = plt.gcf()  # Get the current figure from the plot
ax = plt.gca()  # Get the current axes

# # Increase figure size for better space allocation (adjust as needed)
# fig.set_size_inches(12, 15)

# # Rotate x-tick labels by 45 degrees for better visibility
# ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")

# # Reduce font size for labels if needed
# plt.setp(ax.get_xticklabels(), fontsize=8)
# plt.setp(ax.get_yticklabels(), fontsize=8)

# # Add more padding between the annotations and the figure
plt.tight_layout()

# # Show and save the modified plot
plt.show()

# Optional: Save the arranged heatmap
fig.savefig("/scratch/project_465001027/Spatialformer/Figure/arranged_heatmap.png", dpi=300, bbox_inches='tight')
# Close the figure to free up memory, especially in scripts
plt.close(fig)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_Annotations). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: AT1, AT2, Activated FBs, etc.
# var_group_labels: AT1, AT2, Activated FBs, etc.
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`
# /tmp/ipykernel_121462/4011080912.py:34: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
adata_hvg.obs
# Out:
#             Niche_Annotations               Annotations  n_genes_by_counts  \
# cell_0                     T2                   B cells                  9
# cell_1                     T2                   T-cells                  7
# cell_2                     T2                   B cells                  2
# cell_3                     T5               Macrophages                 35
# cell_4                     T9               Fibroblasts                 36
# ...                       ...                       ...                ...
# cell_892162                T4                      SMCs                  4
# cell_892163                T9               Fibroblasts                  1
# cell_892164                T4                   T-cells                 11
# cell_892165                T4              Alveolar FBs                 24
# cell_892166                T5  Interstitial Macrophages                  2
#
#              log1p_n_genes_by_counts  total_counts  log1p_total_counts  \
# cell_0                      2.302585             9            2.302585
# cell_1                      2.079442             7            2.079442
# cell_2                      1.098612             2            1.098612
# cell_3                      3.583519            35            3.583519
# cell_4                      3.610918            36            3.610918
# ...                              ...           ...                 ...
# cell_892162                 1.609438             4            1.609438
# cell_892163                 0.693147             1            0.693147
# cell_892164                 2.484907            11            2.484907
# cell_892165                 3.218876            24            3.218876
# cell_892166                 1.098612             2            1.098612
#
#              pct_counts_in_top_50_genes  pct_counts_in_top_100_genes  \
# cell_0                            100.0                        100.0
# cell_1                            100.0                        100.0
# cell_2                            100.0                        100.0
# cell_3                            100.0                        100.0
# cell_4                            100.0                        100.0
# ...                                 ...                          ...
# cell_892162                       100.0                        100.0
# cell_892163                       100.0                        100.0
# cell_892164                       100.0                        100.0
# cell_892165                       100.0                        100.0
# cell_892166                       100.0                        100.0
#
#              pct_counts_in_top_200_genes  pct_counts_in_top_500_genes
# cell_0                             100.0                        100.0
# cell_1                             100.0                        100.0
# cell_2                             100.0                        100.0
# cell_3                             100.0                        100.0
# cell_4                             100.0                        100.0
# ...                                  ...                          ...
# cell_892162                        100.0                        100.0
# cell_892163                        100.0                        100.0
# cell_892164                        100.0                        100.0
# cell_892165                        100.0                        100.0
# cell_892166                        100.0                        100.0
#
# [892167 rows x 10 columns]

# %%
import scanpy as sc
# markers = ["('JCHAIN', 'HLA-DRA')", "('STAT1', 'HLA-DRA')", "('VIM', 'HLA-DRA')"]
cluster_list = ["Transitional AT2", "AT2", "AT1", 
                "Proliferating Epithelial", "KRT5-/KRT17+",
               ]
adata_dot = adata[adata.obs["Annotations"].isin(cluster_list),:]

# markers = ["('EPCAM', 'ICAM1')", "('CEACAM6', 'ICAM1')", "('FN1', 'ICAM1')", 
#            "('ITGB1', 'ICAM1')", "('NAPSA', 'ICAM1')", "('ATF4', 'ICAM1')",
#           ""]
markers = top_markers_all_clusters[top_markers_all_clusters["cluster"] == "AT1"]["names"].values

sc.pl.dotplot(adata_dot, markers, groupby='Annotations', dendrogram=True)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_Annotations). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %%
adata.var_names[0]
# Out:
# "('JCHAIN', 'HLA-DRA')"

# %%
top_markers_all_clusters[top_markers_all_clusters["cluster"] == "AT1"]["names"].values
# Out:
# array(["('EPCAM', 'ICAM1')", "('CEACAM6', 'ICAM1')", "('FN1', 'ICAM1')",
#        "('ITGB1', 'ICAM1')", "('NAPSA', 'ICAM1')", "('ATF4', 'ICAM1')",
#        "('SFTPD', 'ICAM1')", "('EPCAM', 'VIM')", "('KRT8', 'VIM')",
#        "('ITGB1', 'RNASE1')", "('KRT18', 'KRT8')", "('VIM', 'RNASE1')",
#        "('SFTPD', 'VIM')", "('CEACAM6', 'SFTPC')", "('MGST1', 'ICAM1')",
#        "('ATF4', 'RNASE1')", "('VIM', 'EPAS1')", "('ICAM1', 'RNASE1')",
#        "('CEACAM6', 'NAPSA')", "('ITGB1', 'SFTPC')",
#        "('NKX2-1', 'SFTPD')", "('NAPSA', 'FN1')", "('KRT18', 'SFTPD')",
#        "('ITGB1', 'CCN2')", "('EPCAM', 'SFTPD')", "('SFTPC', 'VIM')",
#        "('RNASE1', 'SFTPD')", "('KRT8', 'SFTPD')", "('MGST1', 'RNASE1')",
#        "('RHOA', 'NAPSA')"], dtype=object)
