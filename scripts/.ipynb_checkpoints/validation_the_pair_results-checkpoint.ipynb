# %%
from datasets import load_from_disk
from data_loader import create_dataloader,create_dataloader_eval

# %%
import sys
sys.path.append("/scratch/project_465001027/Spatialformer/utils")
from utils import DynamicHuggingFaceDataset
import sys
import scanpy as sc
from train import manual_train_fm
import os
import json
import torch

# %% [markdown]
# ### Configurate the model

# %%
datapath = "/scratch/project_465001027/Spatialformer/cache/xenium_THD0008_pair"
train_dataloader, val_dataloader = create_dataloader_eval(datapath, 
                                                    num_workers = 4, 
                                                    batch_size = 4,
                                                    # batch_size = 16,
                                                    directionality = True,
                                                    context_length = 500, 
                                                    padding_idx = 0, 
                                                    special_token_num = 4, 
                                                    n_bins = 51, 
                                                    sep_token = 1949, 
                                                    cls_token = 1)
get_file_path = lambda path, filename: os.path.join("/scratch/project_465001027/Spatialformer", path, filename)
config_path = get_file_path("config", "_config_train_large_pair.json")
with open(config_path, 'r') as json_file:
    config = json.load(json_file)
model_ckp_path = "step=0025000-train_total_loss=-1.3222-val_total_loss=0.0000.ckpt"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = manual_train_fm(config = config)
ckp = torch.load(model_ckp_path, map_location=torch.device(device))
params = ckp["state_dict"]
model.load_state_dict(params)
model.eval()
model.to(device)
# Out:
# [rank: 0] Global seed set to 42
# require grad: True
# Spaformer(
#   (encoder): SpaEncoder(
#     (emb_proj): Linear(in_features=2560, out_features=512, bias=True)
#     (emb_dropout): Dropout(p=0.1, inplace=False)
#     (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (bpp_feature_proj): Linear(in_features=3, out_features=512, bias=True)
#     (bpp_convnet): BPPConvnet(
#       (conv1): MaskedConv2d(
#         (conv): Conv2dSame(
#           (conv): Conv2d(1, 64, kernel_size=(7, 7), stride=(1, 1))
#         )
#       )
#       (act1): ReLU()
#       (conv2): MaskedConv2d(
#         (conv): Conv2dSame(
#           (conv): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1))
#         )
#       )
#       (final_act): Identity()
#     )
#     (layers): ModuleList(
#       (0-9): 10 x SqueezeformerBlock(
#         (conv_blocks): ModuleList(
#           (0): Conv1DBlock(
#             (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (glu): GLU(
#               (activation): SiLU()
#             )
#             (expand_conv): Linear(in_features=512, out_features=1024, bias=True)
#             (conv): MaskedConv1d(
#               (conv): Conv1dSame(
#                 (conv): Conv1d(512, 512, kernel_size=(17,), stride=(1,), groups=512, bias=False)
#               )
#             )
#             (conv_norm): MaskedBatchNorm1d(512, eps=1e-05, momentum=0.05, affine=True, track_running_stats=True)
#             (conv_act): SiLU()
#             (conv_proj): Linear(in_features=512, out_features=512, bias=True)
#             (mlp): GLUMlp(
#               (ffn1): Linear(in_features=512, out_features=2048, bias=True)
#               (glu): GLU(
#                 (activation): SiLU()
#               )
#               (do1): Dropout(p=0.1, inplace=False)
#               (ffn2): Linear(in_features=1024, out_features=512, bias=True)
#             )
#             (conv_dropout): Dropout(p=0.1, inplace=False)
#             (drop1): DropPath()
#             (drop2): DropPath()
#             (conv_scale): ScaleBiasLayer()
#             (mlp_scale): ScaleBiasLayer()
#           )
#         )
#         (attn_blocks): ModuleList(
#           (0): AltBlock(
#             (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (self_attn): AltAttention(
#               (qkv): Linear(in_features=512, out_features=1536, bias=True)
#               (attn_drop): Dropout(p=0.1, inplace=False)
#               (proj): Linear(in_features=512, out_features=512, bias=True)
#             )
#             (drop1): DropPath()
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (mlp): GLUMlp(
#               (ffn1): Linear(in_features=512, out_features=2048, bias=True)
#               (glu): GLU(
#                 (activation): SiLU()
#               )
#               (do1): Dropout(p=0.1, inplace=False)
#               (ffn2): Linear(in_features=1024, out_features=512, bias=True)
#             )
#             (drop2): DropPath()
#             (attn_scale): ScaleBiasLayer()
#             (mlp_scale): ScaleBiasLayer()
#           )
#         )
#       )
#     )
#   )
#   (classifier_head): Linear(in_features=512, out_features=1950, bias=True)
#   (pair_head): Linear(in_features=512, out_features=2, bias=False)
#   (adjprojector): AdjacencyProjector(
#     (fc): Linear(in_features=1024, out_features=1, bias=False)
#   )
#   (activation): Tanh()
#   (embeddings): Embedding(1950, 512, padding_idx=0)
#   (token_type_embeddings): Embedding(3, 512)
#   (spatialembeds): GraphSAGESpatialEmbedding(
#     (emb): Embedding(1950, 512)
#   )
#   (MEloss): MaskedMSELoss(
#     (loss): CrossEntropyLoss()
#   )
#   (MDloss): MaskedMSE2DLoss()
#   (Pairloss): PairLoss(
#     (loss): CrossEntropyLoss()
#   )
# )

# %%
def get_acc(pred, target):
    target = target.to(device)
    # import pdb; pdb.set_trace()
    _, pred = torch.max(pred.data, 1)  # Get the predicted class
    total = target.size(0)  # Total number of samples
    correct = (pred == target).sum().item()  # Count correct predictions
    accuracy = correct / total
    return accuracy

# %%
from tqdm import tqdm
counter = 0
pos_counter = 0
neg_counter = 0
predicted = []
label = []
with torch.no_grad():
    for i, batch in tqdm(enumerate(val_dataloader)):
        if i<1500:
            pair_label = batch["pair_label"]
            label.append(pair_label)
            counter += len(pair_label)
            pos_counter += (pair_label == 1).sum().item()
            neg_counter += (pair_label == 0).sum().item()
            last_hidden_repr, co_adj_prob = model.get_embeddings(batch, [-1], True, False)
            predicted.append(co_adj_prob)
        else:
            break

predicts = torch.concat(predicted)
targets = torch.concat(label)
acc = get_acc(co_adj_prob, pair_label)
print(f"accuracy of the pair prediction: {acc}")
print(f"There are {counter} samples that are token into account")
print(f"{pos_counter} is positive; {neg_counter} is negative")
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/62 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/62 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/62 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/62 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3378993
#     })
#     test: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3383
#     })
# })DatasetDict({
#     train: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3378993
#     })
#     test: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3383
#     })
# })
#
# DatasetDict({
#     train: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3378993
#     })
#     test: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3383
#     })
# })
# DatasetDict({
#     train: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3378993
#     })
#     test: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3383
#     })
# })
#   0%|          | 0/62 [00:01<?, ?it/s]
#   0%|          | 0/62 [00:01<?, ?it/s]
#   0%|          | 0/62 [00:01<?, ?it/s]
#   0%|          | 0/62 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[81], line 15
#      13     pos_counter += (pair_label == 1).sum().item()
#      14     neg_counter += (pair_label == 0).sum().item()
# ---> 15     last_hidden_repr, co_adj_prob = model.get_embeddings(batch, [-1], True, False)
#      16     predicted.append(co_adj_prob)
#      17 else:
#
# File /pfs/lustrep4/scratch/project_465001027/Spatialformer/model/Spaformer_pair.py:725, in Spaformer.get_embeddings(self, batch, layers, pair_prediction, co_prediction)
#     723 attention_mask = batch["attention_mask"].to(self.device)
#     724 token_type_ids = batch["token_type_ids"].to(self.device)
# --> 725 predictions = self.forward(indices, False, attention_mask, token_type_ids)
#     726 if not pair_prediction:
#     727     if not co_prediction:
#
# File /pfs/lustrep4/scratch/project_465001027/Spatialformer/model/Spaformer_pair.py:318, in Spaformer.forward(self, x, adjmtx, attention_mask, token_type_ids, **kwargs)
#     316 prediction = self.classifier_head(transformer_output[-1])
#     317 #get the pair-wise gene-gene interaction matrix
# --> 318 dis_prediction = self.adjprojector(token_embedding)
#     319 self.attentions = attn_scores
#     320 pair_prediction = self.pair_head(transformer_output[-1][:,0]) # the first token embeddings as input and predict whether two cells are paired
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /scratch/project_465001027/deeploc_torch/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /pfs/lustrep4/scratch/project_465001027/Spatialformer/model/Spaformer_pair.py:145, in AdjacencyProjector.forward(self, E)
#     143 E_i = E.unsqueeze(2).expand(-1, -1, num_genes, -1)##B X L X L X dim
#     144 E_j = E.unsqueeze(1).expand(-1, num_genes, -1, -1)##B X L X L X dim
# --> 145 pairs = torch.cat((E_i, E_j), dim=-1)
#     147 # Compute adjacency scores
#     148 adjacency_scores = self.fc(pairs).squeeze(-1)#B x L X L
#
# OutOfMemoryError: HIP out of memory. Tried to allocate 7.63 GiB. GPU

# %% [markdown]
# ### Perturbation analysis for pair-wise data

# %%
from tqdm import tqdm
with torch.no_grad():
    for i, batch in tqdm(enumerate(val_dataloader)):
        label = batch["pair_label"]
        batch_size = len(label)
        if i < 10:
#             print((1 == label))
            if ((1 == label).sum() == batch_size/2) and ((0 == label).sum() == batch_size/2):
                label = batch["pair_label"]
                that_batch = batch
                last_hidden_repr, co_adj_prob = model.get_embeddings(batch, [-1], True, False)
#             else:
                print("get")
                break
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/62 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/62 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/62 [00:00<?, ?it/s]
# Loading dataset from disk:   0%|          | 0/62 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3378993
#     })
#     test: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3383
#     })
# })
# DatasetDict({
#     train: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3378993
#     })
#     test: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3383
#     })
# })
# DatasetDict({
#     train: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3378993
#     })
#     test: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3383
#     })
# })
# DatasetDict({
#     train: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3378993
#     })
#     test: Dataset({
#         features: ['left_Full_Tokens', 'left_Expression', 'left_row', 'left_col', 'left_data', 'left_shape', 'right_Full_Tokens', 'right_Expression', 'right_row', 'right_col', 'right_data', 'right_shape', 'Labels'],
#         num_rows: 3383
#     })
# })
#   0%|          | 0/62 [00:01<?, ?it/s]
#   0%|          | 0/62 [00:01<?, ?it/s]
#   0%|          | 0/62 [00:01<?, ?it/s]
#   0%|          | 0/62 [00:01<?, ?it/s]
# get

# %%
def rearrange_sentences(batch):
    # Extract the relevant tensors from the batch dictionary
    batch_size = len(batch['indices'])
    max_length = 500
    indices = batch['indices']
    mask_attentions = batch['attention_mask']  # Corrected to match your input
    token_types = batch['token_type_ids']  # Corrected field names
    pair_label = batch["pair_label"]
    new_indices = torch.full((batch_size, max_length), 0, dtype=torch.int)
    new_mask_attention = torch.full((batch_size, max_length), 0, dtype=torch.int)
    new_token_types = torch.full((batch_size, max_length), 0, dtype=torch.int)

    sep_token = 1949  # This is the token ID for the separator

    for i, (indice, mask_attention, token_type) in enumerate(zip(indices, mask_attentions, token_types)):
        # Find the index of the separator token (1949)
        print("batch_size", batch_size)
        mid_index = (indice == sep_token).nonzero(as_tuple=True)[0][0]
        end_index = (indice == sep_token).nonzero(as_tuple=True)[0][1]
#         print((indice == sep_token).nonzero(as_tuple=True))
#         print(mid_index)
        if mid_index.numel() == 0:  # Check if SEP token is present
            print(f"Warning: SEP token not found in batch index {i}.")
            continue  # Skip to the next batch if no SEP token is found
        
        # Split the indices into two sentences
        cls = indice[:1]  # Include the CLS token
#         print(indice)
        sentence1 = indice[1:mid_index + 1]  # From index 1 to the SEP token (inclusive)
        sentence2 = indice[mid_index + 1:end_index+1]   # From the token after the SEP to the end
        # Combine to form the new order: sentence2 followed by sentence1
        combined = torch.cat((cls, sentence2, sentence1))
        
        # Pad to the max_length
        new_sequence = torch.cat((combined, torch.zeros(max_length - combined.size(0), dtype=torch.int)))
#         print(new_sequence)
        # Update new_indices
        new_indices[i, :] = new_sequence[:max_length]  # Ensure to only keep the first max_length tokens

        # Update the attention mask
        new_mask_attention[i, :] = mask_attention  

        # Update the token type IDs
        left_token_type = torch.full((len(cls)+len(sentence2),), 1)  # Token type for the second sentence
        right_token_type = torch.full((len(sentence1),), 2)  # Token type for the first sentence
        pad_token_type = torch.full((max_length - combined.size(0),), 0)  # Padding type
#         print(left_token_type)
        # Combine token types
        new_token_type = torch.cat((left_token_type, right_token_type, pad_token_type))

        # Update new_token_types
        new_token_types[i, :] = new_token_type[:max_length]

    # Put it all back in a dictionary
    new_batch = {
        "indices": new_indices,  # Add batch dimension
        "attention_mask": new_mask_attention.bool(),  # Add batch dimension
        "token_type_ids": new_token_types,  # Add batch dimension
        "pair_label": pair_label
    }
    
    return new_batch

# %%
reorder_batch = rearrange_sentences(that_batch)
# Out:
# batch_size 4
# batch_size 4
# batch_size 4
# batch_size 4

# %%
_repr, prob = model.get_embeddings(that_batch, [-1], True, False)

# %%
prob
# Out:
# tensor([[1.0000e+00, 1.5226e-07],
#         [1.1027e-06, 1.0000e+00],
#         [6.0849e-06, 9.9999e-01],
#         [1.0000e+00, 8.4798e-08]], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %%
that_batch["pair_label"]
# Out:
# tensor([0., 1., 1., 0.])

# %%
rev_repr, rev_prob = model.get_embeddings(reorder_batch, [-1], True, False)

# %%
rev_prob
# Out:
# tensor([[1.3325e-06, 1.0000e+00],
#         [1.7922e-06, 1.0000e+00],
#         [1.3780e-06, 1.0000e+00],
#         [8.6974e-07, 1.0000e+00]], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %%
that_batch["pair_label"]
# Out:
# tensor([0., 1., 1., 0.])
