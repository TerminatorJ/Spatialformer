# %%
import pandas as pd
import pygwalker as pyg

# %% [markdown]
# # The original data of figure 1

# %%
import pandas as pd

# Specify the path to your Excel file
file_path = '/scratch/project_465001027/Spatialformer/data/data_information.xlsx'

# Specify the sheet name you want to load
sheet_name = 'human_data'  # Replace with your sheet name

# Load the specified sheet into a DataFrame
df = pd.read_excel(file_path, sheet_name=sheet_name, index_col=[0])

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                                                    Str_ID  Assays  \
# Number
# 1                     Xenium_V1_hLung_cancer_section_outs  Xenium
# 2       Xenium_Preview_Human_Non_diseased_Lung_With_Ad...  Xenium
# 3       Xenium_Preview_Human_Lung_Cancer_With_Add_on_2...  Xenium
# 4       Xenium_V1_FFPE_Human_Brain_Healthy_With_Addon_...  Xenium
# 5       Xenium_V1_FFPE_Human_Brain_Glioblastoma_With_A...  Xenium
#
#         Transcripts  Genes Tissues  Transcript_per_cell    Cell  Cell_kept  \
# Number
# 1          25774030    377    Lung           171.409770  150365     143122
# 2          23994997    392    Lung            81.096234  295883     274110
# 3          67334982    392    Lung           126.768484  531165     456017
# 4           6011583    319   Brain           246.315783   24406      24074
# 5          13324742    319   Brain           325.891897   40887      40336
#
#           Condition1 Condition2  Dornor Organism  \
# Number
# ...

# %%
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000624846b3c4e72KcFsM1l3YoJP0TzX" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000624846b3c4e72KcFsM1l3YoJP0TzX") {
#             var iframe = document.getElementById("gwalker-000624846b3c4e72KcFsM1l3YoJP0TzX");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

# %%
# !pygwalker login
# Out:
# Please visit https://kanaries.net/home/cli?redirect_url=http%3A//localhost%3A43841 to log in.
# Waiting for authorization...
# Authorization success and kanaries token is configured!
# user: TerminatorJ
# workspace: TerminatorJ

# %%
# !kanaries_api_key
# Out:
# /bin/bash: kanaries_api_key: command not found
